# %%
import sys
#sys.path.append('/Users/si/')
sys.path.append('/Users/si/Python ML/')
#sys.path

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.decomposition import PCA
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from pathlib import Path

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from pathlib import Path
from sklearn.metrics import (roc_curve, auc, accuracy_score)
from sklearn.preprocessing import StandardScaler

from C42Winequality import func_library_c
from C42Winequality import func_library_class
from C42Winequality import MachineLearning

from C42Winequality.MachineLearning import RF_method, DT_method, PCA_method, LR_method
from C42Winequality.func_library_class import Preprocessing
from C42Winequality.func_library_c import standardscaler, preprocessing, dataHQ, fill_with_median, arrange_features,plot_xy
# Out:
# lists: <generator object Path.glob at 0x000002A241E65CA8>
# D:\datasets\data1\winequality-red.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# lists: <generator object Path.glob at 0x000002A241E65EB8>
# D:\datasets\data1\winequality-red.csv

# %%
#path = Path(r'D:/datasets/data1')
#data=func_library_c.preprocessing(path,2)
#data.head()
#dataHQ = func_library_c.dataHQ(data, 6)

path = Path(r'D:/datasets/data1')
data=preprocessing(path,2)
data.head()
dataHQ = dataHQ(data, 6)
# Out:
# lists: <generator object Path.glob at 0x0000026B6FA1BE60>
# D:\datasets\data1\winequality-red.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
#func_library_c.fill_with_median(data).head()
fill_with_median(data).head()
# Out:
# fill null cpmplete: 0
# fill null cpmplete: 1
# fill null cpmplete: 2
# fill null cpmplete: 3
# fill null cpmplete: 4
# fill null cpmplete: 5
# fill null cpmplete: 6
# fill null cpmplete: 7
# fill null cpmplete: 8
# fill null cpmplete: 9
# fill null cpmplete: 10
# fill null cpmplete: 11
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# ...

# %%
#arrange features
#func_library_c.arrange_features(data)

arrange_features(data)
# Out:
#                 features
# 0          fixed acidity
# 1       volatile acidity
# 2            citric acid
# 3         residual sugar
# 4              chlorides
# 5    free sulfur dioxide
# 6   total sulfur dioxide
# 7                density
# 8                     pH
# 9              sulphates
# 10               alcohol
# 11               quality

# %%
#func_library_c.plot_xy(data,10,8,11,50)

plot_xy(data,10,8,11,50)
# Out:
# <function C42Winequality.func_library_c.plot_xy(df, i, j, k, size)>

# %%
dataHQ = func_library_c.dataHQ(data, 6)
func_library_c.plot_xy(dataHQ,10,8,11,50)
# Out:
# <function C42Winequality.func_library_c.plot_xy(df, i, j, k, size)>

# %%
#MachineLearning.RF_method(dataHQ)
#rf_method = MachineLearning.RF_method(dataHQ)
#MachineLearning.RF_importance(dataHQ)
#MachineLearning.RF_data(dataHQ)

rf_method = RF_method(dataHQ)
rf_method.RF_learning()

rf_method.RF_importances()
rf_method.RF_prediction()

rf_method.indices
rf_method.importances
rf_method.features
rf_method.plot_featuresimportances
#rf_method.plot_featuresimportances(30, self.indices, )

#print(rf_method.RF_importances())
print(rf_method.RF_prediction())
# Out:
# (0.9696969696969697, array([7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7],
#       dtype=int64))

# %%
rf_method.plot_featuresimportances(5)

# %%
rf_method.plot_featuresimportances02(5, 
                                     rf_method.indices, 
                                     rf_method.importances, 
                                     rf_method.features)

# %%
dt_method = DT_method(dataHQ)
dt_method.DT_learning()

dt_method.RF_importances()
dt_method.RF_prediction()

#dt_method.indices
##dt_method.importances
#dt_method.features
#dt_method.dt_plot_featuresimportances
# Out:
# (0.9090909090909091,
#  array([7, 7, 7, 8, 7, 7, 7, 7, 8, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#         7, 7, 7, 7, 7, 7, 7, 7, 8, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#         7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 8, 7, 7, 7, 7, 7, 7, 7, 7],
#        dtype=int64))

# %%
dt_method.RF_prediction()
# Out:
# (0.9090909090909091,
#  array([7, 7, 7, 8, 7, 7, 7, 7, 8, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#         7, 7, 7, 7, 7, 7, 7, 7, 8, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#         7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 8, 7, 7, 7, 7, 7, 7, 7, 7],
#        dtype=int64))

# %%
#PCA_method
pca_method = PCA_method(dataHQ)
pca_method.standardscaler()
pca_method.pca_learning(dim=3)
# Out:
# X_train:(151, 11)
# y_train:(151,)
# pca_MEAN:[ 0.02025325  0.022436   -0.02427767  0.00719716 -0.11228698 -0.00597757
#  -0.0261459   0.02366667  0.00218808  0.03457177 -0.00105574]
# pca_X:[[ 3.81047034e+00  2.08443432e+00 -8.26474087e-01]
#  [ 2.67299814e+00 -1.02931585e-01  1.28796638e+00]
#  [-4.11627806e+00 -8.08532257e-01 -1.21309959e-01]
#  [-1.69447833e+00  2.87441914e-01 -7.77264612e-01]
#  [-1.53456961e+00  3.13604538e-01 -2.84020645e-01]
#  [ 6.01166946e-01 -1.17901887e+00  7.98901318e-01]
#  [-4.83496665e+00  2.24716776e+00  8.92688239e-01]
#  [-5.87877416e-01  1.65312207e+00 -1.30204683e+00]
#  [-7.80346899e-01 -2.97476883e-01  1.44387076e+00]
#  [ 1.29790551e+00  2.83810250e+00  5.83533127e-01]
#  [ 2.90799418e+00  1.47637344e+00  1.15547049e+00]
#  [ 1.88807626e+00  2.11433170e-01 -2.10753820e+00]
#  [-2.42380535e+00 -7.96625471e-01  1.26598085e+00]
#  [-1.06292388e+00  5.38746516e-01 -9.34827253e-01]
#  [ 4.89130082e+00 -3.39504498e-01 -1.00729850e+00]
# ...

# %%
lr_method = LR_method(dataHQ)
lr_method.lr_standardscaler()

lr_method.logisticRegression()
lr_method.lr_prediction()
#lr_method.func()
# Out:
# C:\Users\si\Anaconda3\envs\tensorflow-cpu\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# (0.9696969696969697,
#  array([7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#         7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#         7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7],
#        dtype=int64))

# %%
pca_method = PCA_method(dataHQ)
pca_method.standardscaler()
length=pca_method.length(dataHQ)
pca_method.pca_learning(dim= length)
pca_method.ev_ratio()
pca_method.dimension
# Out:
# X_train:(151, 11)
# y_train:(151,)
# pca_MEAN:[ 0.02025325  0.022436   -0.02427767  0.00719716 -0.11228698 -0.00597757
#  -0.0261459   0.02366667  0.00218808  0.03457177 -0.00105574]
# pca_X:[[ 3.81047034  2.08443432 -0.82647409 ...  0.16274353 -0.0576989
#   -0.25958246]
#  [ 2.67299814 -0.10293159  1.28796638 ...  1.06476131 -0.54932178
#   -0.14823296]
#  [-4.11627806 -0.80853226 -0.12130996 ... -0.53727609  0.12544369
#    0.06717864]
#  ...
#  [ 0.00619049 -2.04517825  2.98236401 ...  0.52962816 -0.39573019
#   -0.11251407]
#  [ 0.25587303 -0.62434754 -1.27033083 ...  0.15230381 -0.08595923
#    0.19803313]
#  [ 3.81047034  2.08443432 -0.82647409 ...  0.16274353 -0.0576989
#   -0.25958246]]
# 12

# %%
pca_method.plot_ev()

# %%
pca_method.plot_variance_ratio()
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol'],
#       dtype='object')

# %%
#plot pca_X
pca_method.plot_3D()

# %%
#preprocessing = Preprocessing()
func_library_class.Preprocessing()
preprocessing = func_library_class.Preprocessing()
preprocessing.data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
import matplotlib.pyplot as plt

from sklearn.decomposition import PCA
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from pathlib import Path

from C42Winequality import func_library_c
from C42Winequality import func_library_class

if __name__ == "__main__":
    #preprocessing = Preprocessing()
    path = Path(r'D:/datasets/data1')
    func_library_c.preprocessing(path,2)
    data=func_library_c.preprocessing(path,2)
    
    func_library_class.Preprocessing()
    preprocessing = func_library_class.Preprocessing()
    preprocessing.data
    #preprocessingclass = Preprocessing()
    #preprocessingclass.data
# Out:
# lists: <generator object Path.glob at 0x0000026B767E5938>
# D:\datasets\data1\winequality-red.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# lists: <generator object Path.glob at 0x0000026B767E5990>
# D:\datasets\data1\winequality-red.csv
# <class 'pandas.core.frame.DataFrame'>
# ...
