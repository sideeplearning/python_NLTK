# %%
import pandas as pd
import numpy as np
import nltk
from os import path
import re
import libs as ft
from sklearn.metrics.pairwise import cosine_similarity
#from pyfasttext import FastText
#from gensim.models.wrappers import FastText
import fasttext as ft


import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Si\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Si\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.decomposition import PCA
from matplotlib import pyplot as plt

from mpl_toolkits.mplot3d import Axes3D
from pathlib import Path

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from pathlib import Path
from sklearn.metrics import (roc_curve, auc, accuracy_score)
from sklearn.preprocessing import StandardScaler

import nltk
from nltk.tokenize.punkt import PunktSentenceTokenizer, PunktParameters
from nltk.tokenize.punkt import PunktSentenceTokenizer, PunktParameters

# %%
def cleansing(x, drop_tag, tag_pos, lemmatizer):
    """
    いらない品詞を除外し，レンマ化して返す．apply関数内で使用，

    Args:
        x (Series): apply関数で呼び出されるSeries
        drop_tag (list): いらない品詞リスト(nltk)
        tag_pos (dict): key -> tag, value -> pos. レンマ化の精度向上に使用．
        lemmatizer (nltk.stem.WordNetLemmatizer): lemmatizer

    Returns:
        (str): output sentence
    """
    words = [word for word in x['headline_text'].split(' ') if word != '']  # 空文字入るとエラーになる
    tags = nltk.pos_tag(words)  # 品詞を取得
    try:
        words = [(word, tag_pos[tag]) for word, tag in tags if tag not in drop_tag]  # いらない品詞を除外
    except KeyError:
        print('words:', len(words), words)
    
    #escape termination from undentified words and output the potential point
    words_escaped_list = []
    try:
        for word, pos in words:
            print('word, pos:', word, pos)
            words = [lemmatizer.lemmatize(word, pos=pos)]
    except ValueError:
        print('lemmatization value error escaped!')
        print('words:', len(words), words)
        words_escaped_list.append(words)
    
    #words = [lemmatizer.lemmatize(word, pos=pos) for word, pos in words]
    sentence = ' '.join(words)  # 連結
    return sentence

# %%
def preprocess(data):
    """
    前処理の関数．

    Args:
        data (DataFrame): input dataset

    Retruns:
        (DataFrame): output dataset
    """
    # まずは，いらない品詞を落とし，レンマ化する．
    # その後，階層クラスタリングのときに使う用のcsvファイルとモデル学習用のtxtファイルを出力する．
    lemmatizer = nltk.stem.WordNetLemmatizer()
    # いらない品詞
    drop_tag = ['$', 'CC', 'CD', 'DT', 'IN', 'MD', 'POS', 'PRP', 'PRP$', 'RP', 'TO' , 'WP', 'WRB','WDT','PDT','EX','WP$','In']
    # 品詞とpos(lemma用)の変換辞書
    tag_pos = {'FW': 'n', 'JJ': 'a', 'JJR': 'a', 'JJS': 'a', 'NN': 'n', 'NNP': 'n', 'NNS': 'n', 'RB': 'r', 'RBR': 'r', 'VB': 'v',
               'VBD': 'v', 'VBG': 'v', 'VBN': 'v', 'VBP': 'v', 'VBZ': 'v', 'RBS': 'r',}

    data = data.assign(preprocessed=data.apply(func=cleansing, axis=1, args=(drop_tag, tag_pos, lemmatizer)))

    print('after drop and lemmatization')
    print(data.head())
    data.to_csv('data.csv', sep='\t', index=False)
    #data['preprocessed'].to_csv('text.txt', index=False)
    data.to_csv('text.txt', index=False)
    return data

# %%
def get_word_vector(data_name='text.txt', model_name='./pretrained_model/model.bin'):
    """
    fasttextベースで分散表現を取得する関数．これも見てわかると思うので引数は省略．

    Returns:
        (list of list): 単語リストのリスト．[['word_0_0', 'word_0_1'], ['word_1_0', 'word_1_1', 'word_1_2'], ...]みたいな
        (array): 分散表現 次元=(文章数×分散表現の次元数)
    """
    sentences = []
    with open(data_name, mode='r',encoding="utf-8") as f:
        for line in f.readlines():
            line = re.sub('\n', '', line)
            sentences.append(line.split(' '))

    # modelが12GBくらいメモリを食うので終わったら開放する．
    vec_name =  'sentences_vc.npy'
    #if not path.exists(vec_name):
        #model = FastText.load_fasttext_format(model_name)
    model = ft.load_model(model_name)
    dim = model.get_dimension()
    sentences_vec = np.zeros((dim,))

    for words in sentences:
        vec = np.zeros((dim,))
        for word in words:
            if model.get_word_id(word) == -1:
                print('this word does not exists in corpus: %s at %s' % (word, words))
            vec = np.vstack((vec, model.get_word_vector(word)))
        vec = vec[1:, :].mean(axis=0)
        sentences_vec = np.vstack((sentences_vec, vec))
    sentences_vec = sentences_vec[1:, :]
    del model

    np.save(vec_name, sentences_vec)
    #else:
        #sentences_vec = np.load(vec_name)
    return sentences, sentences_vec

# %%
import re
from contextlib import redirect_stdout
from io import StringIO

example = 'Mary had a little lamb, Jack went up the hill, Jill followed suit, i woke up suddenly, it was a really bad dream...'

def token_to_sentence(str):
    f = StringIO()
    with redirect_stdout(f):
        regex_of_sentence = re.findall('([\w\s]{0,})[^\w\s]', str)
        regex_of_sentence = [x for x in regex_of_sentence if x is not '']
        for i in regex_of_sentence:
            print(i)
        first_step_to_sentence = (f.getvalue()).split('\n')
    g = StringIO()
    with redirect_stdout(g):
        for i in first_step_to_sentence:
            try:
                regex_to_clear_sentence = re.search('\s([\w\s]{0,})', i)
                print(regex_to_clear_sentence.group(1))
            except:
                print(i)
        sentence = (g.getvalue()).split('\n')
    return sentence

def token_to_words(str):
    f = StringIO()
    with redirect_stdout(f):
        for i in str:
            regex_of_word = re.findall('([\w]{0,})', i)
            regex_of_word = [x for x in regex_of_word if x is not '']
            for word in regex_of_word:
                print(regex_of_word)
        words = (f.getvalue()).split('\n')

# %%
#homePC
#path_0 = Path(r'C:\Users\SI\Python_ML\python_NLTK\NLTK_')
#officePC
path_0 = Path(r'C:\Users\Si\Desktop\python_all\python_NLTK\NLTK_')


author = ['Poe','Twain']
type_ = ['letter', 'story']
test = ['test']

choice = [0,1]

index_i = 0
index_j = 1
path_file = str(path_0) + str('/') + str(author[choice[index_i]]) + str('-') + str(type_[choice[index_j]])
#path = str(path_0) + str('/') + str(test[0])
print(path_file)
# Out:
# C:\Users\Si\Desktop\python_all\python_NLTK\NLTK_/Poe-story

# %%
path_file = Path(path_file)
path_file
path_file.glob('*.txt')
list(path_file.glob('*.txt'))
print('lists:', path_file.glob('*.txt'))
#list path
path_list = list(path_file.glob('*.txt'))
path_list
# Out:
# lists: <generator object Path.glob at 0x000001C704456CC8>
# [WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-001.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-002.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-003.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-004.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-005.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-006.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-007.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-008.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-009.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-010.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-011.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-012.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-013.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-014.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-015.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-016.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-017.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-018.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-019.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-020.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-021.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-022.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-023.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-024.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-025.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-026.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-027.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-028.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-029.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-030.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-031.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-032.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-033.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-034.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-035.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-036.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-037.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-038.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-039.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-040.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-041.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-042.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-043.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-044.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-045.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-046.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-047.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-048.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-049.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-050.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-051.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-052.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-053.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-054.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-055.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-056.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-057.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-058.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-059.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-060.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-061.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-062.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-063.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-064.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-065.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-066.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-067.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-068.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-069.txt')]

# %%
data = pd.read_table(path_list[0], encoding="utf-8")
data
# Out:
#                               THE SWISS BELL-RINGERS
# 0  One of the regular allies of the Mirror, a man...
# 1  We have argued the point with him till we are ...
# 2  While these documents are coming, we publish t...
# 3  The readers of the Mirror scarce need be told,...
# 4  The writer alludes to them now only to say, th...
# 5  For this reason, too, they arrange so carefull...
# 6  Their very number shows that they were contriv...

# %%
data_list = data[data.columns[0]].values.tolist()
len(data_list),data_list
# Out:
# (7,
#  ['One of the regular allies of the Mirror, a man of a very humorous critical vein, has taken it into his head to prove the Swiss Bell-ringers to be an automaton. ',
#   'We have argued the point with him till we are tired, and have at last sent to beg a copy of their board-bill with affidavits that their stomachs are not wooden and do kindly entertain rolls and sausages.',
#   "While these documents are coming, we publish the skeleton of our friend's hypothesis: The Swiss Bell-ringers. ",
#   'The readers of the Mirror scarce need be told,  as most of them have seen and heard for themselves,  that the Swiss Bell-ringers enter, to the number of seven, white-plumed and fancifully costumed, and each armed with four or five hand-bells of various sizes, which they deposit on a cushioned table before them, retaining one in each hand, which they are continually changing for others in their armory, putting down and taking up with the rapidity of jugglers, and all the while ringing the changes upon them with a delicate harmony and precision, which are as perfect in a symphony of Haydn as in Miss Lucy Long. ',
#   "The writer alludes to them now only to say, that they may be heard again to-night, and to correct the erroneous but common idea that these Bell-ringers are real living beings. The writer is firmly convinced that they are ingenious pieces of mechanism, contrived on the principle of Maelzel's Automaton Trumpeter and Piano-forte player (exhibited here some years ago), but made so much more perfect and effective by the application to them of the same power which operates in the Electro-Magnetic Telegraph,but which should here be called Electro-tintinnabulic. A powerful electric battery under the stage communicates by a hidden wire with each of them, and its shocks are regulated and directed by the skilful musician and mechanician who secretly man[a]ges the whole affair. This explains the precision with which they all bow at the same instant, as if moved by the same soul (and so they are an electric one), and keep such perfect time and order.",
#   "For this reason, too, they arrange so carefully their surplus bells before them in such exact spots, just as Maelzel's Automaton Chess-player always insisted on the pieces being placed exactly on the centre of the squares, so that his mechanically-moved fingers might not miss them. ",
#   'Their very number shows that they were contrived in imitation of the music of the seven spheres,and any lurking doubt of the truth of our theory will be at once removed by noticing how they electrify their hearers.'])

# %% [raw]
# # divided into short sentences
# sentence = token_to_sentence(data_list[1])
# print(sentence)
#
# df_sentence = pd.DataFrame(sentence)
# df_sentence = df_sentence.rename(columns={0: 'headline_text'})
# df_sentence

# %%
vec_list = []
sentence_list = []
for idx, sentence in enumerate(data_list):
    print(idx, sentence)
    para = sentence

    punkt_params = PunktParameters()
    punkt_params.abbrev_types = set(['Mr', 'Mrs', 'LLC', 'Miss'])
    tokenizer = PunktSentenceTokenizer(punkt_params)
    tokens = tokenizer.tokenize(para)

    for t in tokens:
        print (t, "\n")

    df_sentence = pd.DataFrame(tokens)
    df_sentence = df_sentence.rename(columns={0: 'headline_text'})
    print(idx, df_sentence)
    
    col = pd.DataFrame(df_sentence).columns[0]
    series = pd.DataFrame(df_sentence)['headline_text']
    print(col, series, type(series), series.shape)
    
    df_sentence = preprocess(pd.DataFrame(series))
    sentences, vec = get_word_vector()

    if len(sentences) == 0 or len(vec)==0:
        continue
    elif (len(sentences) == 1 and sentences[0][0] == 'headline_text,preprocessed'):
        continue
    elif (len(sentences) > 1 and sentences[0][0] == 'headline_text,preprocessed'):
        for j in range(vec.shape[0]):
            if j == 0:
                continue
            else:
                sentence_list.append(sentences[j])
                vec_list.append(vec[j])
    else:
        for j in range(vec.shape[0]):
            sentence_list.append(sentences[j])
            vec_list.append(vec[j])
        
    #print(vec.shape, sentences[1], vec_list[1])
    print('idx:',idx, '\n',vec.shape, sentences)
    #sentence_list.append(sentences[1])
    #vec_list.append(vec[1])
# Out:
# 0 One of the regular allies of the Mirror, a man of a very humorous critical vein, has taken it into his head to prove the Swiss Bell-ringers to be an automaton.
# One of the regular allies of the Mirror, a man of a very humorous critical vein, has taken it into his head to prove the Swiss Bell-ringers to be an automaton.
#
# 0                                        headline_text
# 0  One of the regular allies of the Mirror, a man...
# headline_text 0    One of the regular allies of the Mirror, a man...
# Name: headline_text, dtype: object <class 'pandas.core.series.Series'> (1,)
# word, pos: regular a
# word, pos: allies n
# word, pos: Mirror, n
# word, pos: man n
# word, pos: very r
# word, pos: humorous a
# word, pos: critical a
# word, pos: vein, n
# word, pos: has v
# word, pos: taken v
# word, pos: head n
# word, pos: prove v
# word, pos: Swiss a
# word, pos: Bell-ringers n
# word, pos: be v
# word, pos: automaton. n
# after drop and lemmatization
#                                        headline_text preprocessed
# 0  One of the regular allies of the Mirror, a man...   automaton.
# this word does not exists in corpus: headline_text,preprocessed at ['headline_text,preprocessed']
# this word does not exists in corpus: "One at ['"One', 'of', 'the', 'regular', 'allies', 'of', 'the', 'Mirror,', 'a', 'man', 'of', 'a', 'very', 'humorous', 'critical', 'vein,', 'has', 'taken', 'it', 'into', 'his', 'head', 'to', 'prove', 'the', 'Swiss', 'Bell-ringers', 'to', 'be', 'an', 'automaton.",automaton.']
# this word does not exists in corpus: Mirror, at ['"One', 'of', 'the', 'regular', 'allies', 'of', 'the', 'Mirror,', 'a', 'man', 'of', 'a', 'very', 'humorous', 'critical', 'vein,', 'has', 'taken', 'it', 'into', 'his', 'head', 'to', 'prove', 'the', 'Swiss', 'Bell-ringers', 'to', 'be', 'an', 'automaton.",automaton.']
# this word does not exists in corpus: Swiss at ['"One', 'of', 'the', 'regular', 'allies', 'of', 'the', 'Mirror,', 'a', 'man', 'of', 'a', 'very', 'humorous', 'critical', 'vein,', 'has', 'taken', 'it', 'into', 'his', 'head', 'to', 'prove', 'the', 'Swiss', 'Bell-ringers', 'to', 'be', 'an', 'automaton.",automaton.']
# this word does not exists in corpus: Bell-ringers at ['"One', 'of', 'the', 'regular', 'allies', 'of', 'the', 'Mirror,', 'a', 'man', 'of', 'a', 'very', 'humorous', 'critical', 'vein,', 'has', 'taken', 'it', 'into', 'his', 'head', 'to', 'prove', 'the', 'Swiss', 'Bell-ringers', 'to', 'be', 'an', 'automaton.",automaton.']
# this word does not exists in corpus: automaton.",automaton. at ['"One', 'of', 'the', 'regular', 'allies', 'of', 'the', 'Mirror,', 'a', 'man', 'of', 'a', 'very', 'humorous', 'critical', 'vein,', 'has', 'taken', 'it', 'into', 'his', 'head', 'to', 'prove', 'the', 'Swiss', 'Bell-ringers', 'to', 'be', 'an', 'automaton.",automaton.']
# idx: 0
#  (2, 300) [['headline_text,preprocessed'], ['"One', 'of', 'the', 'regular', 'allies', 'of', 'the', 'Mirror,', 'a', 'man', 'of', 'a', 'very', 'humorous', 'critical', 'vein,', 'has', 'taken', 'it', 'into', 'his', 'head', 'to', 'prove', 'the', 'Swiss', 'Bell-ringers', 'to', 'be', 'an', 'automaton.",automaton.']]
# 1 We have argued the point with him till we are tired, and have at last sent to beg a copy of their board-bill with affidavits that their stomachs are not wooden and do kindly entertain rolls and sausages.
# We have argued the point with him till we are tired, and have at last sent to beg a copy of their board-bill with affidavits that their stomachs are not wooden and do kindly entertain rolls and sausages.
#
# 1                                        headline_text
# 0  We have argued the point with him till we are ...
# headline_text 0    We have argued the point with him till we are ...
# Name: headline_text, dtype: object <class 'pandas.core.series.Series'> (1,)
# word, pos: have v
# word, pos: argued v
# word, pos: point n
# word, pos: are v
# word, pos: tired, a
# word, pos: have v
# word, pos: last a
# word, pos: sent n
# word, pos: beg v
# word, pos: copy n
# word, pos: board-bill n
# word, pos: affidavits n
# word, pos: stomachs n
# word, pos: are v
# word, pos: not r
# word, pos: wooden a
# word, pos: do v
# word, pos: kindly r
# word, pos: entertain v
# word, pos: rolls n
# word, pos: sausages. n
# after drop and lemmatization
#                                        headline_text preprocessed
# 0  We have argued the point with him till we are ...    sausages.
# this word does not exists in corpus: headline_text,preprocessed at ['headline_text,preprocessed']
# this word does not exists in corpus: "We at ['"We', 'have', 'argued', 'the', 'point', 'with', 'him', 'till', 'we', 'are', 'tired,', 'and', 'have', 'at', 'last', 'sent', 'to', 'beg', 'a', 'copy', 'of', 'their', 'board-bill', 'with', 'affidavits', 'that', 'their', 'stomachs', 'are', 'not', 'wooden', 'and', 'do', 'kindly', 'entertain', 'rolls', 'and', 'sausages.",sausages.']
# this word does not exists in corpus: tired, at ['"We', 'have', 'argued', 'the', 'point', 'with', 'him', 'till', 'we', 'are', 'tired,', 'and', 'have', 'at', 'last', 'sent', 'to', 'beg', 'a', 'copy', 'of', 'their', 'board-bill', 'with', 'affidavits', 'that', 'their', 'stomachs', 'are', 'not', 'wooden', 'and', 'do', 'kindly', 'entertain', 'rolls', 'and', 'sausages.",sausages.']
# this word does not exists in corpus: board-bill at ['"We', 'have', 'argued', 'the', 'point', 'with', 'him', 'till', 'we', 'are', 'tired,', 'and', 'have', 'at', 'last', 'sent', 'to', 'beg', 'a', 'copy', 'of', 'their', 'board-bill', 'with', 'affidavits', 'that', 'their', 'stomachs', 'are', 'not', 'wooden', 'and', 'do', 'kindly', 'entertain', 'rolls', 'and', 'sausages.",sausages.']
# this word does not exists in corpus: sausages.",sausages. at ['"We', 'have', 'argued', 'the', 'point', 'with', 'him', 'till', 'we', 'are', 'tired,', 'and', 'have', 'at', 'last', 'sent', 'to', 'beg', 'a', 'copy', 'of', 'their', 'board-bill', 'with', 'affidavits', 'that', 'their', 'stomachs', 'are', 'not', 'wooden', 'and', 'do', 'kindly', 'entertain', 'rolls', 'and', 'sausages.",sausages.']
# idx: 1
#  (2, 300) [['headline_text,preprocessed'], ['"We', 'have', 'argued', 'the', 'point', 'with', 'him', 'till', 'we', 'are', 'tired,', 'and', 'have', 'at', 'last', 'sent', 'to', 'beg', 'a', 'copy', 'of', 'their', 'board-bill', 'with', 'affidavits', 'that', 'their', 'stomachs', 'are', 'not', 'wooden', 'and', 'do', 'kindly', 'entertain', 'rolls', 'and', 'sausages.",sausages.']]
# 2 While these documents are coming, we publish the skeleton of our friend's hypothesis: The Swiss Bell-ringers.
# While these documents are coming, we publish the skeleton of our friend's hypothesis: The Swiss Bell-ringers.
#
# 2                                        headline_text
# 0  While these documents are coming, we publish t...
# headline_text 0    While these documents are coming, we publish t...
# Name: headline_text, dtype: object <class 'pandas.core.series.Series'> (1,)
# word, pos: documents n
# word, pos: are v
# word, pos: coming, a
# word, pos: publish v
# word, pos: skeleton n
# word, pos: friend's n
# word, pos: hypothesis: v
# word, pos: Swiss a
# word, pos: Bell-ringers. n
# after drop and lemmatization
#                                        headline_text   preprocessed
# 0  While these documents are coming, we publish t...  Bell-ringers.
# this word does not exists in corpus: headline_text,preprocessed at ['headline_text,preprocessed']
# this word does not exists in corpus: "While at ['"While', 'these', 'documents', 'are', 'coming,', 'we', 'publish', 'the', 'skeleton', 'of', 'our', "friend's", 'hypothesis:', 'The', 'Swiss', 'Bell-ringers.",Bell-ringers.']
# this word does not exists in corpus: friend's at ['"While', 'these', 'documents', 'are', 'coming,', 'we', 'publish', 'the', 'skeleton', 'of', 'our', "friend's", 'hypothesis:', 'The', 'Swiss', 'Bell-ringers.",Bell-ringers.']
# this word does not exists in corpus: hypothesis: at ['"While', 'these', 'documents', 'are', 'coming,', 'we', 'publish', 'the', 'skeleton', 'of', 'our', "friend's", 'hypothesis:', 'The', 'Swiss', 'Bell-ringers.",Bell-ringers.']
# this word does not exists in corpus: The at ['"While', 'these', 'documents', 'are', 'coming,', 'we', 'publish', 'the', 'skeleton', 'of', 'our', "friend's", 'hypothesis:', 'The', 'Swiss', 'Bell-ringers.",Bell-ringers.']
# this word does not exists in corpus: Swiss at ['"While', 'these', 'documents', 'are', 'coming,', 'we', 'publish', 'the', 'skeleton', 'of', 'our', "friend's", 'hypothesis:', 'The', 'Swiss', 'Bell-ringers.",Bell-ringers.']
# this word does not exists in corpus: Bell-ringers.",Bell-ringers. at ['"While', 'these', 'documents', 'are', 'coming,', 'we', 'publish', 'the', 'skeleton', 'of', 'our', "friend's", 'hypothesis:', 'The', 'Swiss', 'Bell-ringers.",Bell-ringers.']
# idx: 2
#  (2, 300) [['headline_text,preprocessed'], ['"While', 'these', 'documents', 'are', 'coming,', 'we', 'publish', 'the', 'skeleton', 'of', 'our', "friend's", 'hypothesis:', 'The', 'Swiss', 'Bell-ringers.",Bell-ringers.']]
# 3 The readers of the Mirror scarce need be told,  as most of them have seen and heard for themselves,  that the Swiss Bell-ringers enter, to the number of seven, white-plumed and fancifully costumed, and each armed with four or five hand-bells of various sizes, which they deposit on a cushioned table before them, retaining one in each hand, which they are continually changing for others in their armory, putting down and taking up with the rapidity of jugglers, and all the while ringing the changes upon them with a delicate harmony and precision, which are as perfect in a symphony of Haydn as in Miss Lucy Long.
# The readers of the Mirror scarce need be told,  as most of them have seen and heard for themselves,  that the Swiss Bell-ringers enter, to the number of seven, white-plumed and fancifully costumed, and each armed with four or five hand-bells of various sizes, which they deposit on a cushioned table before them, retaining one in each hand, which they are continually changing for others in their armory, putting down and taking up with the rapidity of jugglers, and all the while ringing the changes upon them with a delicate harmony and precision, which are as perfect in a symphony of Haydn as in Miss Lucy Long.
#
# 3                                        headline_text
# 0  The readers of the Mirror scarce need be told,...
# headline_text 0    The readers of the Mirror scarce need be told,...
# Name: headline_text, dtype: object <class 'pandas.core.series.Series'> (1,)
# word, pos: readers n
# word, pos: Mirror n
# word, pos: scarce n
# word, pos: need n
# word, pos: be v
# word, pos: told, v
# word, pos: most a
# word, pos: have v
# word, pos: seen v
# word, pos: heard v
# word, pos: themselves, n
# word, pos: Swiss a
# word, pos: Bell-ringers n
# word, pos: enter, n
# word, pos: number n
# word, pos: seven, a
# word, pos: white-plumed a
# word, pos: fancifully r
# word, pos: costumed, a
# word, pos: armed v
# word, pos: hand-bells n
# word, pos: various a
# word, pos: sizes, n
# word, pos: deposit v
# word, pos: cushioned v
# word, pos: table n
# word, pos: them, n
# word, pos: retaining v
# word, pos: hand, n
# word, pos: are v
# word, pos: continually r
# word, pos: changing v
# word, pos: others n
# word, pos: armory, n
# word, pos: putting v
# word, pos: taking v
# word, pos: rapidity n
# word, pos: jugglers, n
# word, pos: while n
# word, pos: ringing v
# word, pos: changes n
# word, pos: delicate a
# word, pos: harmony n
# word, pos: precision, n
# word, pos: are v
# word, pos: perfect n
# word, pos: symphony n
# word, pos: Haydn n
# word, pos: Miss n
# word, pos: Lucy n
# word, pos: Long. n
# after drop and lemmatization
#                                        headline_text preprocessed
# 0  The readers of the Mirror scarce need be told,...        Long.
# this word does not exists in corpus: headline_text,preprocessed at ['headline_text,preprocessed']
# this word does not exists in corpus: "The at ['"The', 'readers', 'of', 'the', 'Mirror', 'scarce', 'need', 'be', 'told,', '', 'as', 'most', 'of', 'them', 'have', 'seen', 'and', 'heard', 'for', 'themselves,', '', 'that', 'the', 'Swiss', 'Bell-ringers', 'enter,', 'to', 'the', 'number', 'of', 'seven,', 'white-plumed', 'and', 'fancifully', 'costumed,', 'and', 'each', 'armed', 'with', 'four', 'or', 'five', 'hand-bells', 'of', 'various', 'sizes,', 'which', 'they', 'deposit', 'on', 'a', 'cushioned', 'table', 'before', 'them,', 'retaining', 'one', 'in', 'each', 'hand,', 'which', 'they', 'are', 'continually', 'changing', 'for', 'others', 'in', 'their', 'armory,', 'putting', 'down', 'and', 'taking', 'up', 'with', 'the', 'rapidity', 'of', 'jugglers,', 'and', 'all', 'the', 'while', 'ringing', 'the', 'changes', 'upon', 'them', 'with', 'a', 'delicate', 'harmony', 'and', 'precision,', 'which', 'are', 'as', 'perfect', 'in', 'a', 'symphony', 'of', 'Haydn', 'as', 'in', 'Miss', 'Lucy', 'Long.",Long.']
# this word does not exists in corpus: Mirror at ['"The', 'readers', 'of', 'the', 'Mirror', 'scarce', 'need', 'be', 'told,', '', 'as', 'most', 'of', 'them', 'have', 'seen', 'and', 'heard', 'for', 'themselves,', '', 'that', 'the', 'Swiss', 'Bell-ringers', 'enter,', 'to', 'the', 'number', 'of', 'seven,', 'white-plumed', 'and', 'fancifully', 'costumed,', 'and', 'each', 'armed', 'with', 'four', 'or', 'five', 'hand-bells', 'of', 'various', 'sizes,', 'which', 'they', 'deposit', 'on', 'a', 'cushioned', 'table', 'before', 'them,', 'retaining', 'one', 'in', 'each', 'hand,', 'which', 'they', 'are', 'continually', 'changing', 'for', 'others', 'in', 'their', 'armory,', 'putting', 'down', 'and', 'taking', 'up', 'with', 'the', 'rapidity', 'of', 'jugglers,', 'and', 'all', 'the', 'while', 'ringing', 'the', 'changes', 'upon', 'them', 'with', 'a', 'delicate', 'harmony', 'and', 'precision,', 'which', 'are', 'as', 'perfect', 'in', 'a', 'symphony', 'of', 'Haydn', 'as', 'in', 'Miss', 'Lucy', 'Long.",Long.']
# this word does not exists in corpus:  at ['"The', 'readers', 'of', 'the', 'Mirror', 'scarce', 'need', 'be', 'told,', '', 'as', 'most', 'of', 'them', 'have', 'seen', 'and', 'heard', 'for', 'themselves,', '', 'that', 'the', 'Swiss', 'Bell-ringers', 'enter,', 'to', 'the', 'number', 'of', 'seven,', 'white-plumed', 'and', 'fancifully', 'costumed,', 'and', 'each', 'armed', 'with', 'four', 'or', 'five', 'hand-bells', 'of', 'various', 'sizes,', 'which', 'they', 'deposit', 'on', 'a', 'cushioned', 'table', 'before', 'them,', 'retaining', 'one', 'in', 'each', 'hand,', 'which', 'they', 'are', 'continually', 'changing', 'for', 'others', 'in', 'their', 'armory,', 'putting', 'down', 'and', 'taking', 'up', 'with', 'the', 'rapidity', 'of', 'jugglers,', 'and', 'all', 'the', 'while', 'ringing', 'the', 'changes', 'upon', 'them', 'with', 'a', 'delicate', 'harmony', 'and', 'precision,', 'which', 'are', 'as', 'perfect', 'in', 'a', 'symphony', 'of', 'Haydn', 'as', 'in', 'Miss', 'Lucy', 'Long.",Long.']
# this word does not exists in corpus:  at ['"The', 'readers', 'of', 'the', 'Mirror', 'scarce', 'need', 'be', 'told,', '', 'as', 'most', 'of', 'them', 'have', 'seen', 'and', 'heard', 'for', 'themselves,', '', 'that', 'the', 'Swiss', 'Bell-ringers', 'enter,', 'to', 'the', 'number', 'of', 'seven,', 'white-plumed', 'and', 'fancifully', 'costumed,', 'and', 'each', 'armed', 'with', 'four', 'or', 'five', 'hand-bells', 'of', 'various', 'sizes,', 'which', 'they', 'deposit', 'on', 'a', 'cushioned', 'table', 'before', 'them,', 'retaining', 'one', 'in', 'each', 'hand,', 'which', 'they', 'are', 'continually', 'changing', 'for', 'others', 'in', 'their', 'armory,', 'putting', 'down', 'and', 'taking', 'up', 'with', 'the', 'rapidity', 'of', 'jugglers,', 'and', 'all', 'the', 'while', 'ringing', 'the', 'changes', 'upon', 'them', 'with', 'a', 'delicate', 'harmony', 'and', 'precision,', 'which', 'are', 'as', 'perfect', 'in', 'a', 'symphony', 'of', 'Haydn', 'as', 'in', 'Miss', 'Lucy', 'Long.",Long.']
# this word does not exists in corpus: Swiss at ['"The', 'readers', 'of', 'the', 'Mirror', 'scarce', 'need', 'be', 'told,', '', 'as', 'most', 'of', 'them', 'have', 'seen', 'and', 'heard', 'for', 'themselves,', '', 'that', 'the', 'Swiss', 'Bell-ringers', 'enter,', 'to', 'the', 'number', 'of', 'seven,', 'white-plumed', 'and', 'fancifully', 'costumed,', 'and', 'each', 'armed', 'with', 'four', 'or', 'five', 'hand-bells', 'of', 'various', 'sizes,', 'which', 'they', 'deposit', 'on', 'a', 'cushioned', 'table', 'before', 'them,', 'retaining', 'one', 'in', 'each', 'hand,', 'which', 'they', 'are', 'continually', 'changing', 'for', 'others', 'in', 'their', 'armory,', 'putting', 'down', 'and', 'taking', 'up', 'with', 'the', 'rapidity', 'of', 'jugglers,', 'and', 'all', 'the', 'while', 'ringing', 'the', 'changes', 'upon', 'them', 'with', 'a', 'delicate', 'harmony', 'and', 'precision,', 'which', 'are', 'as', 'perfect', 'in', 'a', 'symphony', 'of', 'Haydn', 'as', 'in', 'Miss', 'Lucy', 'Long.",Long.']
# this word does not exists in corpus: Bell-ringers at ['"The', 'readers', 'of', 'the', 'Mirror', 'scarce', 'need', 'be', 'told,', '', 'as', 'most', 'of', 'them', 'have', 'seen', 'and', 'heard', 'for', 'themselves,', '', 'that', 'the', 'Swiss', 'Bell-ringers', 'enter,', 'to', 'the', 'number', 'of', 'seven,', 'white-plumed', 'and', 'fancifully', 'costumed,', 'and', 'each', 'armed', 'with', 'four', 'or', 'five', 'hand-bells', 'of', 'various', 'sizes,', 'which', 'they', 'deposit', 'on', 'a', 'cushioned', 'table', 'before', 'them,', 'retaining', 'one', 'in', 'each', 'hand,', 'which', 'they', 'are', 'continually', 'changing', 'for', 'others', 'in', 'their', 'armory,', 'putting', 'down', 'and', 'taking', 'up', 'with', 'the', 'rapidity', 'of', 'jugglers,', 'and', 'all', 'the', 'while', 'ringing', 'the', 'changes', 'upon', 'them', 'with', 'a', 'delicate', 'harmony', 'and', 'precision,', 'which', 'are', 'as', 'perfect', 'in', 'a', 'symphony', 'of', 'Haydn', 'as', 'in', 'Miss', 'Lucy', 'Long.",Long.']
# this word does not exists in corpus: enter, at ['"The', 'readers', 'of', 'the', 'Mirror', 'scarce', 'need', 'be', 'told,', '', 'as', 'most', 'of', 'them', 'have', 'seen', 'and', 'heard', 'for', 'themselves,', '', 'that', 'the', 'Swiss', 'Bell-ringers', 'enter,', 'to', 'the', 'number', 'of', 'seven,', 'white-plumed', 'and', 'fancifully', 'costumed,', 'and', 'each', 'armed', 'with', 'four', 'or', 'five', 'hand-bells', 'of', 'various', 'sizes,', 'which', 'they', 'deposit', 'on', 'a', 'cushioned', 'table', 'before', 'them,', 'retaining', 'one', 'in', 'each', 'hand,', 'which', 'they', 'are', 'continually', 'changing', 'for', 'others', 'in', 'their', 'armory,', 'putting', 'down', 'and', 'taking', 'up', 'with', 'the', 'rapidity', 'of', 'jugglers,', 'and', 'all', 'the', 'while', 'ringing', 'the', 'changes', 'upon', 'them', 'with', 'a', 'delicate', 'harmony', 'and', 'precision,', 'which', 'are', 'as', 'perfect', 'in', 'a', 'symphony', 'of', 'Haydn', 'as', 'in', 'Miss', 'Lucy', 'Long.",Long.']
# this word does not exists in corpus: white-plumed at ['"The', 'readers', 'of', 'the', 'Mirror', 'scarce', 'need', 'be', 'told,', '', 'as', 'most', 'of', 'them', 'have', 'seen', 'and', 'heard', 'for', 'themselves,', '', 'that', 'the', 'Swiss', 'Bell-ringers', 'enter,', 'to', 'the', 'number', 'of', 'seven,', 'white-plumed', 'and', 'fancifully', 'costumed,', 'and', 'each', 'armed', 'with', 'four', 'or', 'five', 'hand-bells', 'of', 'various', 'sizes,', 'which', 'they', 'deposit', 'on', 'a', 'cushioned', 'table', 'before', 'them,', 'retaining', 'one', 'in', 'each', 'hand,', 'which', 'they', 'are', 'continually', 'changing', 'for', 'others', 'in', 'their', 'armory,', 'putting', 'down', 'and', 'taking', 'up', 'with', 'the', 'rapidity', 'of', 'jugglers,', 'and', 'all', 'the', 'while', 'ringing', 'the', 'changes', 'upon', 'them', 'with', 'a', 'delicate', 'harmony', 'and', 'precision,', 'which', 'are', 'as', 'perfect', 'in', 'a', 'symphony', 'of', 'Haydn', 'as', 'in', 'Miss', 'Lucy', 'Long.",Long.']
# this word does not exists in corpus: costumed, at ['"The', 'readers', 'of', 'the', 'Mirror', 'scarce', 'need', 'be', 'told,', '', 'as', 'most', 'of', 'them', 'have', 'seen', 'and', 'heard', 'for', 'themselves,', '', 'that', 'the', 'Swiss', 'Bell-ringers', 'enter,', 'to', 'the', 'number', 'of', 'seven,', 'white-plumed', 'and', 'fancifully', 'costumed,', 'and', 'each', 'armed', 'with', 'four', 'or', 'five', 'hand-bells', 'of', 'various', 'sizes,', 'which', 'they', 'deposit', 'on', 'a', 'cushioned', 'table', 'before', 'them,', 'retaining', 'one', 'in', 'each', 'hand,', 'which', 'they', 'are', 'continually', 'changing', 'for', 'others', 'in', 'their', 'armory,', 'putting', 'down', 'and', 'taking', 'up', 'with', 'the', 'rapidity', 'of', 'jugglers,', 'and', 'all', 'the', 'while', 'ringing', 'the', 'changes', 'upon', 'them', 'with', 'a', 'delicate', 'harmony', 'and', 'precision,', 'which', 'are', 'as', 'perfect', 'in', 'a', 'symphony', 'of', 'Haydn', 'as', 'in', 'Miss', 'Lucy', 'Long.",Long.']
# this word does not exists in corpus: hand-bells at ['"The', 'readers', 'of', 'the', 'Mirror', 'scarce', 'need', 'be', 'told,', '', 'as', 'most', 'of', 'them', 'have', 'seen', 'and', 'heard', 'for', 'themselves,', '', 'that', 'the', 'Swiss', 'Bell-ringers', 'enter,', 'to', 'the', 'number', 'of', 'seven,', 'white-plumed', 'and', 'fancifully', 'costumed,', 'and', 'each', 'armed', 'with', 'four', 'or', 'five', 'hand-bells', 'of', 'various', 'sizes,', 'which', 'they', 'deposit', 'on', 'a', 'cushioned', 'table', 'before', 'them,', 'retaining', 'one', 'in', 'each', 'hand,', 'which', 'they', 'are', 'continually', 'changing', 'for', 'others', 'in', 'their', 'armory,', 'putting', 'down', 'and', 'taking', 'up', 'with', 'the', 'rapidity', 'of', 'jugglers,', 'and', 'all', 'the', 'while', 'ringing', 'the', 'changes', 'upon', 'them', 'with', 'a', 'delicate', 'harmony', 'and', 'precision,', 'which', 'are', 'as', 'perfect', 'in', 'a', 'symphony', 'of', 'Haydn', 'as', 'in', 'Miss', 'Lucy', 'Long.",Long.']
# this word does not exists in corpus: sizes, at ['"The', 'readers', 'of', 'the', 'Mirror', 'scarce', 'need', 'be', 'told,', '', 'as', 'most', 'of', 'them', 'have', 'seen', 'and', 'heard', 'for', 'themselves,', '', 'that', 'the', 'Swiss', 'Bell-ringers', 'enter,', 'to', 'the', 'number', 'of', 'seven,', 'white-plumed', 'and', 'fancifully', 'costumed,', 'and', 'each', 'armed', 'with', 'four', 'or', 'five', 'hand-bells', 'of', 'various', 'sizes,', 'which', 'they', 'deposit', 'on', 'a', 'cushioned', 'table', 'before', 'them,', 'retaining', 'one', 'in', 'each', 'hand,', 'which', 'they', 'are', 'continually', 'changing', 'for', 'others', 'in', 'their', 'armory,', 'putting', 'down', 'and', 'taking', 'up', 'with', 'the', 'rapidity', 'of', 'jugglers,', 'and', 'all', 'the', 'while', 'ringing', 'the', 'changes', 'upon', 'them', 'with', 'a', 'delicate', 'harmony', 'and', 'precision,', 'which', 'are', 'as', 'perfect', 'in', 'a', 'symphony', 'of', 'Haydn', 'as', 'in', 'Miss', 'Lucy', 'Long.",Long.']
# this word does not exists in corpus: armory, at ['"The', 'readers', 'of', 'the', 'Mirror', 'scarce', 'need', 'be', 'told,', '', 'as', 'most', 'of', 'them', 'have', 'seen', 'and', 'heard', 'for', 'themselves,', '', 'that', 'the', 'Swiss', 'Bell-ringers', 'enter,', 'to', 'the', 'number', 'of', 'seven,', 'white-plumed', 'and', 'fancifully', 'costumed,', 'and', 'each', 'armed', 'with', 'four', 'or', 'five', 'hand-bells', 'of', 'various', 'sizes,', 'which', 'they', 'deposit', 'on', 'a', 'cushioned', 'table', 'before', 'them,', 'retaining', 'one', 'in', 'each', 'hand,', 'which', 'they', 'are', 'continually', 'changing', 'for', 'others', 'in', 'their', 'armory,', 'putting', 'down', 'and', 'taking', 'up', 'with', 'the', 'rapidity', 'of', 'jugglers,', 'and', 'all', 'the', 'while', 'ringing', 'the', 'changes', 'upon', 'them', 'with', 'a', 'delicate', 'harmony', 'and', 'precision,', 'which', 'are', 'as', 'perfect', 'in', 'a', 'symphony', 'of', 'Haydn', 'as', 'in', 'Miss', 'Lucy', 'Long.",Long.']
# this word does not exists in corpus: jugglers, at ['"The', 'readers', 'of', 'the', 'Mirror', 'scarce', 'need', 'be', 'told,', '', 'as', 'most', 'of', 'them', 'have', 'seen', 'and', 'heard', 'for', 'themselves,', '', 'that', 'the', 'Swiss', 'Bell-ringers', 'enter,', 'to', 'the', 'number', 'of', 'seven,', 'white-plumed', 'and', 'fancifully', 'costumed,', 'and', 'each', 'armed', 'with', 'four', 'or', 'five', 'hand-bells', 'of', 'various', 'sizes,', 'which', 'they', 'deposit', 'on', 'a', 'cushioned', 'table', 'before', 'them,', 'retaining', 'one', 'in', 'each', 'hand,', 'which', 'they', 'are', 'continually', 'changing', 'for', 'others', 'in', 'their', 'armory,', 'putting', 'down', 'and', 'taking', 'up', 'with', 'the', 'rapidity', 'of', 'jugglers,', 'and', 'all', 'the', 'while', 'ringing', 'the', 'changes', 'upon', 'them', 'with', 'a', 'delicate', 'harmony', 'and', 'precision,', 'which', 'are', 'as', 'perfect', 'in', 'a', 'symphony', 'of', 'Haydn', 'as', 'in', 'Miss', 'Lucy', 'Long.",Long.']
# this word does not exists in corpus: precision, at ['"The', 'readers', 'of', 'the', 'Mirror', 'scarce', 'need', 'be', 'told,', '', 'as', 'most', 'of', 'them', 'have', 'seen', 'and', 'heard', 'for', 'themselves,', '', 'that', 'the', 'Swiss', 'Bell-ringers', 'enter,', 'to', 'the', 'number', 'of', 'seven,', 'white-plumed', 'and', 'fancifully', 'costumed,', 'and', 'each', 'armed', 'with', 'four', 'or', 'five', 'hand-bells', 'of', 'various', 'sizes,', 'which', 'they', 'deposit', 'on', 'a', 'cushioned', 'table', 'before', 'them,', 'retaining', 'one', 'in', 'each', 'hand,', 'which', 'they', 'are', 'continually', 'changing', 'for', 'others', 'in', 'their', 'armory,', 'putting', 'down', 'and', 'taking', 'up', 'with', 'the', 'rapidity', 'of', 'jugglers,', 'and', 'all', 'the', 'while', 'ringing', 'the', 'changes', 'upon', 'them', 'with', 'a', 'delicate', 'harmony', 'and', 'precision,', 'which', 'are', 'as', 'perfect', 'in', 'a', 'symphony', 'of', 'Haydn', 'as', 'in', 'Miss', 'Lucy', 'Long.",Long.']
# this word does not exists in corpus: Haydn at ['"The', 'readers', 'of', 'the', 'Mirror', 'scarce', 'need', 'be', 'told,', '', 'as', 'most', 'of', 'them', 'have', 'seen', 'and', 'heard', 'for', 'themselves,', '', 'that', 'the', 'Swiss', 'Bell-ringers', 'enter,', 'to', 'the', 'number', 'of', 'seven,', 'white-plumed', 'and', 'fancifully', 'costumed,', 'and', 'each', 'armed', 'with', 'four', 'or', 'five', 'hand-bells', 'of', 'various', 'sizes,', 'which', 'they', 'deposit', 'on', 'a', 'cushioned', 'table', 'before', 'them,', 'retaining', 'one', 'in', 'each', 'hand,', 'which', 'they', 'are', 'continually', 'changing', 'for', 'others', 'in', 'their', 'armory,', 'putting', 'down', 'and', 'taking', 'up', 'with', 'the', 'rapidity', 'of', 'jugglers,', 'and', 'all', 'the', 'while', 'ringing', 'the', 'changes', 'upon', 'them', 'with', 'a', 'delicate', 'harmony', 'and', 'precision,', 'which', 'are', 'as', 'perfect', 'in', 'a', 'symphony', 'of', 'Haydn', 'as', 'in', 'Miss', 'Lucy', 'Long.",Long.']
# this word does not exists in corpus: Miss at ['"The', 'readers', 'of', 'the', 'Mirror', 'scarce', 'need', 'be', 'told,', '', 'as', 'most', 'of', 'them', 'have', 'seen', 'and', 'heard', 'for', 'themselves,', '', 'that', 'the', 'Swiss', 'Bell-ringers', 'enter,', 'to', 'the', 'number', 'of', 'seven,', 'white-plumed', 'and', 'fancifully', 'costumed,', 'and', 'each', 'armed', 'with', 'four', 'or', 'five', 'hand-bells', 'of', 'various', 'sizes,', 'which', 'they', 'deposit', 'on', 'a', 'cushioned', 'table', 'before', 'them,', 'retaining', 'one', 'in', 'each', 'hand,', 'which', 'they', 'are', 'continually', 'changing', 'for', 'others', 'in', 'their', 'armory,', 'putting', 'down', 'and', 'taking', 'up', 'with', 'the', 'rapidity', 'of', 'jugglers,', 'and', 'all', 'the', 'while', 'ringing', 'the', 'changes', 'upon', 'them', 'with', 'a', 'delicate', 'harmony', 'and', 'precision,', 'which', 'are', 'as', 'perfect', 'in', 'a', 'symphony', 'of', 'Haydn', 'as', 'in', 'Miss', 'Lucy', 'Long.",Long.']
# this word does not exists in corpus: Lucy at ['"The', 'readers', 'of', 'the', 'Mirror', 'scarce', 'need', 'be', 'told,', '', 'as', 'most', 'of', 'them', 'have', 'seen', 'and', 'heard', 'for', 'themselves,', '', 'that', 'the', 'Swiss', 'Bell-ringers', 'enter,', 'to', 'the', 'number', 'of', 'seven,', 'white-plumed', 'and', 'fancifully', 'costumed,', 'and', 'each', 'armed', 'with', 'four', 'or', 'five', 'hand-bells', 'of', 'various', 'sizes,', 'which', 'they', 'deposit', 'on', 'a', 'cushioned', 'table', 'before', 'them,', 'retaining', 'one', 'in', 'each', 'hand,', 'which', 'they', 'are', 'continually', 'changing', 'for', 'others', 'in', 'their', 'armory,', 'putting', 'down', 'and', 'taking', 'up', 'with', 'the', 'rapidity', 'of', 'jugglers,', 'and', 'all', 'the', 'while', 'ringing', 'the', 'changes', 'upon', 'them', 'with', 'a', 'delicate', 'harmony', 'and', 'precision,', 'which', 'are', 'as', 'perfect', 'in', 'a', 'symphony', 'of', 'Haydn', 'as', 'in', 'Miss', 'Lucy', 'Long.",Long.']
# this word does not exists in corpus: Long.",Long. at ['"The', 'readers', 'of', 'the', 'Mirror', 'scarce', 'need', 'be', 'told,', '', 'as', 'most', 'of', 'them', 'have', 'seen', 'and', 'heard', 'for', 'themselves,', '', 'that', 'the', 'Swiss', 'Bell-ringers', 'enter,', 'to', 'the', 'number', 'of', 'seven,', 'white-plumed', 'and', 'fancifully', 'costumed,', 'and', 'each', 'armed', 'with', 'four', 'or', 'five', 'hand-bells', 'of', 'various', 'sizes,', 'which', 'they', 'deposit', 'on', 'a', 'cushioned', 'table', 'before', 'them,', 'retaining', 'one', 'in', 'each', 'hand,', 'which', 'they', 'are', 'continually', 'changing', 'for', 'others', 'in', 'their', 'armory,', 'putting', 'down', 'and', 'taking', 'up', 'with', 'the', 'rapidity', 'of', 'jugglers,', 'and', 'all', 'the', 'while', 'ringing', 'the', 'changes', 'upon', 'them', 'with', 'a', 'delicate', 'harmony', 'and', 'precision,', 'which', 'are', 'as', 'perfect', 'in', 'a', 'symphony', 'of', 'Haydn', 'as', 'in', 'Miss', 'Lucy', 'Long.",Long.']
# idx: 3
#  (2, 300) [['headline_text,preprocessed'], ['"The', 'readers', 'of', 'the', 'Mirror', 'scarce', 'need', 'be', 'told,', '', 'as', 'most', 'of', 'them', 'have', 'seen', 'and', 'heard', 'for', 'themselves,', '', 'that', 'the', 'Swiss', 'Bell-ringers', 'enter,', 'to', 'the', 'number', 'of', 'seven,', 'white-plumed', 'and', 'fancifully', 'costumed,', 'and', 'each', 'armed', 'with', 'four', 'or', 'five', 'hand-bells', 'of', 'various', 'sizes,', 'which', 'they', 'deposit', 'on', 'a', 'cushioned', 'table', 'before', 'them,', 'retaining', 'one', 'in', 'each', 'hand,', 'which', 'they', 'are', 'continually', 'changing', 'for', 'others', 'in', 'their', 'armory,', 'putting', 'down', 'and', 'taking', 'up', 'with', 'the', 'rapidity', 'of', 'jugglers,', 'and', 'all', 'the', 'while', 'ringing', 'the', 'changes', 'upon', 'them', 'with', 'a', 'delicate', 'harmony', 'and', 'precision,', 'which', 'are', 'as', 'perfect', 'in', 'a', 'symphony', 'of', 'Haydn', 'as', 'in', 'Miss', 'Lucy', 'Long.",Long.']]
# 4 The writer alludes to them now only to say, that they may be heard again to-night, and to correct the erroneous but common idea that these Bell-ringers are real living beings. The writer is firmly convinced that they are ingenious pieces of mechanism, contrived on the principle of Maelzel's Automaton Trumpeter and Piano-forte player (exhibited here some years ago), but made so much more perfect and effective by the application to them of the same power which operates in the Electro-Magnetic Telegraph,but which should here be called Electro-tintinnabulic. A powerful electric battery under the stage communicates by a hidden wire with each of them, and its shocks are regulated and directed by the skilful musician and mechanician who secretly man[a]ges the whole affair. This explains the precision with which they all bow at the same instant, as if moved by the same soul (and so they are an electric one), and keep such perfect time and order.
# The writer alludes to them now only to say, that they may be heard again to-night, and to correct the erroneous but common idea that these Bell-ringers are real living beings.
#
# The writer is firmly convinced that they are ingenious pieces of mechanism, contrived on the principle of Maelzel's Automaton Trumpeter and Piano-forte player (exhibited here some years ago), but made so much more perfect and effective by the application to them of the same power which operates in the Electro-Magnetic Telegraph,but which should here be called Electro-tintinnabulic.
#
# A powerful electric battery under the stage communicates by a hidden wire with each of them, and its shocks are regulated and directed by the skilful musician and mechanician who secretly man[a]ges the whole affair.
#
# This explains the precision with which they all bow at the same instant, as if moved by the same soul (and so they are an electric one), and keep such perfect time and order.
#
# 4                                        headline_text
# 0  The writer alludes to them now only to say, th...
# 1  The writer is firmly convinced that they are i...
# 2  A powerful electric battery under the stage co...
# 3  This explains the precision with which they al...
# headline_text 0    The writer alludes to them now only to say, th...
# 1    The writer is firmly convinced that they are i...
# 2    A powerful electric battery under the stage co...
# 3    This explains the precision with which they al...
# Name: headline_text, dtype: object <class 'pandas.core.series.Series'> (4,)
# word, pos: writer n
# word, pos: alludes v
# word, pos: now r
# word, pos: only r
# word, pos: say, v
# word, pos: be v
# word, pos: heard v
# word, pos: again r
# word, pos: to-night, a
# word, pos: correct v
# word, pos: erroneous a
# word, pos: common a
# word, pos: idea n
# word, pos: Bell-ringers n
# word, pos: are v
# word, pos: real a
# word, pos: living n
# word, pos: beings. n
# word, pos: writer n
# word, pos: is v
# word, pos: firmly r
# word, pos: convinced v
# word, pos: are v
# word, pos: ingenious a
# word, pos: pieces n
# word, pos: mechanism, n
# word, pos: contrived v
# word, pos: principle n
# word, pos: Maelzel's n
# word, pos: Automaton n
# word, pos: Trumpeter n
# word, pos: Piano-forte n
# word, pos: player n
# word, pos: (exhibited v
# word, pos: here r
# word, pos: years n
# word, pos: ago), v
# word, pos: made v
# word, pos: so r
# word, pos: much r
# word, pos: more a
# word, pos: perfect a
# word, pos: effective a
# word, pos: application n
# word, pos: same a
# word, pos: power n
# word, pos: operates v
# word, pos: Electro-Magnetic a
# word, pos: Telegraph,but n
# word, pos: here r
# word, pos: be v
# word, pos: called v
# word, pos: Electro-tintinnabulic. n
# word, pos: powerful a
# word, pos: electric a
# word, pos: battery n
# word, pos: stage n
# word, pos: communicates n
# word, pos: hidden a
# word, pos: wire n
# word, pos: them, n
# word, pos: shocks n
# word, pos: are v
# word, pos: regulated v
# word, pos: directed v
# word, pos: skilful a
# word, pos: musician n
# word, pos: mechanician n
# word, pos: secretly r
# word, pos: man[a]ges v
# word, pos: whole a
# word, pos: affair. n
# word, pos: explains v
# word, pos: precision n
# word, pos: bow v
# word, pos: same a
# word, pos: instant, n
# word, pos: moved v
# word, pos: same a
# word, pos: soul n
# word, pos: (and v
# word, pos: are v
# word, pos: electric a
# word, pos: one), n
# word, pos: keep v
# word, pos: such a
# word, pos: perfect a
# word, pos: time n
# word, pos: order. n
# after drop and lemmatization
#                                        headline_text            preprocessed
# 0  The writer alludes to them now only to say, th...                 beings.
# 1  The writer is firmly convinced that they are i...  Electro-tintinnabulic.
# 2  A powerful electric battery under the stage co...                 affair.
# 3  This explains the precision with which they al...                  order.
# this word does not exists in corpus: headline_text,preprocessed at ['headline_text,preprocessed']
# this word does not exists in corpus: "The at ['"The', 'writer', 'alludes', 'to', 'them', 'now', 'only', 'to', 'say,', 'that', 'they', 'may', 'be', 'heard', 'again', 'to-night,', 'and', 'to', 'correct', 'the', 'erroneous', 'but', 'common', 'idea', 'that', 'these', 'Bell-ringers', 'are', 'real', 'living', 'beings.",beings.']
# this word does not exists in corpus: to-night, at ['"The', 'writer', 'alludes', 'to', 'them', 'now', 'only', 'to', 'say,', 'that', 'they', 'may', 'be', 'heard', 'again', 'to-night,', 'and', 'to', 'correct', 'the', 'erroneous', 'but', 'common', 'idea', 'that', 'these', 'Bell-ringers', 'are', 'real', 'living', 'beings.",beings.']
# this word does not exists in corpus: Bell-ringers at ['"The', 'writer', 'alludes', 'to', 'them', 'now', 'only', 'to', 'say,', 'that', 'they', 'may', 'be', 'heard', 'again', 'to-night,', 'and', 'to', 'correct', 'the', 'erroneous', 'but', 'common', 'idea', 'that', 'these', 'Bell-ringers', 'are', 'real', 'living', 'beings.",beings.']
# this word does not exists in corpus: beings.",beings. at ['"The', 'writer', 'alludes', 'to', 'them', 'now', 'only', 'to', 'say,', 'that', 'they', 'may', 'be', 'heard', 'again', 'to-night,', 'and', 'to', 'correct', 'the', 'erroneous', 'but', 'common', 'idea', 'that', 'these', 'Bell-ringers', 'are', 'real', 'living', 'beings.",beings.']
# this word does not exists in corpus: "The at ['"The', 'writer', 'is', 'firmly', 'convinced', 'that', 'they', 'are', 'ingenious', 'pieces', 'of', 'mechanism,', 'contrived', 'on', 'the', 'principle', 'of', "Maelzel's", 'Automaton', 'Trumpeter', 'and', 'Piano-forte', 'player', '(exhibited', 'here', 'some', 'years', 'ago),', 'but', 'made', 'so', 'much', 'more', 'perfect', 'and', 'effective', 'by', 'the', 'application', 'to', 'them', 'of', 'the', 'same', 'power', 'which', 'operates', 'in', 'the', 'Electro-Magnetic', 'Telegraph,but', 'which', 'should', 'here', 'be', 'called', 'Electro-tintinnabulic.",Electro-tintinnabulic.']
# this word does not exists in corpus: mechanism, at ['"The', 'writer', 'is', 'firmly', 'convinced', 'that', 'they', 'are', 'ingenious', 'pieces', 'of', 'mechanism,', 'contrived', 'on', 'the', 'principle', 'of', "Maelzel's", 'Automaton', 'Trumpeter', 'and', 'Piano-forte', 'player', '(exhibited', 'here', 'some', 'years', 'ago),', 'but', 'made', 'so', 'much', 'more', 'perfect', 'and', 'effective', 'by', 'the', 'application', 'to', 'them', 'of', 'the', 'same', 'power', 'which', 'operates', 'in', 'the', 'Electro-Magnetic', 'Telegraph,but', 'which', 'should', 'here', 'be', 'called', 'Electro-tintinnabulic.",Electro-tintinnabulic.']
# this word does not exists in corpus: Maelzel's at ['"The', 'writer', 'is', 'firmly', 'convinced', 'that', 'they', 'are', 'ingenious', 'pieces', 'of', 'mechanism,', 'contrived', 'on', 'the', 'principle', 'of', "Maelzel's", 'Automaton', 'Trumpeter', 'and', 'Piano-forte', 'player', '(exhibited', 'here', 'some', 'years', 'ago),', 'but', 'made', 'so', 'much', 'more', 'perfect', 'and', 'effective', 'by', 'the', 'application', 'to', 'them', 'of', 'the', 'same', 'power', 'which', 'operates', 'in', 'the', 'Electro-Magnetic', 'Telegraph,but', 'which', 'should', 'here', 'be', 'called', 'Electro-tintinnabulic.",Electro-tintinnabulic.']
# this word does not exists in corpus: Automaton at ['"The', 'writer', 'is', 'firmly', 'convinced', 'that', 'they', 'are', 'ingenious', 'pieces', 'of', 'mechanism,', 'contrived', 'on', 'the', 'principle', 'of', "Maelzel's", 'Automaton', 'Trumpeter', 'and', 'Piano-forte', 'player', '(exhibited', 'here', 'some', 'years', 'ago),', 'but', 'made', 'so', 'much', 'more', 'perfect', 'and', 'effective', 'by', 'the', 'application', 'to', 'them', 'of', 'the', 'same', 'power', 'which', 'operates', 'in', 'the', 'Electro-Magnetic', 'Telegraph,but', 'which', 'should', 'here', 'be', 'called', 'Electro-tintinnabulic.",Electro-tintinnabulic.']
# this word does not exists in corpus: Trumpeter at ['"The', 'writer', 'is', 'firmly', 'convinced', 'that', 'they', 'are', 'ingenious', 'pieces', 'of', 'mechanism,', 'contrived', 'on', 'the', 'principle', 'of', "Maelzel's", 'Automaton', 'Trumpeter', 'and', 'Piano-forte', 'player', '(exhibited', 'here', 'some', 'years', 'ago),', 'but', 'made', 'so', 'much', 'more', 'perfect', 'and', 'effective', 'by', 'the', 'application', 'to', 'them', 'of', 'the', 'same', 'power', 'which', 'operates', 'in', 'the', 'Electro-Magnetic', 'Telegraph,but', 'which', 'should', 'here', 'be', 'called', 'Electro-tintinnabulic.",Electro-tintinnabulic.']
# this word does not exists in corpus: Piano-forte at ['"The', 'writer', 'is', 'firmly', 'convinced', 'that', 'they', 'are', 'ingenious', 'pieces', 'of', 'mechanism,', 'contrived', 'on', 'the', 'principle', 'of', "Maelzel's", 'Automaton', 'Trumpeter', 'and', 'Piano-forte', 'player', '(exhibited', 'here', 'some', 'years', 'ago),', 'but', 'made', 'so', 'much', 'more', 'perfect', 'and', 'effective', 'by', 'the', 'application', 'to', 'them', 'of', 'the', 'same', 'power', 'which', 'operates', 'in', 'the', 'Electro-Magnetic', 'Telegraph,but', 'which', 'should', 'here', 'be', 'called', 'Electro-tintinnabulic.",Electro-tintinnabulic.']
# this word does not exists in corpus: (exhibited at ['"The', 'writer', 'is', 'firmly', 'convinced', 'that', 'they', 'are', 'ingenious', 'pieces', 'of', 'mechanism,', 'contrived', 'on', 'the', 'principle', 'of', "Maelzel's", 'Automaton', 'Trumpeter', 'and', 'Piano-forte', 'player', '(exhibited', 'here', 'some', 'years', 'ago),', 'but', 'made', 'so', 'much', 'more', 'perfect', 'and', 'effective', 'by', 'the', 'application', 'to', 'them', 'of', 'the', 'same', 'power', 'which', 'operates', 'in', 'the', 'Electro-Magnetic', 'Telegraph,but', 'which', 'should', 'here', 'be', 'called', 'Electro-tintinnabulic.",Electro-tintinnabulic.']
# this word does not exists in corpus: ago), at ['"The', 'writer', 'is', 'firmly', 'convinced', 'that', 'they', 'are', 'ingenious', 'pieces', 'of', 'mechanism,', 'contrived', 'on', 'the', 'principle', 'of', "Maelzel's", 'Automaton', 'Trumpeter', 'and', 'Piano-forte', 'player', '(exhibited', 'here', 'some', 'years', 'ago),', 'but', 'made', 'so', 'much', 'more', 'perfect', 'and', 'effective', 'by', 'the', 'application', 'to', 'them', 'of', 'the', 'same', 'power', 'which', 'operates', 'in', 'the', 'Electro-Magnetic', 'Telegraph,but', 'which', 'should', 'here', 'be', 'called', 'Electro-tintinnabulic.",Electro-tintinnabulic.']
# this word does not exists in corpus: Electro-Magnetic at ['"The', 'writer', 'is', 'firmly', 'convinced', 'that', 'they', 'are', 'ingenious', 'pieces', 'of', 'mechanism,', 'contrived', 'on', 'the', 'principle', 'of', "Maelzel's", 'Automaton', 'Trumpeter', 'and', 'Piano-forte', 'player', '(exhibited', 'here', 'some', 'years', 'ago),', 'but', 'made', 'so', 'much', 'more', 'perfect', 'and', 'effective', 'by', 'the', 'application', 'to', 'them', 'of', 'the', 'same', 'power', 'which', 'operates', 'in', 'the', 'Electro-Magnetic', 'Telegraph,but', 'which', 'should', 'here', 'be', 'called', 'Electro-tintinnabulic.",Electro-tintinnabulic.']
# this word does not exists in corpus: Telegraph,but at ['"The', 'writer', 'is', 'firmly', 'convinced', 'that', 'they', 'are', 'ingenious', 'pieces', 'of', 'mechanism,', 'contrived', 'on', 'the', 'principle', 'of', "Maelzel's", 'Automaton', 'Trumpeter', 'and', 'Piano-forte', 'player', '(exhibited', 'here', 'some', 'years', 'ago),', 'but', 'made', 'so', 'much', 'more', 'perfect', 'and', 'effective', 'by', 'the', 'application', 'to', 'them', 'of', 'the', 'same', 'power', 'which', 'operates', 'in', 'the', 'Electro-Magnetic', 'Telegraph,but', 'which', 'should', 'here', 'be', 'called', 'Electro-tintinnabulic.",Electro-tintinnabulic.']
# this word does not exists in corpus: Electro-tintinnabulic.",Electro-tintinnabulic. at ['"The', 'writer', 'is', 'firmly', 'convinced', 'that', 'they', 'are', 'ingenious', 'pieces', 'of', 'mechanism,', 'contrived', 'on', 'the', 'principle', 'of', "Maelzel's", 'Automaton', 'Trumpeter', 'and', 'Piano-forte', 'player', '(exhibited', 'here', 'some', 'years', 'ago),', 'but', 'made', 'so', 'much', 'more', 'perfect', 'and', 'effective', 'by', 'the', 'application', 'to', 'them', 'of', 'the', 'same', 'power', 'which', 'operates', 'in', 'the', 'Electro-Magnetic', 'Telegraph,but', 'which', 'should', 'here', 'be', 'called', 'Electro-tintinnabulic.",Electro-tintinnabulic.']
# this word does not exists in corpus: "A at ['"A', 'powerful', 'electric', 'battery', 'under', 'the', 'stage', 'communicates', 'by', 'a', 'hidden', 'wire', 'with', 'each', 'of', 'them,', 'and', 'its', 'shocks', 'are', 'regulated', 'and', 'directed', 'by', 'the', 'skilful', 'musician', 'and', 'mechanician', 'who', 'secretly', 'man[a]ges', 'the', 'whole', 'affair.",affair.']
# this word does not exists in corpus: man[a]ges at ['"A', 'powerful', 'electric', 'battery', 'under', 'the', 'stage', 'communicates', 'by', 'a', 'hidden', 'wire', 'with', 'each', 'of', 'them,', 'and', 'its', 'shocks', 'are', 'regulated', 'and', 'directed', 'by', 'the', 'skilful', 'musician', 'and', 'mechanician', 'who', 'secretly', 'man[a]ges', 'the', 'whole', 'affair.",affair.']
# this word does not exists in corpus: affair.",affair. at ['"A', 'powerful', 'electric', 'battery', 'under', 'the', 'stage', 'communicates', 'by', 'a', 'hidden', 'wire', 'with', 'each', 'of', 'them,', 'and', 'its', 'shocks', 'are', 'regulated', 'and', 'directed', 'by', 'the', 'skilful', 'musician', 'and', 'mechanician', 'who', 'secretly', 'man[a]ges', 'the', 'whole', 'affair.",affair.']
# this word does not exists in corpus: "This at ['"This', 'explains', 'the', 'precision', 'with', 'which', 'they', 'all', 'bow', 'at', 'the', 'same', 'instant,', 'as', 'if', 'moved', 'by', 'the', 'same', 'soul', '(and', 'so', 'they', 'are', 'an', 'electric', 'one),', 'and', 'keep', 'such', 'perfect', 'time', 'and', 'order.",order.']
# this word does not exists in corpus: instant, at ['"This', 'explains', 'the', 'precision', 'with', 'which', 'they', 'all', 'bow', 'at', 'the', 'same', 'instant,', 'as', 'if', 'moved', 'by', 'the', 'same', 'soul', '(and', 'so', 'they', 'are', 'an', 'electric', 'one),', 'and', 'keep', 'such', 'perfect', 'time', 'and', 'order.",order.']
# this word does not exists in corpus: (and at ['"This', 'explains', 'the', 'precision', 'with', 'which', 'they', 'all', 'bow', 'at', 'the', 'same', 'instant,', 'as', 'if', 'moved', 'by', 'the', 'same', 'soul', '(and', 'so', 'they', 'are', 'an', 'electric', 'one),', 'and', 'keep', 'such', 'perfect', 'time', 'and', 'order.",order.']
# this word does not exists in corpus: one), at ['"This', 'explains', 'the', 'precision', 'with', 'which', 'they', 'all', 'bow', 'at', 'the', 'same', 'instant,', 'as', 'if', 'moved', 'by', 'the', 'same', 'soul', '(and', 'so', 'they', 'are', 'an', 'electric', 'one),', 'and', 'keep', 'such', 'perfect', 'time', 'and', 'order.",order.']
# this word does not exists in corpus: order.",order. at ['"This', 'explains', 'the', 'precision', 'with', 'which', 'they', 'all', 'bow', 'at', 'the', 'same', 'instant,', 'as', 'if', 'moved', 'by', 'the', 'same', 'soul', '(and', 'so', 'they', 'are', 'an', 'electric', 'one),', 'and', 'keep', 'such', 'perfect', 'time', 'and', 'order.",order.']
# idx: 4
#  (5, 300) [['headline_text,preprocessed'], ['"The', 'writer', 'alludes', 'to', 'them', 'now', 'only', 'to', 'say,', 'that', 'they', 'may', 'be', 'heard', 'again', 'to-night,', 'and', 'to', 'correct', 'the', 'erroneous', 'but', 'common', 'idea', 'that', 'these', 'Bell-ringers', 'are', 'real', 'living', 'beings.",beings.'], ['"The', 'writer', 'is', 'firmly', 'convinced', 'that', 'they', 'are', 'ingenious', 'pieces', 'of', 'mechanism,', 'contrived', 'on', 'the', 'principle', 'of', "Maelzel's", 'Automaton', 'Trumpeter', 'and', 'Piano-forte', 'player', '(exhibited', 'here', 'some', 'years', 'ago),', 'but', 'made', 'so', 'much', 'more', 'perfect', 'and', 'effective', 'by', 'the', 'application', 'to', 'them', 'of', 'the', 'same', 'power', 'which', 'operates', 'in', 'the', 'Electro-Magnetic', 'Telegraph,but', 'which', 'should', 'here', 'be', 'called', 'Electro-tintinnabulic.",Electro-tintinnabulic.'], ['"A', 'powerful', 'electric', 'battery', 'under', 'the', 'stage', 'communicates', 'by', 'a', 'hidden', 'wire', 'with', 'each', 'of', 'them,', 'and', 'its', 'shocks', 'are', 'regulated', 'and', 'directed', 'by', 'the', 'skilful', 'musician', 'and', 'mechanician', 'who', 'secretly', 'man[a]ges', 'the', 'whole', 'affair.",affair.'], ['"This', 'explains', 'the', 'precision', 'with', 'which', 'they', 'all', 'bow', 'at', 'the', 'same', 'instant,', 'as', 'if', 'moved', 'by', 'the', 'same', 'soul', '(and', 'so', 'they', 'are', 'an', 'electric', 'one),', 'and', 'keep', 'such', 'perfect', 'time', 'and', 'order.",order.']]
# 5 For this reason, too, they arrange so carefully their surplus bells before them in such exact spots, just as Maelzel's Automaton Chess-player always insisted on the pieces being placed exactly on the centre of the squares, so that his mechanically-moved fingers might not miss them.
# For this reason, too, they arrange so carefully their surplus bells before them in such exact spots, just as Maelzel's Automaton Chess-player always insisted on the pieces being placed exactly on the centre of the squares, so that his mechanically-moved fingers might not miss them.
#
# 5                                        headline_text
# 0  For this reason, too, they arrange so carefull...
# headline_text 0    For this reason, too, they arrange so carefull...
# Name: headline_text, dtype: object <class 'pandas.core.series.Series'> (1,)
# word, pos: reason, n
# word, pos: too, n
# word, pos: arrange v
# word, pos: so r
# word, pos: carefully r
# word, pos: surplus n
# word, pos: bells n
# word, pos: such a
# word, pos: exact a
# word, pos: spots, n
# word, pos: just r
# word, pos: Maelzel's n
# word, pos: Automaton n
# word, pos: Chess-player n
# word, pos: always r
# word, pos: insisted v
# word, pos: pieces n
# word, pos: being v
# word, pos: placed v
# word, pos: exactly r
# word, pos: centre n
# word, pos: squares, n
# word, pos: mechanically-moved a
# word, pos: fingers n
# word, pos: not r
# word, pos: miss v
# word, pos: them. n
# after drop and lemmatization
#                                        headline_text preprocessed
# 0  For this reason, too, they arrange so carefull...        them.
# this word does not exists in corpus: headline_text,preprocessed at ['headline_text,preprocessed']
# this word does not exists in corpus: "For at ['"For', 'this', 'reason,', 'too,', 'they', 'arrange', 'so', 'carefully', 'their', 'surplus', 'bells', 'before', 'them', 'in', 'such', 'exact', 'spots,', 'just', 'as', "Maelzel's", 'Automaton', 'Chess-player', 'always', 'insisted', 'on', 'the', 'pieces', 'being', 'placed', 'exactly', 'on', 'the', 'centre', 'of', 'the', 'squares,', 'so', 'that', 'his', 'mechanically-moved', 'fingers', 'might', 'not', 'miss', 'them.",them.']
# this word does not exists in corpus: spots, at ['"For', 'this', 'reason,', 'too,', 'they', 'arrange', 'so', 'carefully', 'their', 'surplus', 'bells', 'before', 'them', 'in', 'such', 'exact', 'spots,', 'just', 'as', "Maelzel's", 'Automaton', 'Chess-player', 'always', 'insisted', 'on', 'the', 'pieces', 'being', 'placed', 'exactly', 'on', 'the', 'centre', 'of', 'the', 'squares,', 'so', 'that', 'his', 'mechanically-moved', 'fingers', 'might', 'not', 'miss', 'them.",them.']
# this word does not exists in corpus: Maelzel's at ['"For', 'this', 'reason,', 'too,', 'they', 'arrange', 'so', 'carefully', 'their', 'surplus', 'bells', 'before', 'them', 'in', 'such', 'exact', 'spots,', 'just', 'as', "Maelzel's", 'Automaton', 'Chess-player', 'always', 'insisted', 'on', 'the', 'pieces', 'being', 'placed', 'exactly', 'on', 'the', 'centre', 'of', 'the', 'squares,', 'so', 'that', 'his', 'mechanically-moved', 'fingers', 'might', 'not', 'miss', 'them.",them.']
# this word does not exists in corpus: Automaton at ['"For', 'this', 'reason,', 'too,', 'they', 'arrange', 'so', 'carefully', 'their', 'surplus', 'bells', 'before', 'them', 'in', 'such', 'exact', 'spots,', 'just', 'as', "Maelzel's", 'Automaton', 'Chess-player', 'always', 'insisted', 'on', 'the', 'pieces', 'being', 'placed', 'exactly', 'on', 'the', 'centre', 'of', 'the', 'squares,', 'so', 'that', 'his', 'mechanically-moved', 'fingers', 'might', 'not', 'miss', 'them.",them.']
# this word does not exists in corpus: Chess-player at ['"For', 'this', 'reason,', 'too,', 'they', 'arrange', 'so', 'carefully', 'their', 'surplus', 'bells', 'before', 'them', 'in', 'such', 'exact', 'spots,', 'just', 'as', "Maelzel's", 'Automaton', 'Chess-player', 'always', 'insisted', 'on', 'the', 'pieces', 'being', 'placed', 'exactly', 'on', 'the', 'centre', 'of', 'the', 'squares,', 'so', 'that', 'his', 'mechanically-moved', 'fingers', 'might', 'not', 'miss', 'them.",them.']
# this word does not exists in corpus: mechanically-moved at ['"For', 'this', 'reason,', 'too,', 'they', 'arrange', 'so', 'carefully', 'their', 'surplus', 'bells', 'before', 'them', 'in', 'such', 'exact', 'spots,', 'just', 'as', "Maelzel's", 'Automaton', 'Chess-player', 'always', 'insisted', 'on', 'the', 'pieces', 'being', 'placed', 'exactly', 'on', 'the', 'centre', 'of', 'the', 'squares,', 'so', 'that', 'his', 'mechanically-moved', 'fingers', 'might', 'not', 'miss', 'them.",them.']
# this word does not exists in corpus: them.",them. at ['"For', 'this', 'reason,', 'too,', 'they', 'arrange', 'so', 'carefully', 'their', 'surplus', 'bells', 'before', 'them', 'in', 'such', 'exact', 'spots,', 'just', 'as', "Maelzel's", 'Automaton', 'Chess-player', 'always', 'insisted', 'on', 'the', 'pieces', 'being', 'placed', 'exactly', 'on', 'the', 'centre', 'of', 'the', 'squares,', 'so', 'that', 'his', 'mechanically-moved', 'fingers', 'might', 'not', 'miss', 'them.",them.']
# idx: 5
#  (2, 300) [['headline_text,preprocessed'], ['"For', 'this', 'reason,', 'too,', 'they', 'arrange', 'so', 'carefully', 'their', 'surplus', 'bells', 'before', 'them', 'in', 'such', 'exact', 'spots,', 'just', 'as', "Maelzel's", 'Automaton', 'Chess-player', 'always', 'insisted', 'on', 'the', 'pieces', 'being', 'placed', 'exactly', 'on', 'the', 'centre', 'of', 'the', 'squares,', 'so', 'that', 'his', 'mechanically-moved', 'fingers', 'might', 'not', 'miss', 'them.",them.']]
# 6 Their very number shows that they were contrived in imitation of the music of the seven spheres,and any lurking doubt of the truth of our theory will be at once removed by noticing how they electrify their hearers.
# Their very number shows that they were contrived in imitation of the music of the seven spheres,and any lurking doubt of the truth of our theory will be at once removed by noticing how they electrify their hearers.
#
# 6                                        headline_text
# 0  Their very number shows that they were contriv...
# headline_text 0    Their very number shows that they were contriv...
# Name: headline_text, dtype: object <class 'pandas.core.series.Series'> (1,)
# word, pos: very n
# word, pos: number n
# word, pos: shows v
# word, pos: were v
# word, pos: contrived v
# word, pos: imitation n
# word, pos: music n
# word, pos: spheres,and v
# word, pos: lurking a
# word, pos: doubt n
# word, pos: truth n
# word, pos: theory n
# word, pos: be v
# word, pos: once r
# word, pos: removed v
# word, pos: noticing v
# word, pos: electrify v
# word, pos: hearers. n
# after drop and lemmatization
#                                        headline_text preprocessed
# 0  Their very number shows that they were contriv...     hearers.
# this word does not exists in corpus: headline_text,preprocessed at ['headline_text,preprocessed']
# this word does not exists in corpus: "Their at ['"Their', 'very', 'number', 'shows', 'that', 'they', 'were', 'contrived', 'in', 'imitation', 'of', 'the', 'music', 'of', 'the', 'seven', 'spheres,and', 'any', 'lurking', 'doubt', 'of', 'the', 'truth', 'of', 'our', 'theory', 'will', 'be', 'at', 'once', 'removed', 'by', 'noticing', 'how', 'they', 'electrify', 'their', 'hearers.",hearers.']
# this word does not exists in corpus: spheres,and at ['"Their', 'very', 'number', 'shows', 'that', 'they', 'were', 'contrived', 'in', 'imitation', 'of', 'the', 'music', 'of', 'the', 'seven', 'spheres,and', 'any', 'lurking', 'doubt', 'of', 'the', 'truth', 'of', 'our', 'theory', 'will', 'be', 'at', 'once', 'removed', 'by', 'noticing', 'how', 'they', 'electrify', 'their', 'hearers.",hearers.']
# this word does not exists in corpus: hearers.",hearers. at ['"Their', 'very', 'number', 'shows', 'that', 'they', 'were', 'contrived', 'in', 'imitation', 'of', 'the', 'music', 'of', 'the', 'seven', 'spheres,and', 'any', 'lurking', 'doubt', 'of', 'the', 'truth', 'of', 'our', 'theory', 'will', 'be', 'at', 'once', 'removed', 'by', 'noticing', 'how', 'they', 'electrify', 'their', 'hearers.",hearers.']
# idx: 6
#  (2, 300) [['headline_text,preprocessed'], ['"Their', 'very', 'number', 'shows', 'that', 'they', 'were', 'contrived', 'in', 'imitation', 'of', 'the', 'music', 'of', 'the', 'seven', 'spheres,and', 'any', 'lurking', 'doubt', 'of', 'the', 'truth', 'of', 'our', 'theory', 'will', 'be', 'at', 'once', 'removed', 'by', 'noticing', 'how', 'they', 'electrify', 'their', 'hearers.",hearers.']]

# %%
for i in range(len(vec_list)):
    print(i, len(vec_list[i]))
# Out:
# 0 300
# 1 300
# 2 300
# 3 300
# 4 300
# 5 300
# 6 300
# 7 300
# 8 300
# 9 300

# %%
print(vec.shape, len(vec_list), len(vec_list[0]))
# Out:
# (2, 300) 10 300

# %%
print(path.exists)
# Out:
# <function exists at 0x000001C779E3D678>

# %%
from nltk.tokenize.punkt import PunktSentenceTokenizer, PunktParameters

para = '''Either the well was very deep, or she fell very slowly, for she had plenty
of time as she went down to look about her and to wonder what was going to happen
next. First, she tried to look down and make out what she was coming to, but it was
too dark to see anything; then she looked at the sides of the well, and noticed
that they were filled with cupboards and book-shelves; here and there she saw maps
and pictures Mr...hung upon pegs. She took down a jar from one of the shelves as she
passed; it was labelled 'ORANGE MARMALADE', but to her great disappointment it was
empty: she did not like to drop the jar for fear of killing somebody, so managed to
put it into one of the cupboards as she fell past it.'''

punkt_params = PunktParameters()
#punkt_params.abbrev_types = set(['Mr', 'Mrs', 'LLC'])
tokenizer = PunktSentenceTokenizer(punkt_params)
tokens = tokenizer.tokenize(para)

for t in tokens:
    print (t, "\n")
# Out:
# Either the well was very deep, or she fell very slowly, for she had plenty
# of time as she went down to look about her and to wonder what was going to happen
# next.
#
# First, she tried to look down and make out what she was coming to, but it was
# too dark to see anything; then she looked at the sides of the well, and noticed
# that they were filled with cupboards and book-shelves; here and there she saw maps
# and pictures Mr...hung upon pegs.
#
# She took down a jar from one of the shelves as she
# passed; it was labelled 'ORANGE MARMALADE', but to her great disappointment it was
# empty: she did not like to drop the jar for fear of killing somebody, so managed to
# put it into one of the cupboards as she fell past it.
