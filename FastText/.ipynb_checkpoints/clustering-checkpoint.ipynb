# %%
import pandas as pd
import numpy as np
import nltk
from os import path
import re
import libs as ft
from sklearn.metrics.pairwise import cosine_similarity
#from pyfasttext import FastText
#from gensim.models.wrappers import FastText
import fasttext as ft


import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Si\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Si\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def cleansing(x, drop_tag, tag_pos, lemmatizer):
    """
    いらない品詞を除外し，レンマ化して返す．apply関数内で使用，

    Args:
        x (Series): apply関数で呼び出されるSeries
        drop_tag (list): いらない品詞リスト(nltk)
        tag_pos (dict): key -> tag, value -> pos. レンマ化の精度向上に使用．
        lemmatizer (nltk.stem.WordNetLemmatizer): lemmatizer

    Returns:
        (str): output sentence
    """
    words = [word for word in x['headline_text'].split(' ') if word != '']  # 空文字入るとエラーになる
    tags = nltk.pos_tag(words)  # 品詞を取得
    words = [(word, tag_pos[tag]) for word, tag in tags if tag not in drop_tag]  # いらない品詞を除外
    print('words:',words)
    words = [lemmatizer.lemmatize(word, pos=pos) for word, pos in words]
    sentence = ' '.join(words)  # 連結
    return sentence

# %%
def preprocess(data):
    """
    前処理の関数．

    Args:
        data (DataFrame): input dataset

    Retruns:
        (DataFrame): output dataset
    """
    # まずは，いらない品詞を落とし，レンマ化する．
    # その後，階層クラスタリングのときに使う用のcsvファイルとモデル学習用のtxtファイルを出力する．
    lemmatizer = nltk.stem.WordNetLemmatizer()
    # いらない品詞
    drop_tag = ['$', 'CC', 'CD', 'DT', 'IN', 'MD', 'POS', 'PRP', 'PRP$', 'RP', 'TO' , 'WP', 'WRB']
    # 品詞とpos(lemma用)の変換辞書
    tag_pos = {'FW': 'n', 'JJ': 'a', 'JJR': 'a', 'JJS': 'a', 'NN': 'n', 'NNP': 'n', 'NNS': 'n', 'RB': 'r', 'RBR': 'r', 'VB': 'v',
               'VBD': 'v', 'VBG': 'v', 'VBN': 'v', 'VBP': 'v', 'VBZ': 'v', 'RBS': 'r',}

    #data = data.assign(preprocessed=data.apply(func=cleansing, axis=1, args=(drop_tag, tag_pos, lemmatizer,)))
    data = data.assign(preprocessed=data.apply(func=cleansing, axis=1, args=(drop_tag, tag_pos, lemmatizer)))

    print('after drop and lemmatization')
    print(data.head())
    data.to_csv('data2.csv', sep='\t', index=False)
    data['preprocessed'].to_csv('text2.txt', index=False)
    return data

# %%
def get_word_vector(data_name='text.txt', model_name='./pretrained_model/model.bin'):
    """
    fasttextベースで分散表現を取得する関数．これも見てわかると思うので引数は省略．

    Returns:
        (list of list): 単語リストのリスト．[['word_0_0', 'word_0_1'], ['word_1_0', 'word_1_1', 'word_1_2'], ...]みたいな
        (array): 分散表現 次元=(文章数×分散表現の次元数)
    """
    sentences = []
    with open(data_name, mode='r') as f:
        for line in f.readlines():
            line = re.sub('\n', '', line)
            sentences.append(line.split(' '))

    # modelが12GBくらいメモリを食うので終わったら開放する．
    vec_name =  'sentences_vc2.npy'
    if not path.exists(vec_name):
        #model = FastText.load_fasttext_format(model_name)
        model = ft.load_model(model_name)
        dim = model.get_dimension()
        sentences_vec = np.zeros((dim,))

        for words in sentences:
            vec = np.zeros((dim,))
            for word in words:
                if model.get_word_id(word) == -1:
                    print('this word does not exists in corpus: %s at %s' % (word, words))
                vec = np.vstack((vec, model.get_word_vector(word)))
            vec = vec[1:, :].mean(axis=0)
            sentences_vec = np.vstack((sentences_vec, vec))
        sentences_vec = sentences_vec[1:, :]
        del model

        np.save(vec_name, sentences_vec)
    else:
        sentences_vec = np.load(vec_name)
    return sentences, sentences_vec

# %%
if __name__ == '__main__':
    np.random.seed(123)
    # ランダムに50個の記事の題名を取得
    data = pd.read_csv('./abcnews-date-text.csv')
    rand_index = np.random.randint(0, data.shape[0], 400)
    data = data.iloc[rand_index, 1]
data
# Out:
# 773630                   holman heroics save socceroos skins
# 277869        cultural background affects ones health report
# 28030                row brews over radiation therapy delays
# 1066306    liberal mp isobel redmond to retire at 2018 st...
# 194278       waste plan review to consider recycling options
#                                  ...
# 646698                         act election countdown begins
# 353514         search underway for people missing in sa bush
# 773379         pervez musharraf back in pakistan after exile
# 928084     man to front court accused of shooting man in ...
# 655905                               minister backs dec head
# Name: headline_text, Length: 400, dtype: object

# %%
type(data), data.shape
# Out:
# (pandas.core.series.Series, (400,))

# %%
if __name__ == '__main__':
    np.random.seed(123)
    # ランダムに50個の記事の題名を取得
    data = pd.read_csv('./abcnews-date-text.csv')
    rand_index = np.random.randint(0, data.shape[0], 400)
    data = data.iloc[rand_index, 1]
    print('=>raw data:')
    print('=>data.head:', data.head())

    # sent = ' '.join(list(data))
    # words = nltk.word_tokenize(sent)
    # tags = nltk.pos_tag(words)
    # tags = sorted(list(set([tag for word, tag in tags])))
    # for i in tags:
        # print(nltk.help.upenn_tagset(i))
    data = preprocess(pd.DataFrame(data))

    sentences, vec = get_word_vector()
    print(vec.shape)
    #get_similar_sentence(data.iloc[0, 1], data, sentences, vec, 5)
# Out:
# =>raw data:
# =>data.head: 773630                   holman heroics save socceroos skins
# 277869        cultural background affects ones health report
# 28030                row brews over radiation therapy delays
# 1066306    liberal mp isobel redmond to retire at 2018 st...
# 194278       waste plan review to consider recycling options
# Name: headline_text, dtype: object
# words: [('holman', 'n'), ('heroics', 'n'), ('save', 'v'), ('socceroos', 'n'), ('skins', 'n')]
# words: [('cultural', 'a'), ('background', 'n'), ('affects', 'v'), ('ones', 'n'), ('health', 'n'), ('report', 'n')]
# words: [('row', 'n'), ('brews', 'n'), ('radiation', 'n'), ('therapy', 'n'), ('delays', 'n')]
# words: [('liberal', 'a'), ('mp', 'n'), ('isobel', 'n'), ('redmond', 'n'), ('retire', 'v'), ('state', 'n'), ('election', 'n')]
# words: [('waste', 'n'), ('plan', 'n'), ('review', 'v'), ('consider', 'v'), ('recycling', 'v'), ('options', 'n')]
# words: [('png', 'a'), ('government', 'n'), ('tactics', 'n'), ("'cowardly", 'r')]
# words: [('local', 'a'), ('councils', 'n'), ('advocate', 'v'), ('social', 'a'), ('change', 'n')]
# words: [('climber', 'n'), ('scales', 'n'), ('trump', 'v'), ('tower', 'n'), ('suction', 'n'), ('caps', 'n')]
# words: [('larry', 'n'), ('nassars', 'n'), ('huge', 'a'), ('sentence', 'n'), ('feels', 'n'), ('victory', 'n'), ('too', 'r')]
# words: [('security', 'n'), ('cameras', 'n'), ('help', 'v'), ('combat', 'v'), ('stock', 'n'), ('theft', 'n')]
# words: [('brazil', 'n'), ('court', 'n'), ('appeal', 'n'), ('athens', 'n'), ('marathon', 'n'), ('gold', 'n')]
# words: [('lakes', 'n'), ('blue', 'v'), ('green', 'a'), ('algae', 'n'), ('threat', 'n'), ('remains', 'n')]
# words: [('customs', 'n'), ('software', 'n'), ('stay', 'v'), ('ellison', 'n'), ('says', 'v')]
# words: [('litchfield', 'n'), ('take', 'v'), ('drl', 'a'), ('premiership', 'n')]
# words: [('broncos', 'n'), ('go', 'v'), ('bang', 'n'), ('whimper', 'n')]
# words: [('geraldton', 'n'), ('welcomes', 'v'), ('cctv', 'a'), ('funding', 'n')]
# words: [('minister', 'n'), ('reassured', 'v'), ('qld', 'a'), ('rail', 'n'), ('wind', 'v'), ('back', 'r')]
# words: [('ryan', 'a'), ('european', 'a'), ('crisis', 'n'), ('things', 'n'), ('have', 'v'), ('change', 'v')]
# words: [('man', 'n'), ('pleads', 'v'), ('not', 'r'), ('guilty', 'a'), ('alleged', 'a'), ('drug', 'n'), ('debt', 'n'), ('bashing', 'n')]
# words: [('families', 'n'), ('shot', 'v'), ('dead', 'a'), ('fleeing', 'v'), ('syria', 'n')]
# words: [('newcastle', 'a'), ('lawyers', 'n'), ('welcome', 'v'), ('judge', 'n'), ('appointment', 'n')]
# words: [('appeal', 'n'), ('dismissed', 'v'), ('atm', 'a'), ('robbery', 'n'), ('case', 'n')]
# words: [('snapper', 'n'), ('fisher', 'n'), ('fined', 'v')]
# words: [('boosting', 'v'), ('legal', 'a'), ('services', 'n'), ('save', 'v'), ('money', 'n'), ('greens', 'n')]
# words: [('police', 'n'), ('boost', 'v'), ('efforts', 'n'), ('kyneton', 'n'), ('events', 'n')]
# words: [('relatives', 'n'), ('turned', 'v'), ('aged', 'v'), ('care', 'n'), ('complaints', 'n')]
# words: [('zadie', 'n'), ('smith', 'n'), ('fiction', 'n'), ('novel', 'a'), ('short', 'a'), ('stories', 'n'), ('white', 'a'), ('teeth', 'n')]
# words: [('blueberry', 'n'), ('export', 'n'), ('market', 'n'), ('development', 'n'), ('greg', 'n'), ('mcculloch', 'n')]
# words: [('federal', 'a'), ('govt', 'n'), ('urged', 'v'), ('rethink', 'v'), ('decision', 'n'), ('not', 'r'), ('fund', 'v')]
# words: [('earthquake', 'n'), ('strikes', 'n'), ('png', 'v')]
# words: [('principals', 'n'), ('question', 'v'), ('value', 'n'), ('parent', 'n'), ('targeted', 'v'), ('literacy', 'n'), ('video', 'n')]
# words: [('finks', 'n'), ('jailed', 'v'), ('contempt', 'n'), ('ccc', 'n')]
# words: [('cash', 'n'), ('staffer', 'n'), ('resigns', 'v'), ('awu', 'a'), ('raids', 'n')]
# words: [('narromine', 'a'), ('considers', 'n'), ('staged', 'v'), ('rollout', 'n'), ('cctv', 'n')]
# words: [('lee', 'n'), ('summer', 'n')]
# words: [('gunn', 'a'), ('shares', 'n'), ('trade', 'n'), ('again', 'r')]
# words: [('big', 'a'), ('plans', 'n'), ('adelaide', 'a'), ('airport', 'n'), ('revamp', 'n')]
# words: [('un', 'a'), ('condemns', 'n'), ('attacks', 'n'), ('syria', 'n')]
# words: [('bobsleigh', 'a'), ('worker', 'n'), ('has', 'v'), ('legs', 'v'), ('broken', 'v'), ('crash', 'n')]
# words: [('nt', 'n'), ('benefit', 'v'), ('raaf', 'a'), ('base', 'n'), ('upgrade', 'n')]
# words: [('media', 'n'), ('cautioned', 'v'), ('british', 'a'), ('prisoner', 'n'), ('abuse', 'n'), ('case', 'n')]
# words: [('top', 'a'), ('stories', 'n'), ('abc', 'a'), ('news', 'n')]
# words: [('rain', 'n'), ('delays', 'n'), ('scg', 'v'), ('test', 'n'), ('again', 'r')]
# words: [('fatal', 'a'), ('crash', 'n'), ('teen', 'n'), ('victims', 'n'), ('mourned', 'v'), ('darwin', 'n'), ('classmates', 'n')]
# words: [('premiers', 'n'), ('says', 'v'), ('public', 'a'), ('service', 'n'), ('jobs', 'n'), ('go', 'v'), ('new', 'a'), ('rules', 'n')]
# words: [('woods', 'n'), ('caps', 'n'), ('year', 'n'), ('remember', 'v'), ('eighth', 'a'), ('victory', 'n')]
# words: [('alice', 'r'), ('council', 'n'), ('step', 'v'), ('push', 'n'), ('non', 'a'), ('sniff', 'n'), ('petrol', 'n')]
# words: [('round', 'n'), ('league', 'n'), ('too', 'r'), ('close', 'r'), ('call', 'v')]
# words: [('committee', 'n'), ('invites', 'v'), ('patients', 'n'), ('have', 'v'), ('health', 'n'), ('say', 'v')]
# words: [('flinders', 'n'), ('university', 'n'), ('offering', 'v'), ('early', 'a'), ('retirement', 'n'), ('packages', 'n'), ('staff', 'n')]
# words: [('michael', 'v'), ('bloomberg', 'n'), ('make', 'v'), ('worthy', 'a'), ('presidential', 'a'), ('candidate', 'n')]
# words: [('fears', 'n'), ('flood', 'v'), ('funding', 'n'), ('faces', 'v'), ('delay', 'n')]
# words: [('indigenous', 'a'), ('patients', 'n'), ('confused', 'v'), ('kidney', 'n'), ('disease', 'n')]
# words: [('first', 'r'), ('ashes', 'a'), ('test', 'n'), ('day', 'n'), ('summary', 'n')]
# words: [('beattie', 'a'), ('defends', 'n'), ('fast', 'r'), ('tracking', 'v'), ('ir', 'n'), ('laws', 'n')]
# words: [('smoko', 'n'), ('room', 'n'), ('closed', 'v'), ('toxic', 'a'), ('dust', 'n'), ('fears', 'n')]
# words: [('study', 'n'), ('says', 'v'), ('ewl', 'v'), ('cut', 'v'), ('travel', 'n'), ('times', 'n')]
# words: [('markets', 'n'), ('close', 'r'), ('dollar', 'n'), ('drags', 'n')]
# words: [('burma', 'n'), ('tries', 'n'), ('cool', 'v'), ('international', 'a'), ('pressure', 'n')]
# words: [('momentum', 'n'), ('set', 'v'), ('build', 'v'), ('wimbledons', 'n'), ('second', 'a'), ('week', 'n')]
# words: [('trial', 'n'), ('chinas', 'n'), ('former', 'a'), ('police', 'n'), ('chief', 'n'), ('begins', 'n')]
# words: [('bardot', 'n'), ('decries', 'n'), ('polar', 'v'), ('bear', 'n'), ('hunt', 'n')]
# words: [('apra', 'n'), ('asks', 'v'), ('banks', 'n'), ('living', 'n'), ('wills', 'n')]
# words: [('storm', 'n'), ('kills', 'n'), ('philippines', 'n')]
# words: [('nsw', 'a'), ('ombudsman', 'a'), ('examines', 'n'), ('care', 'n'), ('deaths', 'n')]
# words: [('teacher', 'n')]
# words: [('opal', 'a'), ('danger', 'n')]
# words: [('steelers', 'n'), ('canada', 'n'), ('win', 'v'), ('gold', 'n')]
# words: [('halloran', 'n')]
# words: [('green', 'a'), ('groups', 'n'), ('aboriginal', 'a'), ('land', 'n'), ('council', 'n'), ('protest', 'v'), ('water', 'n'), ('licenses', 'n')]
# words: [('police', 'n'), ('probe', 'v'), ('fatal', 'a'), ('rockhampton', 'n'), ('crash', 'n')]
# words: [('pedestrian', 'a'), ('accident', 'n'), ('puts', 'v'), ('woman', 'n'), ('hospital', 'n')]
# words: [('report', 'n'), ('highlights', 'n'), ('desire', 'n'), ('changes', 'n'), ('wheat', 'v')]
# words: [('council', 'n'), ('ceos', 'n'), ('bribe', 'n'), ('evidence', 'n'), ('inconsistent', 'n')]
# words: [('car', 'n'), ('leasing', 'v'), ('firm', 'n'), ('faces', 'v'), ('uncertain', 'a'), ('future', 'n')]
# words: [('remains', 'n'), ('shed', 'v'), ('light', 'n'), ('disappearance', 'n')]
# words: [('wa', 'n'), ('joins', 'v'), ('national', 'a'), ('fight', 'n'), ('salinity', 'n')]
# words: [('health', 'n'), ('service', 'n'), ('urged', 'v'), ('change', 'v'), ('management', 'n'), ('tack', 'n')]
# words: [('man', 'n'), ('dead', 'a'), ('sydney', 'n'), ('shooting', 'n')]
# words: [('fire', 'n'), ('alert', 'n'), ('winds', 'n'), ('pick', 'v')]
# words: [('lismore', 'n'), ('telstra', 'n')]
# words: [('call', 'n'), ('armidale', 'n'), ('join', 'v'), ('sentencing', 'v'), ('scheme', 'n')]
# words: [('judge', 'n'), ('criticises', 'n'), ('law', 'n'), ('makers', 'n'), ('negligence', 'n'), ('jail', 'n')]
# words: [('andre', 'n'), ('awarded', 'v'), ('damages', 'n'), ('cheating', 'n'), ('claims', 'n')]
# words: [('david', 'n'), ('mcbride', 'n'), ('speaks', 'n'), ('court', 'n')]
# words: [('fires', 'n'), ('continue', 'v'), ('burn', 'v'), ('far', 'r'), ('north', 'a'), ('qld', 'n')]
# words: [('gates', 'n'), ('pledges', 'n'), ('unclog', 'v'), ('email', 'n'), ('boxes', 'n')]
# words: [('rspca', 'n'), ('backs', 'v'), ('cull', 'n'), ('feral', 'a'), ('horses', 'n'), ('wa', 'n')]
# words: [('housing', 'n'), ('woes', 'n'), ('probe', 'v'), ('take', 'v'), ('broader', 'a'), ('view', 'n')]
# words: [('adapt', 'r'), ('potentially', 'r'), ('fatal', 'a'), ('impulse', 'n'), ('rescue', 'v'), ('someone', 'n'), ('drowning', 'v')]
# words: [('sixth', 'a'), ('harry', 'n'), ('potter', 'n'), ('cast', 'v'), ('spell', 'n'), ('july', 'n')]
# words: [('horse', 'n'), ('flu', 'n'), ('compensation', 'n'), ('class', 'n'), ('action', 'n'), ('goes', 'v'), ('mediation', 'v')]
# words: [('more', 'r'), ('affordable', 'a'), ('homes', 'n'), ('way', 'n')]
# words: [('asx', 'r'), ('falls', 'v'), ('anz', 'n'), ('cba', 'n'), ('drag', 'n'), ('share', 'n'), ('market', 'n')]
# words: [('church', 'n'), ('celebrates', 'v'), ('bishops', 'n'), ('house', 'n'), ('centenary', 'n')]
# words: [('hargreaves', 'n'), ('behaviour', 'v'), ('debated', 'v'), ('assembly', 'n')]
# words: [('israel', 'n'), ('hamas', 'v'), ('battle', 'n'), ('un', 'a'), ('ceasefire', 'n'), ('demand', 'n')]
# words: [('wach', 'n'), ('exmouth', 'n'), ('banana', 'n'), ('prawns', 'n')]
# words: [('hamilton', 'n'), ('edges', 'v'), ('singapore', 'n'), ('pole', 'n')]
# words: [('tarting', 'v'), ('nbn', 'n')]
# words: [('emergency', 'n'), ('beacon', 'n'), ('false', 'a'), ('alarm', 'n')]
# words: [('horticulture', 'n'), ('aquaponics', 'n'), ('industry', 'n'), ('wheatbelt', 'n')]
# words: [('frances', 'n'), ('pinault', 'v'), ('stays', 'n'), ('top', 'n'), ('art', 'n'), ('world', 'n'), ('power', 'n'), ('list', 'n')]
# words: [('south', 'a'), ('sudan', 'a'), ('celebrations', 'n'), ('muted', 'v'), ('fifth', 'a'), ('anniversary', 'n'), ('founding', 'v')]
# words: [('yogi', 'r'), ('berra;', 'a'), ('new', 'a'), ('york', 'n'), ('yankees', 'n'), ('legend;', 'v'), ('dies', 'n'), ('aged', 'v')]
# words: [('mineral', 'a'), ('energy', 'n'), ('exports', 'n')]
# words: [('un', 'a'), ('imposes', 'n'), ('weapons', 'n'), ('sanctions', 'n'), ('north', 'a'), ('korea', 'n')]
# words: [('indigenous', 'a'), ('culture', 'n'), ('offers', 'v'), ('mental', 'a'), ('health', 'n'), ('lessons', 'n')]
# words: [('endangered', 'v'), ('sea', 'n'), ('lion', 'n'), ('pup', 'n'), ('makes', 'v'), ('public', 'a'), ('debut', 'n'), ('marine', 'n'), ('park', 'n')]
# words: [('not', 'r'), ('guilty', 'a'), ('plea', 'n'), ('listeria', 'n'), ('find', 'v')]
# words: [('college', 'n'), ('suffers', 'n'), ('staff', 'n'), ('shortage', 'n')]
# words: [('mp', 'n'), ('says', 'v'), ('solar', 'a'), ('switch', 'n'), ('pull', 'v'), ('plug', 'n'), ('business', 'n')]
# words: [('election', 'n'), ('forums', 'n')]
# words: [('study', 'n'), ('highlights', 'n'), ('councils', 'n'), ('road', 'n'), ('maintenance', 'n'), ('struggle', 'n')]
# words: [('thomas', 'r'), ('now', 'r'), ('target', 'n'), ('say', 'v'), ('roos', 'n')]
# words: [('b', 'n'), ('j', 'n'), ('bentley', 'n'), ('cops', 'v'), ('dumping', 'n'), ('fine', 'n')]
# words: [('hussey', 'n'), ('langer', 'r'), ('lead', 'a'), ('warriors', 'n'), ('fightback', 'v')]
# words: [('arrest', 'n'), ('warrant', 'n'), ('issued', 'v'), ('teen', 'a'), ('accused', 'v'), ('sheep', 'n')]
# words: [('mercurial', 'a'), ('jones', 'n'), ('leads', 'v'), ('warriors', 'n'), ('victory', 'n')]
# words: [('drug', 'n'), ('testing', 'v'), ('device', 'n'), ('speed', 'v'), ('detection', 'n')]
# words: [('australians', 'n'), ('worried', 'v'), ('uncomfortable', 'a'), ('retirement', 'n'), ('lifestyle', 'n'), ('survey', 'n')]
# words: [('alcohol', 'n'), ('plan', 'n'), ('policing', 'v'), ('stops', 'n'), ('cape', 'n'), ('york', 'n'), ('hell', 'n')]
# words: [('wilcannia', 'n'), ('works', 'v'), ('scheme', 'n'), ('be', 'v'), ('model', 'n'), ('other', 'a')]
# words: [('concern', 'n'), ('illegal', 'a'), ('brothels', 'n'), ('wa', 'n')]
# words: [('torres', 'n'), ('strait', 'v'), ('islanders', 'n'), ('plan', 'v'), ('compo', 'a'), ('class', 'n'), ('action', 'n')]
# words: [('forces', 'n'), ('launch', 'a'), ('attack', 'n'), ('western', 'a'), ('iraq', 'n')]
# words: [('stephen', 'n'), ('hawking', 'v'), ('world', 'n'), ('reacts', 'v'), ('death', 'n'), ('physicist', 'n')]
# words: [('thousands', 'n'), ('shipbuilding', 'v'), ('jobs', 'n'), ('risk:', 'n'), ('union', 'n')]
# words: [('administrator', 'n'), ('appointed', 'v'), ('wagga', 'v'), ('land', 'n'), ('council', 'n')]
# words: [('woolshed', 'v'), ('gets', 'v'), ('award', 'r'), ('honour', 'n')]
# words: [('pm', 'n'), ('sweetens', 'v'), ('health', 'n'), ('plan', 'n')]
# words: [('finance', 'n'), ('quarter', 'n')]
# words: [('thredbo', 'a'), ('visitor', 'n'), ('numbers', 'n'), ('expected', 'v'), ('bounce', 'v'), ('back', 'r')]
# words: [('japan', 'n'), ('accuses', 'v'), ('greenpeace', 'n'), ('piracy', 'n')]
# words: [('black', 'a'), ('caps', 'n'), ('duo', 'a'), ('admit', 'v'), ('role', 'n'), ('india', 'a'), ('riot', 'n')]
# words: [('senior', 'a'), ('police', 'n'), ('officer', 'n'), ('escapes', 'v'), ('internal', 'a'), ('discipline', 'n')]
# words: [('customs', 'n'), ('combat', 'v'), ('illegal', 'a'), ('fishing', 'n'), ('base', 'n'), ('reef', 'n')]
# words: [('staff', 'n'), ('struggle', 'n'), ('reduce', 'v'), ('indigenous', 'a'), ('smoking', 'n'), ('rates', 'n')]
# words: [('regional', 'a'), ('drivers', 'n'), ('warned', 'v'), ('fuel', 'n'), ('price', 'n'), ('rise', 'n')]
# words: [('struggling', 'v'), ('regional', 'a'), ('schools', 'n'), ('miss', 'v'), ('funds', 'n'), ('mp', 'n')]
# words: [('fall', 'n'), ('wall', 'n'), ('remembered', 'v')]
# words: [('animal', 'a'), ('activists', 'n'), ('renew', 'v'), ('push', 'n'), ('live', 'a'), ('exports', 'n'), ('ban', 'n')]
# words: [('residents', 'n'), ('quick', 'v'), ('oppose', 'v'), ('speed', 'n'), ('reduction', 'n'), ('plan', 'n')]
# words: [('bartlett', 'n'), ('admits', 'v'), ('more', 'r'), ('mining', 'n'), ('inspectors', 'n'), ('needed', 'v')]
# words: [('violence', 'n'), ('continues', 'v'), ('foreign', 'a'), ('presence', 'n')]
# words: [('kempsey', 'n'), ('business', 'n'), ('sector', 'n'), ('optimistic', 'a'), ('pacific', 'a'), ('highway', 'n'), ('bypass', 'n')]
# words: [('diegos', 'r'), ('metre', 'n'), ('chip', 'n'), ('earns', 'v'), ('santos', 'a'), ('libertadores', 'n'), ('draw', 'v')]
# words: [('man', 'n'), ('charged', 'v'), ('baby', 'n'), ('murder', 'n')]
# words: [('researchers', 'n'), ('enlist', 'v'), ('koalas', 'n'), ('search', 'n'), ('chlamydia', 'n')]
# words: [('cyclist', 'n'), ('charged', 'v'), ('blowing', 'v')]
# words: [('clean', 'v'), ('begins', 'n'), ('nsw', 'a'), ('storms', 'n')]
# words: [('gibbs', 'n'), ('facing', 'v'), ('ban', 'n'), ('kneeing', 'v')]
# words: [('xmas', 'a'), ('retail', 'a'), ('signs', 'n'), ('pick', 'v')]
# words: [('partnership', 'n'), ('call', 'n'), ('speed', 'v'), ('land', 'n'), ('releases', 'n')]
# words: [('cattle', 'n'), ('station', 'n'), ('murderer', 'n'), ('set', 'v'), ('walk', 'v'), ('free', 'a')]
# words: [('govt', 'n'), ('fast', 'n'), ('tracks', 'n'), ('albany', 'v'), ('hospital', 'a'), ('work', 'n')]
# words: [('outback', 'n'), ('campdrafts', 'n'), ('big', 'a'), ('business', 'n'), ('horse', 'n'), ('owners', 'n')]
# words: [('argentina', 'r'), ('italy', 'n'), ('hopman', 'a'), ('cup', 'n'), ('first', 'r'), ('round', 'n')]
# words: [('abare', 'n'), ('launches', 'v'), ('final', 'a'), ('stage', 'n'), ('growers', 'n'), ('survey', 'n')]
# words: [('perth', 'n'), ('teens', 'n'), ('photography', 'v'), ('focuses', 'v'), ('attention', 'n'), ('homelessness', 'n')]
# words: [('turfed', 'v'), ('mine:', 'n'), ('wyong', 'a'), ('farmer', 'n'), ('fears', 'n')]
# words: [('tony', 'a'), ('burke', 'n'), ('rubbishes', 'n'), ('fairfax', 'v'), ('asylum', 'a'), ('seeker', 'n'), ('report', 'n')]
# words: [('town', 'n'), ('honour', 'v'), ('racing', 'v'), ('great', 'a'), ('gunsynd', 'n')]
# words: [('national', 'a'), ('disability', 'n'), ('insurance', 'n'), ('scheme', 'n'), ('promise', 'n'), ('check', 'n')]
# words: [('gillard', 'n'), ('denies', 'v'), ('scenes', 'n'), ('deal', 'n'), ('greens', 'n')]
# words: [('australian', 'a'), ('share', 'n'), ('market', 'n'), ('opens', 'v'), ('higher', 'a')]
# words: [('bland', 'n'), ('mou', 'n')]
# words: [('wagga', 'a'), ('service', 'n'), ('remembers', 'n'), ('army', 'v'), ('training', 'v'), ('accident', 'n')]
# words: [('adam', 'n'), ('giles', 'n'), ('plan', 'v'), ('dump', 'v'), ('bail', 'n'), ('youths', 'n'), ('slammed', 'v'), ('lawyers', 'n')]
# words: [('interview', 'n'), ('broadbent', 'n')]
# words: [('push', 'n'), ('farmers', 'n'), ('get', 'v'), ('storm', 'n'), ('aid', 'n')]
# words: [('vic', 'a'), ('poppies', 'n'), ('ruled', 'v')]
# words: [('council', 'n'), ('orders', 'n'), ('environmental', 'a'), ('probe', 'n'), ('proposed', 'v'), ('marina', 'n')]
# words: [('abc', 'n'), ('entertainment', 'n')]
# words: [('matautaavas', 'n'), ('amazing', 'v'), ('effort', 'n'), ('powers', 'n'), ('vanuatu', 'v'), ('wcl', 'n')]
# words: [('graham', 'n'), ('quirk', 'n'), ('rejects', 'v'), ('claims', 'n'), ('favourable', 'a'), ('treatment', 'n'), ('lnp', 'n'), ('donor', 'n')]
# words: [('fina', 'n'), ('consider', 'v'), ('hacketts', 'n'), ('proposal', 'n')]
# words: [('forum', 'n'), ('focuses', 'v'), ('helping', 'v'), ('stressed', 'a'), ('families', 'n')]
# words: [('men', 'n'), ('brace', 'n'), ('beard', 'n'), ('patrols', 'n'), ('iraqs', 'n'), ('mosul', 'n')]
# words: [('decision', 'n'), ('hands', 'n'), ('beattie', 'v'), ('tells', 'n'), ('palm', 'v')]
# words: [('wild', 'a'), ('dog', 'n'), ('cost', 'n'), ('recalculated', 'v'), ('new', 'a'), ('bait', 'n'), ('set', 'v'), ('release', 'n')]
# words: [('swan', 'n'), ('delivers', 'n'), ('fair', 'v'), ('go', 'v'), ('budget', 'n'), ('save', 'v'), ('labor', 'n')]
# words: [('cattle', 'n'), ('drive', 'v'), ('beefs', 'n'), ('overseas', 'a'), ('interest', 'n')]
# words: [('macqueen', 'a'), ('confident', 'a'), ('team', 'n'), ('put', 'v'), ('show', 'n')]
# words: [('blair', 'n'), ('athol', 'n'), ('deli', 'a'), ('staff', 'n'), ('held', 'v'), ('man', 'n'), ('needle', 'a')]
# words: [('heart', 'n'), ('patients', 'n'), ('better', 'a'), ('manage', 'n'), ('rehab', 'n')]
# words: [('search', 'n'), ('car', 'n'), ('fatal', 'a'), ('sydney', 'n'), ('hit', 'n'), ('run', 'v')]
# words: [('bureau', 'n'), ('warns', 'n'), ('damaging', 'v'), ('winds', 'n'), ('nsw', 'n'), ('act', 'n')]
# words: [('flinders', 'n'), ('emergency', 'n'), ('department', 'n'), ('operating', 'n'), ('theatres', 'n')]
# words: [('restrictions', 'n'), ('halt', 'v'), ('watering', 'v'), ('parklands', 'n')]
# words: [('rba', 'n'), ('debelle', 'n'), ('speech', 'n')]
# words: [('youve', 'r'), ('come', 'v'), ('long', 'a'), ('way', 'n'), ('tony', 'n')]
# words: [('nbn', 'r'), ('satellite', 'a'), ('offers', 'n'), ('hope', 'v'), ('faster', 'a'), ('internet', 'n'), ('outback', 'n')]
# words: [('man', 'n'), ('accused', 'v'), ('fatal', 'a'), ('stabbing', 'v'), ('pleads', 'n'), ('not', 'r'), ('guilty', 'a'), ('murder', 'v')]
# words: [('knights', 'n'), ('defend', 'v'), ('fortress', 'n'), ('season', 'n'), ('opener', 'n')]
# words: [('lack', 'n'), ('scale', 'n'), ('crushing', 'n'), ('ord', 'n'), ('sugar', 'n'), ('dream', 'n')]
# words: [('council', 'n'), ('approves', 'v'), ('mill', 'r'), ('development', 'n')]
# words: [('trump', 'n'), ('delivers', 'n'), ('first', 'a'), ('public', 'a'), ('condemnation', 'n'), ('anti', 'a'), ('semitic', 'a'), ('threats', 'n')]
# words: [('cash', 'n'), ('flows', 'n'), ('ansett', 'v'), ('workers', 'n')]
# words: [('american', 'a'), ('aid', 'n'), ('worker', 'n'), ('alan', 'n'), ('goss', 'n'), ('welcomes', 'v'), ('cuban', 'a'), ('relations', 'n'), ('shift', 'n')]
# words: [('groth', 'n'), ('prepares', 'n'), ('wimbledon', 'n'), ('winning', 'v'), ('manchester', 'n'), ('trophy', 'n')]
# words: [('narendra', 'a'), ('modi', 'n'), ('declares', 'v'), ('victory', 'n'), ('indian', 'a'), ('election', 'n')]
# words: [('medicare', 'v'), ('local', 'a'), ('promises', 'n'), ('more', 'r'), ('health', 'n'), ('funding', 'n')]
# words: [('queensland', 'n'), ('scientists', 'n'), ('help', 'v'), ('develop', 'v'), ('new', 'a'), ('polio', 'n'), ('vaccine', 'n')]
# words: [('doll', 'n'), ('kidnapper', 'n'), ('gets', 'v'), ('jail', 'a'), ('time', 'n')]
# words: [('exposure', 'n'), ('particulate', 'a'), ('matter', 'n'), ('air', 'n'), ('pollution', 'n'), ('harmful', 'n')]
# words: [('little', 'a'), ('pebble', 'a'), ('jailed', 'v'), ('sexual', 'a'), ('abuse', 'n')]
# words: [('grazier', 'n'), ('wants', 'v'), ('beef', 'n'), ('exported', 'v'), ('rockhampton', 'n'), ('airport', 'n')]
# words: [('drought', 'n'), ('not', 'r'), ('stopping', 'v'), ('big', 'a'), ('field', 'n'), ('days', 'n')]
# words: [('interview', 'n'), ('rob', 'n'), ('simmons', 'n')]
# words: [('research', 'n'), ('turns', 'v'), ('spotlight', 'v'), ('binge', 'n'), ('drinking', 'n')]
# words: [('linden', 'n'), ('funding', 'n')]
# words: [('fifth', 'a'), ('ashes', 'n'), ('test', 'v'), ('day', 'n'), ('live', 'a'), ('blog', 'n')]
# words: [('melbourne', 'a'), ('facing', 'v'), ('public', 'a'), ('transport', 'n'), ('strike', 'n')]
# words: [('pokies', 'n'), ('reform', 'v'), ('undemocratic', 'a'), ('says', 'v'), ('clubs', 'n'), ('head', 'n')]
# words: [('police', 'n'), ('nab', 'r'), ('grandma', 'v'), ('drug', 'n'), ('dealers', 'n')]
# words: [('lynx', 'n'), ('win', 'a'), ('battle', 'n'), ('cellar', 'a'), ('dwellers', 'n')]
# words: [('pele', 'n'), ('hospital', 'n'), ('improving', 'v')]
# words: [('cloud', 'v'), ('fire', 'n'), ('create', 'v'), ('weather', 'n')]
# words: [('families', 'n'), ('take', 'v'), ('toxic', 'a'), ('milk', 'n'), ('deal', 'n'), ('china', 'n'), ('says', 'v')]
# words: [('family', 'n'), ('calls', 'v'), ('government', 'n'), ('compassion', 'n'), ('fight', 'n'), ('save', 'v'), ('girl', 'n')]
# words: [('ethiopian', 'a'), ('gun', 'n'), ('battle', 'n'), ('leaves', 'v'), ('dead', 'a')]
# words: [('ibac', 'n'), ('given', 'v'), ('power', 'n'), ('review', 'v'), ('opi', 'a'), ('matters', 'n')]
# words: [('angry', 'a'), ('police', 'n'), ('demand', 'v'), ('resignation', 'n'), ('commissioner', 'n')]
# words: [('hewitt', 'n'), ('thumped', 'v'), ('aussies', 'n'), ('bow', 'v')]
# words: [('great', 'a'), ('chop', 'n'), ('challenge', 'n')]
# words: [('man', 'n'), ('arrested', 'v'), ('dui', 'n'), ('times', 'n'), ('hours', 'n')]
# words: [('gasnier', 'n'), ('dismisses', 'n'), ('wigan', 'v'), ('link', 'n')]
# words: [('nasty', 'a'), ('battle', 'n'), ('is', 'v'), ('shaping', 'v'), ('control', 'n')]
# words: [('search', 'n'), ('ibac', 'a'), ('boss', 'n'), ('continues', 'v')]
# words: [('beachside', 'r'), ('promenade', 'n'), ('works', 'v'), ('uncover', 'r'), ('historic', 'a'), ('railway', 'n')]
# words: [('health', 'n'), ('quarter', 'n')]
# words: [('car', 'n'), ('bomb', 'n'), ('kills', 'v'), ('maltese', 'a'), ('journalist', 'n'), ('exposed', 'v'), ('panama', 'n'), ('papers', 'n'), ('link', 'v')]
# words: [('analysing', 'v'), ('vanuatu', 'a'), ('election', 'n'), ('results', 'n')]
# words: [('refugee', 'n'), ('received', 'v'), ('adequate', 'a'), ('care:', 'n'), ('dept', 'v')]
# words: [('ben', 'n'), ('zygier', 'n'), ('suspected', 'v'), ('double', 'a'), ('agent', 'n'), ('sources', 'n')]
# words: [('iraqi', 'n'), ('guards', 'n'), ('killed', 'v'), ('russians', 'n'), ('kidnapped', 'v')]
# words: [('magistrate', 'n'), ('dismisses', 'n'), ('charges', 'n'), ('bomb', 'n'), ('threat', 'n'), ('case', 'n')]
# words: [('parental', 'a'), ('leave', 'v'), ('open', 'a'), ('abortion', 'n'), ('rorts', 'n'), ('fielding', 'v')]
# words: [('asian', 'a'), ('business', 'n'), ('group', 'n'), ('bid', 'v'), ('whitsunday', 'n'), ('casino', 'n')]
# words: [('abcs', 'n'), ('lord', 'n'), ('switch', 'v'), ('mic', 'n')]
# words: [('world', 'n'), ('trade', 'n'), ('talks', 'n'), ('jeopardy', 'n')]
# words: [('neal', 'n'), ('coalition', 'n'), ('firing', 'n'), ('line', 'n')]
# words: [('kakadu', 'n'), ('plum', 'n'), ('is', 'v'), ('way', 'n'), ('forward', 'r')]
# words: [('fomer', 'n'), ('grazier', 'n'), ('turned', 'v'), ('egg', 'a'), ('producer', 'n'), ('cracks', 'n'), ('egg', 'v'), ('industry', 'n')]
# words: [('dead', 'a'), ('diggers', 'n'), ('dad', 'v'), ('wants', 'v'), ('australia', 'a'), ('stay', 'v'), ('course', 'n')]
# words: [('police', 'n'), ('inquiring', 'v'), ('sexual', 'a'), ('assault', 'n'), ('claim', 'n')]
# words: [('shares', 'n'), ('wall', 'n'), ('st', 'n'), ('slip', 'n'), ('trade', 'n'), ('war', 'n'), ('fears', 'n')]
# words: [('nobel', 'a'), ('prize', 'n'), ('physics', 'n'), ('awarded', 'v'), ('work', 'n'), ('lasers', 'n')]
# words: [('file', 'n'), ('sharing', 'v'), ('debate', 'n'), ('divides', 'n'), ('british', 'a'), ('pop', 'n'), ('stars', 'n')]
# words: [('wombats', 'n'), ('disease', 'v'), ('weeds', 'n'), ('crisis', 'n'), ('meeting', 'n')]
# words: [('joey', 'n'), ('clear', 'a')]
# words: [('goldfields', 'n'), ('police', 'n'), ('ready', 'a'), ('easter', 'a'), ('road', 'n'), ('blitz', 'n')]
# words: [('bias', 'a'), ('reporting', 'n'), ('gaza', 'n'), ('conflict', 'n')]
# words: [('teen', 'n'), ('critical', 'a'), ('condition', 'n'), ('alleged', 'v'), ('home', 'n')]
# words: [('rewards', 'n'), ('bowraville', 'a'), ('deaths', 'n'), ('increased', 'v')]
# words: [('rail', 'a'), ('accident', 'a'), ('report', 'n'), ('months', 'n'), ('away', 'r')]
# words: [('man', 'n'), ('charged', 'v'), ('darwin', 'a'), ('murder', 'n')]
# words: [('die', 'n'), ('crash', 'n'), ('peakhurst', 'n')]
# words: [('drought', 'n'), ('hit', 'v'), ('communities', 'n'), ('plea', 'n'), ('tourists', 'n'), ('visit', 'v')]
# words: [('vidic', 'n'), ('handed', 'v'), ('game', 'n'), ('champions', 'n'), ('league', 'v'), ('ban', 'n')]
# words: [('tv', 'n'), ('film', 'n'), ('spoilers', 'n'), ('be', 'v'), ('less', 'r'), ('important', 'a'), ('think', 'v'), ('research', 'n')]
# words: [('liberal', 'a'), ('minister', 'n'), ('nuclear', 'a'), ('power', 'n')]
# words: [('studio', 'n'), ('satyajit', 'n'), ('das', 'n')]
# words: [('bupa', 'n'), ('ceo', 'n'), ('says', 'v'), ('sorry', 'n'), ('aged', 'v'), ('care', 'n'), ('residents', 'n'), ('did', 'v')]
# words: [('vector', 'n'), ('borne', 'n'), ('diseases', 'n'), ('estimated', 'v'), ('cause', 'v'), ('more', 'a')]
# words: [('north', 'a'), ('koreas', 'n'), ('history', 'n'), ('explained', 'v')]
# words: [('former', 'a'), ('chaplain', 'n'), ('found', 'v'), ('not', 'r'), ('guilty', 'a'), ('sexual', 'a'), ('abuse', 'n')]
# words: [('richard', 'n'), ('colbeck', 'n'), ('india', 'n'), ('trade', 'n')]
# words: [('heritage', 'n'), ('sale', 'n'), ('scrutiny', 'n')]
# words: [('karl', 'n'), ('anthony', 'n'), ('towns', 'n'), ('taken', 'v'), ('minnesota', 'a'), ('timberwolves', 'n'), ('first', 'a'), ('p', 'n')]
# words: [('q', 'n'), ('al', 'n'), ('afl', 'n'), ('grand', 'a'), ('final', 'a'), ('preview', 'n')]
# words: [('rugby', 'n'), ('captains', 'n'), ('join', 'v'), ('campaign', 'n'), ('promote', 'v'), ('sdgs', 'n')]
# words: [('rugby', 'n'), ('centre', 'n')]
# words: [('aquino', 'n'), ('proclaimed', 'v'), ('philippines', 'n'), ('president', 'n')]
# words: [('lions', 'n'), ('bent', 'n'), ('better', 'a'), ('start', 'n'), ('black', 'a')]
# words: [('saudi', 'n'), ('authorities', 'n'), ('arrest', 'v'), ('al', 'a'), ('qaeda', 'n'), ('linked', 'v')]
# words: [('defeat', 'n'), ('not', 'r'), ('option', 'n'), ('says', 'v'), ('elsom', 'n')]
# words: [('boat', 'n'), ('ramp', 'n'), ('follow', 'v')]
# words: [('turbulence', 'n'), ('shakes', 'n'), ('passengers', 'n'), ('seats', 'n')]
# words: [('al', 'n'), ('qaeda', 'n'), ('prison', 'n'), ('escape', 'n'), ('detailed', 'v'), ('court', 'n'), ('martial', 'n')]
# words: [('killed', 'v'), ('china', 'n'), ('quake', 'v')]
# words: [('die', 'n'), ('nt', 'a'), ('road', 'n'), ('accidents', 'n')]
# words: [('nrn', 'a'), ('dist', 'n'), ('china', 'n'), ('wheat', 'n')]
# words: [('novovirus', 'a'), ('situation', 'n'), ('slowly', 'r'), ('improving', 'v'), ('qld', 'n')]
# words: [('perry', 'n'), ('saves', 'v'), ('sky', 'a'), ('blues', 'n')]
# words: [('russian', 'a'), ('rocket', 'n'), ('lifts', 'n'), ('israeli', 'a'), ('satellite', 'n'), ('space', 'n')]
# words: [('labor', 'n'), ('takes', 'v'), ('credit', 'n'), ('highway', 'n'), ('premier', 'n')]
# words: [('vera', 'n'), ('drake', 'n'), ('cleans', 'v'), ('london', 'n'), ('awards', 'n')]
# words: [('heavy', 'a'), ('rain', 'n'), ('drenches', 'n'), ('far', 'r'), ('north', 'a'), ('qld', 'n')]
# words: [('hendra', 'n'), ('virus', 'n'), ('quartantine', 'n'), ('be', 'v'), ('lifted', 'v')]
# words: [('perth', 'n'), ('service', 'n'), ('mark', 'v'), ('years', 'n'), ('long', 'r'), ('tan', 'n')]
# words: [('ferrari', 'n'), ('dominate', 'v'), ('malaysia', 'v'), ('too', 'r'), ('barrichello', 'a')]
# words: [('mcguire:', 'n'), ('good', 'a'), ('footy', 'n')]
# words: [('gunns', 'n'), ('comment', 'n'), ('sale', 'n')]
# words: [('boomers', 'n'), ('lose', 'v'), ('second', 'a'), ('match', 'n'), ('greece', 'n')]
# words: [('political', 'a'), ('fray', 'n')]
# words: [('non', 'r'), ('stick', 'a'), ('gum', 'n'), ('step', 'n'), ('closer', 'r')]
# words: [('royal', 'a'), ('commission', 'n'), ('hold', 'v'), ('hearings', 'n'), ('child', 'n'), ('sex', 'n'), ('abuse', 'n'), ('darwin', 'n')]
# words: [('bluescope', 'n'), ('furnace', 'n'), ('upgrade', 'n'), ('cost', 'v')]
# words: [('investigation', 'n'), ('called', 'v'), ('prison', 'n'), ('assault', 'n')]
# words: [('union', 'n'), ('accusing', 'v'), ('costa', 'a'), ('group', 'n'), ('undercutting', 'v'), ('workplace', 'n'), ('conditions', 'n')]
# words: [('turtle', 'a'), ('death', 'n'), ('sparks', 'n'), ('renewed', 'v'), ('call', 'n'), ('container', 'n')]
# words: [('darchinyan', 'n'), ('retains', 'v'), ('superfly', 'a'), ('titles', 'n')]
# words: [('lucas', 'n'), ('height', 'v'), ('nuclear', 'a'), ('reactor', 'n'), ('closed', 'v')]
# words: [('verrender', 'n'), ('demoralising', 'v'), ('time', 'n'), ('be', 'v'), ('prime', 'a'), ('minister', 'n')]
# words: [('residents', 'n'), ('want', 'v'), ('brakes', 'n'), ('put', 'v'), ('rv', 'n'), ('stopping', 'v'), ('area', 'n')]
# words: [('flying', 'v'), ('foxes', 'n'), ('die', 'v'), ('heat', 'n'), ('stress', 'n'), ('eastern', 'a'), ('victoria', 'n')]
# words: [('changes', 'n'), ('snowy', 'v'), ('hydro', 'a'), ('licence', 'n'), ('challenged', 'v')]
# words: [('bunbury', 'n'), ('minimum', 'a'), ('security', 'n'), ('prison', 'n'), ('get', 'v'), ('revamp', 'v')]
# words: [('plane', 'n'), ('damaged', 'v'), ('crash', 'n')]
# words: [('rangers', 'n'), ('go', 'v'), ('down', 'r'), ('fire', 'v')]
# words: [('anti', 'a'), ('nuclear', 'a'), ('protesters', 'n'), ('disperse', 'v'), ('police', 'n'), ('standoff', 'r')]
# words: [('queenslanders', 'n'), ('urged', 'v'), ('be', 'v'), ('tolerant', 'a'), ('towards', 'n'), ('muslims', 'n')]
# words: [('mcardle', 'a'), ('congratulates', 'n'), ('springborg', 'v'), ('return', 'n')]
# words: [('organic', 'a'), ('farming', 'n'), ('rise', 'n'), ('report', 'n')]
# words: [('sonny', 'a'), ('bill', 'n'), ('not', 'r'), ('sold', 'v'), ('abs', 'n')]
# words: [('sub', 'n'), ('contractors', 'n'), ('claims', 'n'), ('assessed', 'v')]
# words: [('pro', 'a'), ('choice', 'n'), ('petition', 'n'), ('wont', 'n'), ('go', 'v'), ('parliament', 'n')]
# words: [('australian', 'a'), ('consulate', 'n'), ('indonesia', 'a'), ('boosts', 'n'), ('security', 'n'), ('threat', 'n')]
# words: [('detective', 'n'), ('named', 'v'), ('aom', 'n')]
# words: [('food', 'n'), ('safety', 'n'), ('seminar', 'n')]
# words: [('lowan', 'n'), ('mp', 'n'), ('emma', 'n'), ('kealy', 'n'), ('keen', 'n'), ('talks', 'n'), ('depi', 'n')]
# words: [('iraqis', 'n'), ('killed', 'v'), ('najaf', 'a'), ('blast', 'n')]
# words: [('trayvon', 'n'), ('martins', 'v'), ('killer', 'v'), ('george', 'n'), ('zimmerman', 'n'), ('questioned', 'v'), ('police', 'n')]
# words: [('australian', 'a'), ('play', 'n'), ('packer', 'n'), ('sons', 'n'), ('james', 'n'), ('packer', 'v'), ('kerry', 'n'), ('packer', 'n')]
# words: [('sorenstam', 'n'), ('wins', 'v'), ('lpga', 'a'), ('championship', 'n'), ('fifth', 'a'), ('major', 'a')]
# words: [('women', 'n'), ('remove', 'v'), ('pants', 'n'), ('swazi', 'a'), ('king', 'n')]
# words: [('bangladeshi', 'n'), ('deputy', 'n'), ('opposition', 'n'), ('leader', 'n'), ('arrested', 'v')]
# words: [('closer', 'r'), ('pm1', 'n')]
# words: [('australia', 'n'), ('treating', 'v'), ('bpd', 'n'), ('researcher', 'n'), ('says', 'v')]
# words: [('sneaky', 'a'), ('stray', 'n'), ('cats', 'n'), ('take', 'v'), ('main', 'a'), ('stage', 'n'), ('ahead', 'r'), ('g20', 'a'), ('summit', 'n')]
# words: [('police', 'n'), ('investigate', 'v'), ('mylestom', 'n'), ('club', 'n'), ('robbery', 'n')]
# words: [('hawks', 'n'), ('launch', 'n'), ('season', 'n'), ('style', 'n'), ('point', 'n'), ('win', 'n'), ('lions', 'n')]
# words: [('mps', 'n'), ('take', 'v'), ('concerns', 'n'), ('local', 'a'), ('govt', 'n'), ('minister', 'n')]
# words: [('key', 'a'), ('considers', 'n'), ('recommitting', 'v'), ('troops', 'n'), ('afghanistan', 'v')]
# words: [('police', 'n'), ('probe', 'n'), ('attacks', 'n'), ('gold', 'n'), ('coast', 'n'), ('joggers', 'n')]
# words: [('jim', 'n'), ('keays', 'n'), ('raw', 'v')]
# words: [('go', 'v'), ('unbeaten', 'a'), ('ponting', 'n')]
# words: [('interview', 'n'), ('isaac', 'n'), ('luke', 'n')]
# words: [('asbestos', 'n'), ('still', 'r'), ('massive', 'a'), ('problem', 'n'), ('nsw', 'a'), ('north', 'a'), ('coast', 'n')]
# words: [('zimbabwe', 'n'), ('results', 'n'), ('not', 'r'), ('released', 'v'), ('sub', 'a'), ('judice', 'n'), ('grounds', 'n')]
# words: [('hewitt', 'n'), ('cleared', 'v'), ('doubts', 'n'), ('remain', 'v')]
# words: [('gunfire', 'n'), ('erupts', 'n'), ('south', 'a'), ('sudan', 'n'), ('ceasefire', 'n'), ('talks', 'n'), ('begin', 'v')]
# words: [('colorado', 'n'), ('group', 'n'), ('sale', 'n')]
# words: [('martyn', 'n'), ('skipper', 'v'), ('warriors', 'n')]
# words: [('queensland', 'n'), ('wont', 'n'), ('give', 'v'), ('bid', 'n'), ('eradicate', 'v'), ('cattle', 'n')]
# words: [('iron', 'n'), ('firm', 'n'), ('wary', 'n'), ('resources', 'n'), ('tax', 'n')]
# words: [('cats', 'n'), ('take', 'v'), ('points', 'n'), ('fighting', 'v'), ('tigers', 'n')]
# words: [('energy', 'n'), ('giant', 'n'), ('promises', 'n'), ('clean', 'v'), ('gasworks', 'n'), ('site', 'n'), ("'properly'", 'n')]
# words: [('cumnock', 'n'), ('dry', 'n'), ('dams', 'v'), ('almost', 'r'), ('empty', 'a')]
# words: [('atlas', 'n'), ('iron', 'n'), ('records', 'n'), ('slump', 'n'), ('profits', 'n')]
# words: [('wednesday', 'n'), ('weather', 'n')]
# words: [('progress', 'n'), ('made', 'v'), ('reducing', 'v'), ('animal', 'a'), ('numbers', 'n')]
# words: [('queensland', 'n'), ('film', 'n'), ('festival', 'n'), ('program', 'n'), ('dominated', 'v'), ('women', 'n'), ('filmmakers', 'n')]
# words: [('police', 'n'), ('renew', 'v'), ('search', 'n'), ('vaughans', 'n'), ('remains', 'n')]
# words: [('fluoride', 'a'), ('opponents', 'n'), ('brush', 'v'), ('plan', 'n')]
# words: [('streeton', 'n'), ('tipped', 'v'), ('top', 'a'), ('dollar', 'n'), ('fosters', 'n'), ('sell', 'v')]
# words: [('civoniceva', 'n'), ('miss', 'v'), ('manly', 'r'), ('clash', 'n')]
# words: [('church', 'n'), ('bells', 'n'), ('take', 'v'), ('toll', 'n'), ('neighbourhood', 'n')]
# words: [('oconnell', 'r'), ('wharf', 'r'), ('close', 'v'), ('revamp', 'n')]
# words: [('traders', 'n'), ('dont', 'v'), ('want', 'a'), ('intersection', 'n'), ('black', 'a'), ('spot', 'n'), ('closed', 'v')]
# words: [('planning', 'v'), ('conference', 'n')]
# words: [('hodgman', 'v'), ('says', 'v'), ('labor', 'n'), ('has', 'v'), ('acted', 'v'), ('dishonourably', 'r')]
# words: [('changes', 'n'), ('recommended', 'v'), ('workers', 'n'), ('comp', 'n')]
# words: [('nt', 'r'), ('gearing', 'v'), ('cyclone', 'n')]
# words: [('stakeholders', 'n'), ('agree', 'v'), ('traditional', 'a'), ('hunting', 'n'), ('limits', 'n')]
# words: [('councillor', 'n'), ('seeks', 'v'), ('changed', 'v'), ('hand', 'n'), ('held', 'v'), ('hosing', 'n'), ('hours', 'n')]
# words: [('detains', 'v'), ('iraqi', 'a'), ('journalists', 'n'), ('misunderstanding', 'v')]
# words: [('grant', 'n'), ('hackett', 'n'), ('says', 'v'), ('return', 'n')]
# words: [('police', 'n'), ('find', 'v'), ('eva', 'a'), ('perons', 'n'), ('stolen', 'v'), ('jewels', 'n')]
# words: [('baby', 'n'), ('missing', 'v'), ('alice', 'a'), ('springs', 'n'), ('found', 'v'), ('safe', 'a'), ('western', 'a'), ('australia', 'n')]
# words: [('ben', 'n'), ('lomond', 'n'), ('ski', 'n'), ('season', 'n'), ('closes', 'v'), ('high', 'a')]
# words: [('interview', 'n'), ('stephanie', 'n'), ('rice', 'n')]
# words: [('record', 'n'), ('low', 'a'), ('atm', 'a'), ('usage', 'n'), ('suggest', 'v'), ('rise', 'n'), ('cashless', 'a'), ('payment', 'n'), ('systems', 'n')]
# words: [('modest', 'a'), ('budget', 'n'), ('boost', 'n'), ('nt', 'a'), ('regions', 'n')]
# words: [('docs', 'n'), ('drops', 'v'), ('pursuit', 'n'), ('anti', 'a'), ('vaccine', 'n'), ('couple', 'n')]
# words: [('djokovic', 'n'), ('breezes', 'v'), ('past', 'a'), ('ferrer', 'n'), ('final', 'a')]
# words: [('fact', 'n'), ('check', 'n'), ('is', 'v'), ('australia', 'v'), ('breach', 'n'), ('anti', 'a'), ('corruption', 'n'), ('obligations', 'n')]
# words: [('black', 'a'), ('caps', 'n'), ('crush', 'a'), ('zimbabwe', 'n'), ('wickets', 'n'), ('second', 'a'), ('odi', 'n')]
# words: [('volcanologists', 'n'), ('spy', 'v'), ('pink', 'v'), ('dinosaur', 'n'), ('remote', 'n'), ('webcam', 'n')]
# words: [('police', 'n'), ('arrest', 'v'), ('dead', 'a'), ('canoeist', 'n')]
# words: [('p', 'n'), ('plate', 'n'), ('curfew', 'n'), ('proposal', 'n'), ('parked', 'v'), ('premier', 'n')]
# words: [('injured', 'a'), ('wilkinson', 'n'), ('desperate', 'n'), ('tour', 'v'), ('new', 'a'), ('zealand', 'n')]
# words: [('contador', 'n'), ('set', 'v'), ('tour', 'n'), ('spain', 'n'), ('triumph', 'n')]
# words: [('headbutt', 'n'), ('lands', 'v'), ('footy', 'a'), ('player', 'n'), ('court', 'n')]
# words: [('brumbies', 'n'), ('outrun', 'v'), ('lions', 'n')]
# words: [('vanuatu', 'n'), ('ladies', 'n'), ('cricket', 'v')]
# words: [('mitchell', 'n'), ('starc', 'n'), ('biggest', 'a'), ('weapon', 'n'), ('mitchell', 'n'), ('india', 'n'), ('australia', 'n')]
# words: [('wage', 'n'), ('growth', 'n'), ('steady', 'a'), ('abs', 'n')]
# words: [('rudan', 'n'), ('named', 'v'), ('captain', 'n'), ('sydney', 'n'), ('fc', 'n'), ('look', 'v'), ('yorke', 'n')]
# words: [('nowra', 'a'), ('speedway', 'n'), ('hosts', 'n'), ('ny', 'v'), ('sprintcar', 'n'), ('showdown', 'n')]
# words: [('woman', 'n'), ('suspected', 'v'), ('murdering', 'v'), ('husband', 'n'), ('others', 'n')]
# words: [('friends', 'n'), ('rally', 'v'), ('kylie', 'n')]
# words: [('police', 'n'), ('search', 'n'), ('robbers', 'n')]
# words: [('act', 'a'), ('election', 'n'), ('countdown', 'n'), ('begins', 'n')]
# words: [('search', 'n'), ('underway', 'n'), ('people', 'n'), ('missing', 'v'), ('sa', 'n'), ('bush', 'n')]
# words: [('pervez', 'n'), ('musharraf', 'n'), ('back', 'r'), ('pakistan', 'n'), ('exile', 'n')]
# words: [('man', 'n'), ('front', 'v'), ('court', 'n'), ('accused', 'v'), ('shooting', 'v'), ('man', 'n'), ('face', 'n')]
# words: [('minister', 'n'), ('backs', 'n'), ('dec', 'v'), ('head', 'n')]
# after drop and lemmatization
#                                              headline_text  \
# 773630                 holman heroics save socceroos skins
# 277869      cultural background affects ones health report
# 28030              row brews over radiation therapy delays
# 1066306  liberal mp isobel redmond to retire at 2018 st...
# 194278     waste plan review to consider recycling options
#
#                                             preprocessed
# 773630                 holman heroic save socceroos skin
# 277869      cultural background affect one health report
# 28030                   row brew radiation therapy delay
# 1066306  liberal mp isobel redmond retire state election
# 194278         waste plan review consider recycle option
# this word does not exists in corpus: 'cowardly at ['png', 'government', 'tactic', "'cowardly"]
# this word does not exists in corpus: nassars at ['larry', 'nassars', 'huge', 'sentence', 'feel', 'victory', 'too']
# this word does not exists in corpus: berra; at ['yogi', 'berra;', 'new', 'york', 'yankee', 'legend;', 'dy', 'age']
# this word does not exists in corpus: legend; at ['yogi', 'berra;', 'new', 'york', 'yankee', 'legend;', 'dy', 'age']
# this word does not exists in corpus: risk: at ['thousand', 'shipbuilding', 'job', 'risk:', 'union']
# this word does not exists in corpus: campdrafts at ['outback', 'campdrafts', 'big', 'business', 'horse', 'owner']
# this word does not exists in corpus: mine: at ['turf', 'mine:', 'wyong', 'farmer', 'fear']
# this word does not exists in corpus: matautaavas at ['matautaavas', 'amaze', 'effort', 'power', 'vanuatu', 'wcl']
# this word does not exists in corpus: care: at ['refugee', 'receive', 'adequate', 'care:', 'dept']
# this word does not exists in corpus: novovirus at ['novovirus', 'situation', 'slowly', 'improve', 'qld']
# this word does not exists in corpus: quartantine at ['hendra', 'virus', 'quartantine', 'be', 'lift']
# this word does not exists in corpus: mcguire: at ['mcguire:', 'good', 'footy']
# this word does not exists in corpus: verrender at ['verrender', 'demoralise', 'time', 'be', 'prime', 'minister']
# this word does not exists in corpus: pm1 at ['closer', 'pm1']
# this word does not exists in corpus: g20 at ['sneaky', 'stray', 'cat', 'take', 'main', 'stage', 'ahead', 'g20', 'summit']
# this word does not exists in corpus: mylestom at ['police', 'investigate', 'mylestom', 'club', 'robbery']
# this word does not exists in corpus: 'properly' at ['energy', 'giant', 'promise', 'clean', 'gasworks', 'site', "'properly'"]
# (401, 300)

# %%
data
# Out:
#                                              headline_text  \
# 773630                 holman heroics save socceroos skins
# 277869      cultural background affects ones health report
# 28030              row brews over radiation therapy delays
# 1066306  liberal mp isobel redmond to retire at 2018 st...
# 194278     waste plan review to consider recycling options
# ...                                                    ...
# 646698                       act election countdown begins
# 353514       search underway for people missing in sa bush
# 773379       pervez musharraf back in pakistan after exile
# 928084   man to front court accused of shooting man in ...
# 655905                             minister backs dec head
#
#                                             preprocessed
# 773630                 holman heroic save socceroos skin
# 277869      cultural background affect one health report
# 28030                   row brew radiation therapy delay
# 1066306  liberal mp isobel redmond retire state election
# 194278         waste plan review consider recycle option
# ...                                                  ...
# 646698                      act election countdown begin
# 353514               search underway people miss sa bush
# 773379              pervez musharraf back pakistan exile
# 928084             man front court accuse shoot man face
# 655905                            minister back dec head
#
# [400 rows x 2 columns]

# %%
df_vec = pd.DataFrame(vec)
df_vec
# Out:
#           0         1         2         3         4         5         6    \
# 0   -0.025192  0.100360 -0.220985  0.216720 -0.375728 -0.136017  0.469670
# 1   -0.042216  0.007807 -0.323374  0.239274 -0.171238 -0.051610 -0.085143
# 2   -0.092368 -0.189523 -0.009720  0.183215 -0.029319 -0.023563 -0.049403
# 3   -0.069223  0.120941 -0.256029  0.106836 -0.199290 -0.129381  0.045415
# 4   -0.084492 -0.263232 -0.093723  0.007081  0.005129 -0.178735  0.145290
# ..        ...       ...       ...       ...       ...       ...       ...
# 396 -0.092496 -0.161918  0.003437 -0.000338 -0.166313  0.000480 -0.029617
# 397 -0.211835 -0.118695 -0.201009  0.076824 -0.137734 -0.019259  0.097436
# 398  0.097125 -0.312537  0.036275  0.334059 -0.105306 -0.130261 -0.055160
# 399 -0.071388 -0.058593 -0.179957  0.154407 -0.176266  0.012906 -0.027642
# 400 -0.125740 -0.322405 -0.163025  0.038425 -0.088402  0.012159  0.037578
#
#           7         8         9    ...       290       291       292  \
# 0   -0.395489  0.293971 -0.341170  ...  0.104766 -0.089663 -0.246274
# 1    0.053878 -0.024637  0.036788  ... -0.028024 -0.056563  0.112036
# 2   -0.176174  0.098500  0.145629  ...  0.094414  0.133662  0.143568
# 3   -0.080313  0.204904  0.049175  ...  0.124354 -0.031129  0.090552
# 4   -0.264792 -0.215830  0.267448  ...  0.167543  0.006900  0.185153
# ..        ...       ...       ...  ...       ...       ...       ...
# 396 -0.036378 -0.172753 -0.019287  ...  0.189887  0.086398 -0.027365
# 397 -0.302849 -0.101496 -0.075175  ...  0.010582  0.061602 -0.042718
# 398 -0.418767 -0.419265  0.156148  ... -0.241456  0.164796  0.060799
# 399 -0.047768  0.063605  0.137224  ...  0.031463 -0.054614  0.078948
# 400 -0.025443  0.033848  0.040842  ...  0.156933 -0.192533  0.269014
#
#           293       294       295       296       297       298       299
# 0    0.206871  0.549405 -0.171528 -0.151983  0.137993  0.223821  0.065391
# 1   -0.002028 -0.073680 -0.021632 -0.097797  0.187835  0.106588  0.096950
# 2   -0.100534  0.055244 -0.067328 -0.073239  0.133813  0.188375 -0.091567
# 3   -0.103008 -0.142635 -0.183100  0.087854  0.279785  0.337483  0.008798
# 4    0.171885  0.002973 -0.154298 -0.139211 -0.134581  0.106265  0.065847
# ..        ...       ...       ...       ...       ...       ...       ...
# 396  0.004651 -0.029130 -0.032107 -0.197571 -0.112846  0.156353  0.233766
# 397 -0.019891 -0.079696 -0.068846 -0.277174  0.194296  0.054312 -0.026135
# 398 -0.306069  0.421134 -0.226880 -0.390187 -0.001768 -0.145094  0.127011
# 399 -0.000712  0.001410 -0.121144 -0.231274  0.182183  0.064684  0.041597
# 400  0.136275  0.161677 -0.265520 -0.182618  0.049300 -0.149497  0.269109
#
# [401 rows x 300 columns]

# %%
len(sentences), sentences
# Out:
# (401,
#  [['preprocessed'],
#   ['holman', 'heroic', 'save', 'socceroos', 'skin'],
#   ['cultural', 'background', 'affect', 'one', 'health', 'report'],
#   ['row', 'brew', 'radiation', 'therapy', 'delay'],
#   ['liberal', 'mp', 'isobel', 'redmond', 'retire', 'state', 'election'],
#   ['waste', 'plan', 'review', 'consider', 'recycle', 'option'],
#   ['png', 'government', 'tactic', "'cowardly"],
#   ['local', 'council', 'advocate', 'social', 'change'],
#   ['climber', 'scale', 'trump', 'tower', 'suction', 'cap'],
#   ['larry', 'nassars', 'huge', 'sentence', 'feel', 'victory', 'too'],
#   ['security', 'camera', 'help', 'combat', 'stock', 'theft'],
#   ['brazil', 'court', 'appeal', 'athens', 'marathon', 'gold'],
#   ['lake', 'blue', 'green', 'algae', 'threat', 'remains'],
#   ['custom', 'software', 'stay', 'ellison', 'say'],
#   ['litchfield', 'take', 'drl', 'premiership'],
#   ['bronco', 'go', 'bang', 'whimper'],
#   ['geraldton', 'welcome', 'cctv', 'funding'],
#   ['minister', 'reassure', 'qld', 'rail', 'wind', 'back'],
#   ['ryan', 'european', 'crisis', 'thing', 'have', 'change'],
#   ['man', 'plead', 'not', 'guilty', 'alleged', 'drug', 'debt', 'bashing'],
#   ['family', 'shoot', 'dead', 'flee', 'syria'],
#   ['newcastle', 'lawyer', 'welcome', 'judge', 'appointment'],
#   ['appeal', 'dismiss', 'atm', 'robbery', 'case'],
#   ['snapper', 'fisher', 'fin'],
#   ['boost', 'legal', 'service', 'save', 'money', 'green'],
#   ['police', 'boost', 'effort', 'kyneton', 'event'],
#   ['relative', 'turn', 'age', 'care', 'complaint'],
#   ['zadie', 'smith', 'fiction', 'novel', 'short', 'story', 'white', 'teeth'],
#   ['blueberry', 'export', 'market', 'development', 'greg', 'mcculloch'],
#   ['federal', 'govt', 'urge', 'rethink', 'decision', 'not', 'fund'],
#   ['earthquake', 'strike', 'png'],
#   ['principal', 'question', 'value', 'parent', 'target', 'literacy', 'video'],
#   ['fink', 'jail', 'contempt', 'ccc'],
#   ['cash', 'staffer', 'resign', 'awu', 'raid'],
#   ['narromine', 'considers', 'stag', 'rollout', 'cctv'],
#   ['lee', 'summer'],
#   ['gunn', 'share', 'trade', 'again'],
#   ['big', 'plan', 'adelaide', 'airport', 'revamp'],
#   ['un', 'condemns', 'attack', 'syria'],
#   ['bobsleigh', 'worker', 'have', 'legs', 'break', 'crash'],
#   ['nt', 'benefit', 'raaf', 'base', 'upgrade'],
#   ['medium', 'caution', 'british', 'prisoner', 'abuse', 'case'],
#   ['top', 'story', 'abc', 'news'],
#   ['rain', 'delay', 'scg', 'test', 'again'],
#   ['fatal', 'crash', 'teen', 'victim', 'mourn', 'darwin', 'classmate'],
#   ['premier', 'say', 'public', 'service', 'job', 'go', 'new', 'rule'],
#   ['wood', 'cap', 'year', 'remember', 'eighth', 'victory'],
#   ['alice', 'council', 'step', 'push', 'non', 'sniff', 'petrol'],
#   ['round', 'league', 'too', 'close', 'call'],
#   ['committee', 'invite', 'patient', 'have', 'health', 'say'],
#   ['flinders',
#    'university',
#    'offer',
#    'early',
#    'retirement',
#    'package',
#    'staff'],
#   ['michael', 'bloomberg', 'make', 'worthy', 'presidential', 'candidate'],
#   ['fear', 'flood', 'funding', 'face', 'delay'],
#   ['indigenous', 'patient', 'confuse', 'kidney', 'disease'],
#   ['first', 'ashes', 'test', 'day', 'summary'],
#   ['beattie', 'defends', 'fast', 'track', 'ir', 'law'],
#   ['smoko', 'room', 'close', 'toxic', 'dust', 'fear'],
#   ['study', 'say', 'ewl', 'cut', 'travel', 'time'],
#   ['market', 'close', 'dollar', 'drag'],
#   ['burma', 'try', 'cool', 'international', 'pressure'],
#   ['momentum', 'set', 'build', 'wimbledon', 'second', 'week'],
#   ['trial', 'china', 'former', 'police', 'chief', 'begin'],
#   ['bardot', 'decries', 'polar', 'bear', 'hunt'],
#   ['apra', 'ask', 'bank', 'living', 'will'],
#   ['storm', 'kill', 'philippine'],
#   ['nsw', 'ombudsman', 'examines', 'care', 'death'],
#   ['teacher'],
#   ['opal', 'danger'],
#   ['steelers', 'canada', 'win', 'gold'],
#   ['halloran'],
#   ['green',
#    'group',
#    'aboriginal',
#    'land',
#    'council',
#    'protest',
#    'water',
#    'license'],
#   ['police', 'probe', 'fatal', 'rockhampton', 'crash'],
#   ['pedestrian', 'accident', 'put', 'woman', 'hospital'],
#   ['report', 'highlight', 'desire', 'change', 'wheat'],
#   ['council', 'ceo', 'bribe', 'evidence', 'inconsistent'],
#   ['car', 'lease', 'firm', 'face', 'uncertain', 'future'],
#   ['remains', 'shed', 'light', 'disappearance'],
#   ['wa', 'join', 'national', 'fight', 'salinity'],
#   ['health', 'service', 'urge', 'change', 'management', 'tack'],
#   ['man', 'dead', 'sydney', 'shooting'],
#   ['fire', 'alert', 'wind', 'pick'],
#   ['lismore', 'telstra'],
#   ['call', 'armidale', 'join', 'sentence', 'scheme'],
#   ['judge', 'criticises', 'law', 'maker', 'negligence', 'jail'],
#   ['andre', 'award', 'damage', 'cheating', 'claim'],
#   ['david', 'mcbride', 'speaks', 'court'],
#   ['fire', 'continue', 'burn', 'far', 'north', 'qld'],
#   ['gate', 'pledge', 'unclog', 'email', 'box'],
#   ['rspca', 'back', 'cull', 'feral', 'horse', 'wa'],
#   ['housing', 'woe', 'probe', 'take', 'broad', 'view'],
#   ['adapt', 'potentially', 'fatal', 'impulse', 'rescue', 'someone', 'drown'],
#   ['sixth', 'harry', 'potter', 'cast', 'spell', 'july'],
#   ['horse', 'flu', 'compensation', 'class', 'action', 'go', 'mediation'],
#   ['more', 'affordable', 'home', 'way'],
#   ['asx', 'fall', 'anz', 'cba', 'drag', 'share', 'market'],
#   ['church', 'celebrate', 'bishop', 'house', 'centenary'],
#   ['hargreaves', 'behaviour', 'debate', 'assembly'],
#   ['israel', 'hamas', 'battle', 'un', 'ceasefire', 'demand'],
#   ['wach', 'exmouth', 'banana', 'prawn'],
#   ['hamilton', 'edge', 'singapore', 'pole'],
#   ['tarting', 'nbn'],
#   ['emergency', 'beacon', 'false', 'alarm'],
#   ['horticulture', 'aquaponics', 'industry', 'wheatbelt'],
#   ['france', 'pinault', 'stay', 'top', 'art', 'world', 'power', 'list'],
#   ['south', 'sudan', 'celebration', 'mute', 'fifth', 'anniversary', 'found'],
#   ['yogi', 'berra;', 'new', 'york', 'yankee', 'legend;', 'dy', 'age'],
#   ['mineral', 'energy', 'export'],
#   ['un', 'imposes', 'weapon', 'sanction', 'north', 'korea'],
#   ['indigenous', 'culture', 'offer', 'mental', 'health', 'lesson'],
#   ['endanger',
#    'sea',
#    'lion',
#    'pup',
#    'make',
#    'public',
#    'debut',
#    'marine',
#    'park'],
#   ['not', 'guilty', 'plea', 'listeria', 'find'],
#   ['college', 'suffers', 'staff', 'shortage'],
#   ['mp', 'say', 'solar', 'switch', 'pull', 'plug', 'business'],
#   ['election', 'forum'],
#   ['study', 'highlight', 'council', 'road', 'maintenance', 'struggle'],
#   ['thomas', 'now', 'target', 'say', 'roos'],
#   ['b', 'j', 'bentley', 'cop', 'dumping', 'fine'],
#   ['hussey', 'langer', 'lead', 'warrior', 'fightback'],
#   ['arrest', 'warrant', 'issue', 'teen', 'accuse', 'sheep'],
#   ['mercurial', 'jones', 'lead', 'warrior', 'victory'],
#   ['drug', 'test', 'device', 'speed', 'detection'],
#   ['australian',
#    'worry',
#    'uncomfortable',
#    'retirement',
#    'lifestyle',
#    'survey'],
#   ['alcohol', 'plan', 'police', 'stop', 'cape', 'york', 'hell'],
#   ['wilcannia', 'work', 'scheme', 'be', 'model', 'other'],
#   ['concern', 'illegal', 'brothel', 'wa'],
#   ['torres', 'strait', 'islander', 'plan', 'compo', 'class', 'action'],
#   ['force', 'launch', 'attack', 'western', 'iraq'],
#   ['stephen', 'hawk', 'world', 'react', 'death', 'physicist'],
#   ['thousand', 'shipbuilding', 'job', 'risk:', 'union'],
#   ['administrator', 'appoint', 'wagga', 'land', 'council'],
#   ['woolshed', 'get', 'award', 'honour'],
#   ['pm', 'sweeten', 'health', 'plan'],
#   ['finance', 'quarter'],
#   ['thredbo', 'visitor', 'number', 'expect', 'bounce', 'back'],
#   ['japan', 'accuse', 'greenpeace', 'piracy'],
#   ['black', 'cap', 'duo', 'admit', 'role', 'india', 'riot'],
#   ['senior', 'police', 'officer', 'escape', 'internal', 'discipline'],
#   ['custom', 'combat', 'illegal', 'fishing', 'base', 'reef'],
#   ['staff', 'struggle', 'reduce', 'indigenous', 'smoking', 'rate'],
#   ['regional', 'driver', 'warn', 'fuel', 'price', 'rise'],
#   ['struggle', 'regional', 'school', 'miss', 'fund', 'mp'],
#   ['fall', 'wall', 'remember'],
#   ['animal', 'activist', 'renew', 'push', 'live', 'export', 'ban'],
#   ['resident', 'quick', 'oppose', 'speed', 'reduction', 'plan'],
#   ['bartlett', 'admit', 'more', 'mining', 'inspector', 'need'],
#   ['violence', 'continue', 'foreign', 'presence'],
#   ['kempsey',
#    'business',
#    'sector',
#    'optimistic',
#    'pacific',
#    'highway',
#    'bypass'],
#   ['diegos', 'metre', 'chip', 'earn', 'santos', 'libertadores', 'draw'],
#   ['man', 'charge', 'baby', 'murder'],
#   ['researcher', 'enlist', 'koala', 'search', 'chlamydia'],
#   ['cyclist', 'charge', 'blow'],
#   ['clean', 'begin', 'nsw', 'storm'],
#   ['gibbs', 'face', 'ban', 'kneeing'],
#   ['xmas', 'retail', 'sign', 'pick'],
#   ['partnership', 'call', 'speed', 'land', 'release'],
#   ['cattle', 'station', 'murderer', 'set', 'walk', 'free'],
#   ['govt', 'fast', 'track', 'albany', 'hospital', 'work'],
#   ['outback', 'campdrafts', 'big', 'business', 'horse', 'owner'],
#   ['argentina', 'italy', 'hopman', 'cup', 'first', 'round'],
#   ['abare', 'launch', 'final', 'stage', 'grower', 'survey'],
#   ['perth', 'teen', 'photography', 'focus', 'attention', 'homelessness'],
#   ['turf', 'mine:', 'wyong', 'farmer', 'fear'],
#   ['tony', 'burke', 'rubbish', 'fairfax', 'asylum', 'seeker', 'report'],
#   ['town', 'honour', 'race', 'great', 'gunsynd'],
#   ['national', 'disability', 'insurance', 'scheme', 'promise', 'check'],
#   ['gillard', 'deny', 'scene', 'deal', 'green'],
#   ['australian', 'share', 'market', 'open', 'high'],
#   ['bland', 'mou'],
#   ['wagga', 'service', 'remembers', 'army', 'train', 'accident'],
#   ['adam', 'giles', 'plan', 'dump', 'bail', 'youth', 'slam', 'lawyer'],
#   ['interview', 'broadbent'],
#   ['push', 'farmer', 'get', 'storm', 'aid'],
#   ['vic', 'poppy', 'rule'],
#   ['council', 'order', 'environmental', 'probe', 'propose', 'marina'],
#   ['abc', 'entertainment'],
#   ['matautaavas', 'amaze', 'effort', 'power', 'vanuatu', 'wcl'],
#   ['graham',
#    'quirk',
#    'reject',
#    'claim',
#    'favourable',
#    'treatment',
#    'lnp',
#    'donor'],
#   ['fina', 'consider', 'hacketts', 'proposal'],
#   ['forum', 'focus', 'help', 'stressed', 'family'],
#   ['men', 'brace', 'beard', 'patrol', 'iraq', 'mosul'],
#   ['decision', 'hand', 'beattie', 'tell', 'palm'],
#   ['wild', 'dog', 'cost', 'recalculate', 'new', 'bait', 'set', 'release'],
#   ['swan', 'delivers', 'fair', 'go', 'budget', 'save', 'labor'],
#   ['cattle', 'drive', 'beef', 'overseas', 'interest'],
#   ['macqueen', 'confident', 'team', 'put', 'show'],
#   ['blair', 'athol', 'deli', 'staff', 'hold', 'man', 'needle'],
#   ['heart', 'patient', 'good', 'manage', 'rehab'],
#   ['search', 'car', 'fatal', 'sydney', 'hit', 'run'],
#   ['bureau', 'warns', 'damage', 'wind', 'nsw', 'act'],
#   ['flinders', 'emergency', 'department', 'operating', 'theatre'],
#   ['restriction', 'halt', 'water', 'parkland'],
#   ['rba', 'debelle', 'speech'],
#   ['youve', 'come', 'long', 'way', 'tony'],
#   ['nbn', 'satellite', 'offer', 'hope', 'fast', 'internet', 'outback'],
#   ['man', 'accuse', 'fatal', 'stab', 'pleads', 'not', 'guilty', 'murder'],
#   ['knight', 'defend', 'fortress', 'season', 'opener'],
#   ['lack', 'scale', 'crushing', 'ord', 'sugar', 'dream'],
#   ['council', 'approve', 'mill', 'development'],
#   ['trump',
#    'delivers',
#    'first',
#    'public',
#    'condemnation',
#    'anti',
#    'semitic',
#    'threat'],
#   ['cash', 'flow', 'ansett', 'worker'],
#   ['american',
#    'aid',
#    'worker',
#    'alan',
#    'go',
#    'welcome',
#    'cuban',
#    'relation',
#    'shift'],
#   ['groth', 'prepares', 'wimbledon', 'win', 'manchester', 'trophy'],
#   ['narendra', 'modi', 'declare', 'victory', 'indian', 'election'],
#   ['medicare', 'local', 'promise', 'more', 'health', 'funding'],
#   ['queensland', 'scientist', 'help', 'develop', 'new', 'polio', 'vaccine'],
#   ['doll', 'kidnapper', 'get', 'jail', 'time'],
#   ['exposure', 'particulate', 'matter', 'air', 'pollution', 'harmful'],
#   ['little', 'pebble', 'jail', 'sexual', 'abuse'],
#   ['grazier', 'want', 'beef', 'export', 'rockhampton', 'airport'],
#   ['drought', 'not', 'stop', 'big', 'field', 'day'],
#   ['interview', 'rob', 'simmons'],
#   ['research', 'turn', 'spotlight', 'binge', 'drinking'],
#   ['linden', 'funding'],
#   ['fifth', 'ash', 'test', 'day', 'live', 'blog'],
#   ['melbourne', 'face', 'public', 'transport', 'strike'],
#   ['poky', 'reform', 'undemocratic', 'say', 'club', 'head'],
#   ['police', 'nab', 'grandma', 'drug', 'dealer'],
#   ['lynx', 'win', 'battle', 'cellar', 'dweller'],
#   ['pele', 'hospital', 'improve'],
#   ['cloud', 'fire', 'create', 'weather'],
#   ['family', 'take', 'toxic', 'milk', 'deal', 'china', 'say'],
#   ['family', 'call', 'government', 'compassion', 'fight', 'save', 'girl'],
#   ['ethiopian', 'gun', 'battle', 'leave', 'dead'],
#   ['ibac', 'give', 'power', 'review', 'opi', 'matter'],
#   ['angry', 'police', 'demand', 'resignation', 'commissioner'],
#   ['hewitt', 'thump', 'aussie', 'bow'],
#   ['great', 'chop', 'challenge'],
#   ['man', 'arrest', 'duo', 'time', 'hour'],
#   ['gasnier', 'dismisses', 'wigan', 'link'],
#   ['nasty', 'battle', 'be', 'shape', 'control'],
#   ['search', 'ibac', 'bos', 'continue'],
#   ['beachside', 'promenade', 'work', 'uncover', 'historic', 'railway'],
#   ['health', 'quarter'],
#   ['car',
#    'bomb',
#    'kill',
#    'maltese',
#    'journalist',
#    'expose',
#    'panama',
#    'paper',
#    'link'],
#   ['analyse', 'vanuatu', 'election', 'result'],
#   ['refugee', 'receive', 'adequate', 'care:', 'dept'],
#   ['ben', 'zygier', 'suspect', 'double', 'agent', 'source'],
#   ['iraqi', 'guard', 'kill', 'russian', 'kidnap'],
#   ['magistrate', 'dismisses', 'charge', 'bomb', 'threat', 'case'],
#   ['parental', 'leave', 'open', 'abortion', 'rorts', 'field'],
#   ['asian', 'business', 'group', 'bid', 'whitsunday', 'casino'],
#   ['abc', 'lord', 'switch', 'mic'],
#   ['world', 'trade', 'talk', 'jeopardy'],
#   ['neal', 'coalition', 'firing', 'line'],
#   ['kakadu', 'plum', 'be', 'way', 'forward'],
#   ['fomer', 'grazier', 'turn', 'egg', 'producer', 'crack', 'egg', 'industry'],
#   ['dead', 'digger', 'dad', 'want', 'australia', 'stay', 'course'],
#   ['police', 'inquire', 'sexual', 'assault', 'claim'],
#   ['share', 'wall', 'st', 'slip', 'trade', 'war', 'fear'],
#   ['nobel', 'prize', 'physic', 'award', 'work', 'laser'],
#   ['file', 'share', 'debate', 'divide', 'british', 'pop', 'star'],
#   ['wombat', 'disease', 'weed', 'crisis', 'meeting'],
#   ['joey', 'clear'],
#   ['goldfield', 'police', 'ready', 'easter', 'road', 'blitz'],
#   ['bias', 'reporting', 'gaza', 'conflict'],
#   ['teen', 'critical', 'condition', 'allege', 'home'],
#   ['reward', 'bowraville', 'death', 'increase'],
#   ['rail', 'accident', 'report', 'month', 'away'],
#   ['man', 'charge', 'darwin', 'murder'],
#   ['die', 'crash', 'peakhurst'],
#   ['drought', 'hit', 'community', 'plea', 'tourist', 'visit'],
#   ['vidic', 'hand', 'game', 'champion', 'league', 'ban'],
#   ['tv', 'film', 'spoiler', 'be', 'less', 'important', 'think', 'research'],
#   ['liberal', 'minister', 'nuclear', 'power'],
#   ['studio', 'satyajit', 'da'],
#   ['bupa', 'ceo', 'say', 'sorry', 'age', 'care', 'resident', 'do'],
#   ['vector', 'borne', 'disease', 'estimate', 'cause', 'more'],
#   ['north', 'korea', 'history', 'explain'],
#   ['former', 'chaplain', 'find', 'not', 'guilty', 'sexual', 'abuse'],
#   ['richard', 'colbeck', 'india', 'trade'],
#   ['heritage', 'sale', 'scrutiny'],
#   ['karl',
#    'anthony',
#    'town',
#    'take',
#    'minnesota',
#    'timberwolves',
#    'first',
#    'p'],
#   ['q', 'al', 'afl', 'grand', 'final', 'preview'],
#   ['rugby', 'captain', 'join', 'campaign', 'promote', 'sdgs'],
#   ['rugby', 'centre'],
#   ['aquino', 'proclaim', 'philippine', 'president'],
#   ['lion', 'bent', 'good', 'start', 'black'],
#   ['saudi', 'authority', 'arrest', 'al', 'qaeda', 'link'],
#   ['defeat', 'not', 'option', 'say', 'elsom'],
#   ['boat', 'ramp', 'follow'],
#   ['turbulence', 'shake', 'passenger', 'seat'],
#   ['al', 'qaeda', 'prison', 'escape', 'detail', 'court', 'martial'],
#   ['kill', 'china', 'quake'],
#   ['die', 'nt', 'road', 'accident'],
#   ['nrn', 'dist', 'china', 'wheat'],
#   ['novovirus', 'situation', 'slowly', 'improve', 'qld'],
#   ['perry', 'save', 'sky', 'blue'],
#   ['russian', 'rocket', 'lift', 'israeli', 'satellite', 'space'],
#   ['labor', 'take', 'credit', 'highway', 'premier'],
#   ['vera', 'drake', 'clean', 'london', 'award'],
#   ['heavy', 'rain', 'drenches', 'far', 'north', 'qld'],
#   ['hendra', 'virus', 'quartantine', 'be', 'lift'],
#   ['perth', 'service', 'mark', 'year', 'long', 'tan'],
#   ['ferrari', 'dominate', 'malaysia', 'too', 'barrichello'],
#   ['mcguire:', 'good', 'footy'],
#   ['gunns', 'comment', 'sale'],
#   ['boomer', 'lose', 'second', 'match', 'greece'],
#   ['political', 'fray'],
#   ['non', 'stick', 'gum', 'step', 'closer'],
#   ['royal',
#    'commission',
#    'hold',
#    'hearing',
#    'child',
#    'sex',
#    'abuse',
#    'darwin'],
#   ['bluescope', 'furnace', 'upgrade', 'cost'],
#   ['investigation', 'call', 'prison', 'assault'],
#   ['union', 'accuse', 'costa', 'group', 'undercut', 'workplace', 'condition'],
#   ['turtle', 'death', 'spark', 'renew', 'call', 'container'],
#   ['darchinyan', 'retain', 'superfly', 'title'],
#   ['lucas', 'height', 'nuclear', 'reactor', 'close'],
#   ['verrender', 'demoralise', 'time', 'be', 'prime', 'minister'],
#   ['resident', 'want', 'brake', 'put', 'rv', 'stop', 'area'],
#   ['fly', 'fox', 'die', 'heat', 'stress', 'eastern', 'victoria'],
#   ['change', 'snowy', 'hydro', 'licence', 'challenge'],
#   ['bunbury', 'minimum', 'security', 'prison', 'get', 'revamp'],
#   ['plane', 'damage', 'crash'],
#   ['ranger', 'go', 'down', 'fire'],
#   ['anti', 'nuclear', 'protester', 'disperse', 'police', 'standoff'],
#   ['queenslanders', 'urge', 'be', 'tolerant', 'towards', 'muslim'],
#   ['mcardle', 'congratulates', 'springborg', 'return'],
#   ['organic', 'farming', 'rise', 'report'],
#   ['sonny', 'bill', 'not', 'sell', 'ab'],
#   ['sub', 'contractor', 'claim', 'assess'],
#   ['pro', 'choice', 'petition', 'wont', 'go', 'parliament'],
#   ['australian', 'consulate', 'indonesia', 'boost', 'security', 'threat'],
#   ['detective', 'name', 'aom'],
#   ['food', 'safety', 'seminar'],
#   ['lowan', 'mp', 'emma', 'kealy', 'keen', 'talk', 'depi'],
#   ['iraqi', 'kill', 'najaf', 'blast'],
#   ['trayvon',
#    'martins',
#    'killer',
#    'george',
#    'zimmerman',
#    'question',
#    'police'],
#   ['australian',
#    'play',
#    'packer',
#    'son',
#    'james',
#    'packer',
#    'kerry',
#    'packer'],
#   ['sorenstam', 'win', 'lpga', 'championship', 'fifth', 'major'],
#   ['woman', 'remove', 'pant', 'swazi', 'king'],
#   ['bangladeshi', 'deputy', 'opposition', 'leader', 'arrest'],
#   ['closer', 'pm1'],
#   ['australia', 'treat', 'bpd', 'researcher', 'say'],
#   ['sneaky',
#    'stray',
#    'cat',
#    'take',
#    'main',
#    'stage',
#    'ahead',
#    'g20',
#    'summit'],
#   ['police', 'investigate', 'mylestom', 'club', 'robbery'],
#   ['hawk', 'launch', 'season', 'style', 'point', 'win', 'lion'],
#   ['mp', 'take', 'concern', 'local', 'govt', 'minister'],
#   ['key', 'considers', 'recommit', 'troop', 'afghanistan'],
#   ['police', 'probe', 'attack', 'gold', 'coast', 'jogger'],
#   ['jim', 'keays', 'raw'],
#   ['go', 'unbeaten', 'ponting'],
#   ['interview', 'isaac', 'luke'],
#   ['asbestos', 'still', 'massive', 'problem', 'nsw', 'north', 'coast'],
#   ['zimbabwe', 'result', 'not', 'release', 'sub', 'judice', 'ground'],
#   ['hewitt', 'clear', 'doubt', 'remain'],
#   ['gunfire', 'erupts', 'south', 'sudan', 'ceasefire', 'talk', 'begin'],
#   ['colorado', 'group', 'sale'],
#   ['martyn', 'skipper', 'warrior'],
#   ['queensland', 'wont', 'give', 'bid', 'eradicate', 'cattle'],
#   ['iron', 'firm', 'wary', 'resource', 'tax'],
#   ['cat', 'take', 'point', 'fight', 'tiger'],
#   ['energy', 'giant', 'promise', 'clean', 'gasworks', 'site', "'properly'"],
#   ['cumnock', 'dry', 'dam', 'almost', 'empty'],
#   ['atlas', 'iron', 'record', 'slump', 'profit'],
#   ['wednesday', 'weather'],
#   ['progress', 'make', 'reduce', 'animal', 'number'],
#   ['queensland',
#    'film',
#    'festival',
#    'program',
#    'dominate',
#    'woman',
#    'filmmaker'],
#   ['police', 'renew', 'search', 'vaughan', 'remains'],
#   ['fluoride', 'opponent', 'brush', 'plan'],
#   ['streeton', 'tip', 'top', 'dollar', 'foster', 'sell'],
#   ['civoniceva', 'miss', 'manly', 'clash'],
#   ['church', 'bell', 'take', 'toll', 'neighbourhood'],
#   ['oconnell', 'wharf', 'close', 'revamp'],
#   ['trader', 'dont', 'want', 'intersection', 'black', 'spot', 'close'],
#   ['plan', 'conference'],
#   ['hodgman', 'say', 'labor', 'have', 'act', 'dishonourably'],
#   ['change', 'recommend', 'worker', 'comp'],
#   ['nt', 'gear', 'cyclone'],
#   ['stakeholder', 'agree', 'traditional', 'hunting', 'limit'],
#   ['councillor', 'seek', 'change', 'hand', 'hold', 'hosing', 'hour'],
#   ['detain', 'iraqi', 'journalist', 'misunderstand'],
#   ['grant', 'hackett', 'say', 'return'],
#   ['police', 'find', 'eva', 'peron', 'steal', 'jewel'],
#   ['baby', 'miss', 'alice', 'spring', 'find', 'safe', 'western', 'australia'],
#   ['ben', 'lomond', 'ski', 'season', 'close', 'high'],
#   ['interview', 'stephanie', 'rice'],
#   ['record',
#    'low',
#    'atm',
#    'usage',
#    'suggest',
#    'rise',
#    'cashless',
#    'payment',
#    'system'],
#   ['modest', 'budget', 'boost', 'nt', 'region'],
#   ['doc', 'drop', 'pursuit', 'anti', 'vaccine', 'couple'],
#   ['djokovic', 'breeze', 'past', 'ferrer', 'final'],
#   ['fact',
#    'check',
#    'be',
#    'australia',
#    'breach',
#    'anti',
#    'corruption',
#    'obligation'],
#   ['black', 'cap', 'crush', 'zimbabwe', 'wicket', 'second', 'odi'],
#   ['volcanologists', 'spy', 'pink', 'dinosaur', 'remote', 'webcam'],
#   ['police', 'arrest', 'dead', 'canoeist'],
#   ['p', 'plate', 'curfew', 'proposal', 'park', 'premier'],
#   ['injured', 'wilkinson', 'desperate', 'tour', 'new', 'zealand'],
#   ['contador', 'set', 'tour', 'spain', 'triumph'],
#   ['headbutt', 'land', 'footy', 'player', 'court'],
#   ['brumbies', 'outrun', 'lion'],
#   ['vanuatu', 'lady', 'cricket'],
#   ['mitchell', 'starc', 'big', 'weapon', 'mitchell', 'india', 'australia'],
#   ['wage', 'growth', 'steady', 'ab'],
#   ['rudan', 'name', 'captain', 'sydney', 'fc', 'look', 'yorke'],
#   ['nowra', 'speedway', 'host', 'ny', 'sprintcar', 'showdown'],
#   ['woman', 'suspect', 'murder', 'husband', 'others'],
#   ['friend', 'rally', 'kylie'],
#   ['police', 'search', 'robber'],
#   ['act', 'election', 'countdown', 'begin'],
#   ['search', 'underway', 'people', 'miss', 'sa', 'bush'],
#   ['pervez', 'musharraf', 'back', 'pakistan', 'exile'],
#   ['man', 'front', 'court', 'accuse', 'shoot', 'man', 'face'],
#   ['minister', 'back', 'dec', 'head']])

# %%
#RNN => feature vector
# method1: average of dataframe
## this will ignore time sequence, just like CNN classifier, only get the vector

# %%
df_vec
# Out:
#           0         1         2         3         4         5         6    \
# 0   -0.025192  0.100360 -0.220985  0.216720 -0.375728 -0.136017  0.469670
# 1   -0.042216  0.007807 -0.323374  0.239274 -0.171238 -0.051610 -0.085143
# 2   -0.092368 -0.189523 -0.009720  0.183215 -0.029319 -0.023563 -0.049403
# 3   -0.069223  0.120941 -0.256029  0.106836 -0.199290 -0.129381  0.045415
# 4   -0.084492 -0.263232 -0.093723  0.007081  0.005129 -0.178735  0.145290
# ..        ...       ...       ...       ...       ...       ...       ...
# 396 -0.092496 -0.161918  0.003437 -0.000338 -0.166313  0.000480 -0.029617
# 397 -0.211835 -0.118695 -0.201009  0.076824 -0.137734 -0.019259  0.097436
# 398  0.097125 -0.312537  0.036275  0.334059 -0.105306 -0.130261 -0.055160
# 399 -0.071388 -0.058593 -0.179957  0.154407 -0.176266  0.012906 -0.027642
# 400 -0.125740 -0.322405 -0.163025  0.038425 -0.088402  0.012159  0.037578
#
#           7         8         9    ...       290       291       292  \
# 0   -0.395489  0.293971 -0.341170  ...  0.104766 -0.089663 -0.246274
# 1    0.053878 -0.024637  0.036788  ... -0.028024 -0.056563  0.112036
# 2   -0.176174  0.098500  0.145629  ...  0.094414  0.133662  0.143568
# 3   -0.080313  0.204904  0.049175  ...  0.124354 -0.031129  0.090552
# 4   -0.264792 -0.215830  0.267448  ...  0.167543  0.006900  0.185153
# ..        ...       ...       ...  ...       ...       ...       ...
# 396 -0.036378 -0.172753 -0.019287  ...  0.189887  0.086398 -0.027365
# 397 -0.302849 -0.101496 -0.075175  ...  0.010582  0.061602 -0.042718
# 398 -0.418767 -0.419265  0.156148  ... -0.241456  0.164796  0.060799
# 399 -0.047768  0.063605  0.137224  ...  0.031463 -0.054614  0.078948
# 400 -0.025443  0.033848  0.040842  ...  0.156933 -0.192533  0.269014
#
#           293       294       295       296       297       298       299
# 0    0.206871  0.549405 -0.171528 -0.151983  0.137993  0.223821  0.065391
# 1   -0.002028 -0.073680 -0.021632 -0.097797  0.187835  0.106588  0.096950
# 2   -0.100534  0.055244 -0.067328 -0.073239  0.133813  0.188375 -0.091567
# 3   -0.103008 -0.142635 -0.183100  0.087854  0.279785  0.337483  0.008798
# 4    0.171885  0.002973 -0.154298 -0.139211 -0.134581  0.106265  0.065847
# ..        ...       ...       ...       ...       ...       ...       ...
# 396  0.004651 -0.029130 -0.032107 -0.197571 -0.112846  0.156353  0.233766
# 397 -0.019891 -0.079696 -0.068846 -0.277174  0.194296  0.054312 -0.026135
# 398 -0.306069  0.421134 -0.226880 -0.390187 -0.001768 -0.145094  0.127011
# 399 -0.000712  0.001410 -0.121144 -0.231274  0.182183  0.064684  0.041597
# 400  0.136275  0.161677 -0.265520 -0.182618  0.049300 -0.149497  0.269109
#
# [401 rows x 300 columns]

# %%
df_ = df_vec.describe()
df_
# Out:
#               0           1           2           3           4           5    \
# count  401.000000  401.000000  401.000000  401.000000  401.000000  401.000000
# mean    -0.095547   -0.074184   -0.125072    0.171894   -0.133329    0.013321
# std      0.114695    0.126309    0.116858    0.111393    0.104305    0.120401
# min     -0.450379   -0.632769   -0.443189   -0.215559   -0.519985   -0.343233
# 25%     -0.168978   -0.143553   -0.204127    0.097889   -0.195826   -0.068800
# 50%     -0.097062   -0.064573   -0.130745    0.162787   -0.134583    0.012159
# 75%     -0.018767    0.001076   -0.048366    0.242841   -0.075525    0.097859
# max      0.405031    0.314218    0.356870    0.514291    0.207358    0.365577
#
#               6           7           8           9    ...         290  \
# count  401.000000  401.000000  401.000000  401.000000  ...  401.000000
# mean     0.030053   -0.148463   -0.044789    0.105181  ...    0.088252
# std      0.110572    0.127969    0.127150    0.117445  ...    0.116976
# min     -0.332102   -0.573074   -0.718343   -0.374328  ...   -0.298984
# 25%     -0.043687   -0.225703   -0.120792    0.035194  ...    0.020884
# 50%      0.018698   -0.144323   -0.041444    0.114958  ...    0.096158
# 75%      0.105859   -0.063553    0.033848    0.186209  ...    0.164557
# max      0.469670    0.333786    0.310687    0.450027  ...    0.553675
#
#               291         292         293         294         295         296  \
# count  401.000000  401.000000  401.000000  401.000000  401.000000  401.000000
# mean    -0.013725    0.079870    0.019978   -0.014581   -0.115680   -0.101476
# std      0.130968    0.118389    0.110495    0.114980    0.120257    0.101840
# min     -0.505446   -0.246274   -0.330600   -0.355333   -0.463338   -0.390187
# 25%     -0.089395   -0.008355   -0.056401   -0.091261   -0.194381   -0.172520
# 50%     -0.014218    0.085360    0.015907   -0.014986   -0.114595   -0.101267
# 75%      0.056644    0.155184    0.091832    0.050730   -0.038328   -0.040372
# max      0.491430    0.599578    0.471221    0.549405    0.210920    0.218374
#
#               297         298         299
# count  401.000000  401.000000  401.000000
# mean     0.154656    0.103135    0.028297
# std      0.126808    0.100834    0.111167
# min     -0.465604   -0.177589   -0.319669
# 25%      0.089996    0.041636   -0.041916
# 50%      0.157398    0.106265    0.031263
# 75%      0.231205    0.166630    0.099613
# max      0.471699    0.365460    0.446840
#
# [8 rows x 300 columns]

# %%
df_mean = df_.loc['mean']
df_mean
# Out:
# 0     -0.095547
# 1     -0.074184
# 2     -0.125072
# 3      0.171894
# 4     -0.133329
#          ...
# 295   -0.115680
# 296   -0.101476
# 297    0.154656
# 298    0.103135
# 299    0.028297
# Name: mean, Length: 300, dtype: float64

# %%
df_std = df_.loc['std']
df_std
# Out:
# 0      0.114695
# 1      0.126309
# 2      0.116858
# 3      0.111393
# 4      0.104305
#          ...
# 295    0.120257
# 296    0.101840
# 297    0.126808
# 298    0.100834
# 299    0.111167
# Name: std, Length: 300, dtype: float64

# %%
path
# Out:
# <module 'ntpath' from 'C:\\anaconda3\\envs\\fasttext\\lib\\ntpath.py'>

# %%
print(path.exists)
# Out:
# <function exists at 0x000001E10517D678>

# %%
vec_name =  'sentences_vec.npy'
if not path.exists():
    print('true')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-7aa74666401f> in <module>
#       1 vec_name =  'sentences_vec.npy'
# ----> 2 if not path.exists():
#       3     print('true')
#
# TypeError: exists() missing 1 required positional argument: 'path'

# %%
ｃｃ

# %%
#read all txts

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.decomposition import PCA
from matplotlib import pyplot as plt

from mpl_toolkits.mplot3d import Axes3D
from pathlib import Path

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from pathlib import Path
from sklearn.metrics import (roc_curve, auc, accuracy_score)
from sklearn.preprocessing import StandardScaler

import nltk

# %%
#homePC
#path_0 = Path(r'C:\Users\SI\Python_ML\python_NLTK\NLTK_')
#officePC
path_0 = Path(r'C:\Users\Si\Desktop\python_all\python_NLTK\NLTK_')


author = ['Poe','Twain']
type_ = ['letter', 'story']
test = ['test']

choice = [0,1]

index_i = 0
index_j = 1
path = str(path_0) + str('/') + str(author[choice[index_i]]) + str('-') + str(type_[choice[index_j]])
#path = str(path_0) + str('/') + str(test[0])
print(path)

# %%
#new_dir_path_csv = 'csv/' + str(test[choice[index_i]]) + str('_') 
#new_dir_path_png = 'png/' + str(test[choice[index_i]]) + str('_') 

#author_type = str(test[choice[index_i]]) + str('_')

new_dir_path_csv = 'csv/' + str(author[choice[index_i]]) + str('-') + str(type_[choice[index_j]])
new_dir_path_png = 'png/' + str(author[choice[index_i]]) + str('-') + str(type_[choice[index_j]])

author_type = str(author[choice[index_i]]) + str('-') + str(type_[choice[index_j]])

new_dir_path_png_top = 'png/' + author_type + '/top_ranking'
new_dir_path_png_top_no_punc = 'png/' + author_type + '/top_ranking_no_punc'
new_dir_path_png_top_no_punc_no_stopwords = 'png/' + author_type + '/top_ranking_no_punc_no_stopwords'
new_dir_path_png_dispersion_plot = 'png/' + author_type + '/dispersion_plot'
new_dir_path_png_biagram_plot  = 'png/' + author_type + '/biagram_plot'

def my_makedirs(path):
    if not os.path.isdir(path):
        os.makedirs(path)

my_makedirs(new_dir_path_csv)
my_makedirs(new_dir_path_png)
my_makedirs(new_dir_path_png_top)
my_makedirs(new_dir_path_png_top_no_punc)
my_makedirs(new_dir_path_png_top_no_punc_no_stopwords)

my_makedirs(new_dir_path_png_dispersion_plot)
my_makedirs(new_dir_path_png_biagram_plot)

new_dir_path_csv, new_dir_path_png, new_dir_path_png_top, new_dir_path_png_top_no_punc, new_dir_path_png_top_no_punc_no_stopwords,new_dir_path_png_dispersion_plot, new_dir_path_png_biagram_plot

# %%
path = Path(path)
path
path.glob('*.txt')
list(path.glob('*.txt'))
print('lists:', path.glob('*.txt'))
#list path
path = list(path.glob('*.txt'))
path

# %%
data = pd.read_table(path[0], encoding='cp932')
data

# %%
data.columns[0]

# %%
data_list = data[data.columns[0]].values.tolist()
len(data_list),data_list

# %%
data_list[0]

# %%
from nltk.tokenize.punkt import PunktSentenceTokenizer, PunktParameters

para = data_list[0]

punkt_params = PunktParameters()
punkt_params.abbrev_types = set(['Mr', 'Mrs', 'LLC'])
tokenizer = PunktSentenceTokenizer(punkt_params)
tokens = tokenizer.tokenize(para)

for t in tokens:
    print (t, "\n")

# %%
#break the sentences into sub-sentences

# %%
import re
from contextlib import redirect_stdout
from io import StringIO

example = 'Mary had a little lamb, Jack went up the hill, Jill followed suit, i woke up suddenly, it was a really bad dream...'

def token_to_sentence(str):
    f = StringIO()
    with redirect_stdout(f):
        regex_of_sentence = re.findall('([\w\s]{0,})[^\w\s]', str)
        regex_of_sentence = [x for x in regex_of_sentence if x is not '']
        for i in regex_of_sentence:
            print(i)
        first_step_to_sentence = (f.getvalue()).split('\n')
    g = StringIO()
    with redirect_stdout(g):
        for i in first_step_to_sentence:
            try:
                regex_to_clear_sentence = re.search('\s([\w\s]{0,})', i)
                print(regex_to_clear_sentence.group(1))
            except:
                print(i)
        sentence = (g.getvalue()).split('\n')
    return sentence

def token_to_words(str):
    f = StringIO()
    with redirect_stdout(f):
        for i in str:
            regex_of_word = re.findall('([\w]{0,})', i)
            regex_of_word = [x for x in regex_of_word if x is not '']
            for word in regex_of_word:
                print(regex_of_word)
        words = (f.getvalue()).split('\n')

# %%
sentence = token_to_sentence(data_list[0])
words = token_to_words(data_list[0])

# %%
sentence, words

# %%
df_sentence = pd.DataFrame(sentence)
df_sentence

# %%
df_sentence = df_sentence.rename(columns={0: 'headline_text'})
df_sentence

# %%
df_sentence = df_sentence[0:5]
df_sentence

# %%
col = pd.DataFrame(df_sentence).columns[0]
col

# %%
series = pd.DataFrame(df_sentence)['headline_text']
series, type(series), series.shape

# %%
df_sentence = preprocess(pd.DataFrame(series))

# %%
sentences, vec = get_word_vector()
print(vec.shape)

# %%
vec,sentences

# %%
df_sentence = preprocess(pd.DataFrame(series))

# %%
print(path.exists)

# %%
np.random.seed(123)
# ランダムに50個の記事の題名を取得
#data = pd.read_csv('./abcnews-date-text.csv')

rand_index = np.random.randint(0, data.shape[0], 500)
data = data.iloc[rand_index, 1]
print('raw data')
print(data.head())

# sent = ' '.join(list(data))
# words = nltk.word_tokenize(sent)
# tags = nltk.pos_tag(words)
# tags = sorted(list(set([tag for word, tag in tags])))
# for i in tags:
    # print(nltk.help.upenn_tagset(i))
data = preprocess(pd.DataFrame(data))

sentences, vec = get_word_vector()
print(vec.shape)
#get_similar_sentence(data.iloc[0, 1], data, sentences, vec, 5)

# %%
sentence_list = []
for index, sentence in enumerate(data_list):
    print(index, sentence)
    sentence_list.extend(sentence)

# %%
df_concat = pd.concat([df_test_list[j] for j in range(len(detector_mode))], axis=axis_)

# %%
#break the story into sentences

# %%
from nltk.tokenize.punkt import PunktSentenceTokenizer, PunktParameters

para = '''Either the well was very deep, or she fell very slowly, for she had plenty
of time as she went down to look about her and to wonder what was going to happen
next. First, she tried to look down and make out what she was coming to, but it was
too dark to see anything; then she looked at the sides of the well, and noticed
that they were filled with cupboards and book-shelves; here and there she saw maps
and pictures Mr...hung upon pegs. She took down a jar from one of the shelves as she
passed; it was labelled 'ORANGE MARMALADE', but to her great disappointment it was
empty: she did not like to drop the jar for fear of killing somebody, so managed to
put it into one of the cupboards as she fell past it.'''

punkt_params = PunktParameters()
#punkt_params.abbrev_types = set(['Mr', 'Mrs', 'LLC'])
tokenizer = PunktSentenceTokenizer(punkt_params)
tokens = tokenizer.tokenize(para)

for t in tokens:
    print (t, "\n")

# %%
# ランダムに50個の記事の題名を取得
data = pd.read_csv('./abcnews-date-text.csv')
data

# %%
np.random.seed(123)
# ランダムに50個の記事の題名を取得
data = pd.read_csv('./abcnews-date-text.csv')

rand_index = np.random.randint(0, data.shape[0], 500)
data = data.iloc[rand_index, 1]
print('raw data')
print(data.head())

# sent = ' '.join(list(data))
# words = nltk.word_tokenize(sent)
# tags = nltk.pos_tag(words)
# tags = sorted(list(set([tag for word, tag in tags])))
# for i in tags:
    # print(nltk.help.upenn_tagset(i))
data = preprocess(pd.DataFrame(data))

sentences, vec = get_word_vector()
print(vec.shape)
#get_similar_sentence(data.iloc[0, 1], data, sentences, vec, 5)

# %%
# feature vector => SVM or clustering
