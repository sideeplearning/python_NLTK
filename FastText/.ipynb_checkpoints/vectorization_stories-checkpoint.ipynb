# %%
import pandas as pd
import numpy as np
import nltk
from os import path
import re
import libs as ft
from sklearn.metrics.pairwise import cosine_similarity
#from pyfasttext import FastText
#from gensim.models.wrappers import FastText
import fasttext as ft


import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Si\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Si\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.decomposition import PCA
from matplotlib import pyplot as plt

from mpl_toolkits.mplot3d import Axes3D
from pathlib import Path

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from pathlib import Path
from sklearn.metrics import (roc_curve, auc, accuracy_score)
from sklearn.preprocessing import StandardScaler

import nltk
from nltk.tokenize.punkt import PunktSentenceTokenizer, PunktParameters
from nltk.tokenize.punkt import PunktSentenceTokenizer, PunktParameters

# %%
def cleansing(x, drop_tag, tag_pos, lemmatizer):
    """
    いらない品詞を除外し，レンマ化して返す．apply関数内で使用，

    Args:
        x (Series): apply関数で呼び出されるSeries
        drop_tag (list): いらない品詞リスト(nltk)
        tag_pos (dict): key -> tag, value -> pos. レンマ化の精度向上に使用．
        lemmatizer (nltk.stem.WordNetLemmatizer): lemmatizer

    Returns:
        (str): output sentence
    """
    words = [word for word in x['headline_text'].split(' ') if word != '']  # 空文字入るとエラーになる
    tags = nltk.pos_tag(words)  # 品詞を取得
    try:
        words = [(word, tag_pos[tag]) for word, tag in tags if tag not in drop_tag]  # いらない品詞を除外
    except KeyError:
        print('drop_tag:', len(words), words)
    
    #escape termination from undentified words and output the potential point
    words_escaped_list = []
    try:
        for word, pos in words:
            print('word, pos:', word, pos)
            words = [lemmatizer.lemmatize(word, pos=pos)]
    except ValueError:
        print('lemmatization value error escaped!')
        print('words:', len(words), words)
        words_escaped_list.append(words)
    
    #words = [lemmatizer.lemmatize(word, pos=pos) for word, pos in words]
    sentence = ' '.join(words)  # 連結
    return sentence

# %%
def preprocess(data):
    """
    前処理の関数．

    Args:
        data (DataFrame): input dataset

    Retruns:
        (DataFrame): output dataset
    """
    # まずは，いらない品詞を落とし，レンマ化する．
    # その後，階層クラスタリングのときに使う用のcsvファイルとモデル学習用のtxtファイルを出力する．
    lemmatizer = nltk.stem.WordNetLemmatizer()
    # いらない品詞
    drop_tag = ['$', 'CC', 'CD', 'DT', 'IN', 'MD', 'POS', 'PRP', 'PRP$', 'RP', 'TO' , 'WP', 'WRB','WDT','PDT','EX','WP$','In']
    # 品詞とpos(lemma用)の変換辞書
    tag_pos = {'FW': 'n', 'JJ': 'a', 'JJR': 'a', 'JJS': 'a', 'NN': 'n', 'NNP': 'n', 'NNS': 'n', 'RB': 'r', 'RBR': 'r', 'VB': 'v',
               'VBD': 'v', 'VBG': 'v', 'VBN': 'v', 'VBP': 'v', 'VBZ': 'v', 'RBS': 'r',}

    data = data.assign(preprocessed=data.apply(func=cleansing, axis=1, args=(drop_tag, tag_pos, lemmatizer)))

    print('after drop and lemmatization:')
    print(data)
    data.to_csv('data.csv', sep='\t', index=False)
    data['headline_text'].to_csv('text.txt', index=False)
    
    '''
    s = data['headline_text'].values.tolist()[0]
    print(s)
    path_w = 'text.txt'
    txt = ['headline_text\n', s]
    print(txt)
    with open(path_w, mode='w') as f:
        f.writelines(txt)
    '''
    
    
    #data.to_csv('text.txt', index=False)
    return data

# %%
def get_word_vector(data_name='text.txt', model_name='./pretrained_model/model.bin'):
    """
    fasttextベースで分散表現を取得する関数．これも見てわかると思うので引数は省略．

    Returns:
        (list of list): 単語リストのリスト．[['word_0_0', 'word_0_1'], ['word_1_0', 'word_1_1', 'word_1_2'], ...]みたいな
        (array): 分散表現 次元=(文章数×分散表現の次元数)
    """
    sentences = []
    with open(data_name, mode='r',encoding="utf-8") as f:
        for line in f.readlines():
            line = re.sub('\n', '', line)
            sentences.append(line.split(' '))

    # modelが12GBくらいメモリを食うので終わったら開放する．
    vec_name =  'sentences_vc.npy'
    #if not path.exists(vec_name):
        #model = FastText.load_fasttext_format(model_name)
    model = ft.load_model(model_name)
    dim = model.get_dimension()
    sentences_vec = np.zeros((dim,))

    for words in sentences:
        vec = np.zeros((dim,))
        for word in words:
            if model.get_word_id(word) == -1:
                print('this word does not exists in corpus: %s at %s' % (word, words))
            vec = np.vstack((vec, model.get_word_vector(word)))
        vec = vec[1:, :].mean(axis=0)
        sentences_vec = np.vstack((sentences_vec, vec))
    sentences_vec = sentences_vec[1:, :]
    del model

    np.save(vec_name, sentences_vec)
    #else:
        #sentences_vec = np.load(vec_name)
    return sentences, sentences_vec

# %%
import re
from contextlib import redirect_stdout
from io import StringIO

example = 'Mary had a little lamb, Jack went up the hill, Jill followed suit, i woke up suddenly, it was a really bad dream...'

def token_to_sentence(str):
    f = StringIO()
    with redirect_stdout(f):
        regex_of_sentence = re.findall('([\w\s]{0,})[^\w\s]', str)
        regex_of_sentence = [x for x in regex_of_sentence if x is not '']
        for i in regex_of_sentence:
            print(i)
        first_step_to_sentence = (f.getvalue()).split('\n')
    g = StringIO()
    with redirect_stdout(g):
        for i in first_step_to_sentence:
            try:
                regex_to_clear_sentence = re.search('\s([\w\s]{0,})', i)
                print(regex_to_clear_sentence.group(1))
            except:
                print(i)
        sentence = (g.getvalue()).split('\n')
    return sentence

def token_to_words(str):
    f = StringIO()
    with redirect_stdout(f):
        for i in str:
            regex_of_word = re.findall('([\w]{0,})', i)
            regex_of_word = [x for x in regex_of_word if x is not '']
            for word in regex_of_word:
                print(regex_of_word)
        words = (f.getvalue()).split('\n')

# %%
#homePC
#path_0 = Path(r'C:\Users\SI\Python_ML\python_NLTK\NLTK_')
#officePC
path_0 = Path(r'C:\Users\Si\Desktop\python_all\python_NLTK\NLTK_')


author = ['Poe','Twain']
type_ = ['letter', 'story']
test = ['test']

choice = [0,1]

index_i = 0
index_j = 1
path_file = str(path_0) + str('/') + str(author[choice[index_i]]) + str('-') + str(type_[choice[index_j]])
#path = str(path_0) + str('/') + str(test[0])
print(path_file)
# Out:
# C:\Users\Si\Desktop\python_all\python_NLTK\NLTK_/Poe-story

# %%
path_file = Path(path_file)
path_file
path_file.glob('*.txt')
list(path_file.glob('*.txt'))
print('lists:', path_file.glob('*.txt'))
#list path
path_list = list(path_file.glob('*.txt'))
path_list
# Out:
# lists: <generator object Path.glob at 0x000001BFF32D6BC8>
# [WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-001.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-002.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-003.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-004.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-005.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-006.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-007.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-008.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-009.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-010.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-011.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-012.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-013.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-014.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-015.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-016.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-017.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-018.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-019.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-020.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-021.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-022.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-023.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-024.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-025.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-026.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-027.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-028.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-029.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-030.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-031.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-032.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-033.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-034.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-035.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-036.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-037.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-038.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-039.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-040.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-041.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-042.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-043.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-044.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-045.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-046.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-047.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-048.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-049.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-050.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-051.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-052.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-053.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-054.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-055.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-056.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-057.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-058.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-059.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-060.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-061.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-062.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-063.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-064.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-065.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-066.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-067.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-068.txt'),
#  WindowsPath('C:/Users/Si/Desktop/python_all/python_NLTK/NLTK_/Poe-story/Poe-story-069.txt')]

# %%
#new_dir_path_csv = 'csv/' + str(test[choice[index_i]]) + str('_') 
#new_dir_path_png = 'png/' + str(test[choice[index_i]]) + str('_') 

#author_type = str(test[choice[index_i]]) + str('_')

new_dir_path_csv = 'csv/' + str(author[choice[index_i]]) + str('-') + str(type_[choice[index_j]])
new_dir_path_png = 'png/' + str(author[choice[index_i]]) + str('-') + str(type_[choice[index_j]])

author_type = str(author[choice[index_i]]) + str('-') + str(type_[choice[index_j]])

new_dir_path_png_top = 'png/' + author_type + '/top_ranking'
new_dir_path_png_top_no_punc = 'png/' + author_type + '/top_ranking_no_punc'
new_dir_path_png_top_no_punc_no_stopwords = 'png/' + author_type + '/top_ranking_no_punc_no_stopwords'
new_dir_path_png_dispersion_plot = 'png/' + author_type + '/dispersion_plot'
new_dir_path_png_biagram_plot  = 'png/' + author_type + '/biagram_plot'

def my_makedirs(path):
    if not os.path.isdir(path):
        os.makedirs(path)

my_makedirs(new_dir_path_csv)
my_makedirs(new_dir_path_png)
my_makedirs(new_dir_path_png_top)
my_makedirs(new_dir_path_png_top_no_punc)
my_makedirs(new_dir_path_png_top_no_punc_no_stopwords)

my_makedirs(new_dir_path_png_dispersion_plot)
my_makedirs(new_dir_path_png_biagram_plot)

new_dir_path_csv, new_dir_path_png, new_dir_path_png_top, new_dir_path_png_top_no_punc, new_dir_path_png_top_no_punc_no_stopwords,new_dir_path_png_dispersion_plot, new_dir_path_png_biagram_plot
# Out:
# ('csv/Poe-story',
#  'png/Poe-story',
#  'png/Poe-story/top_ranking',
#  'png/Poe-story/top_ranking_no_punc',
#  'png/Poe-story/top_ranking_no_punc_no_stopwords',
#  'png/Poe-story/dispersion_plot',
#  'png/Poe-story/biagram_plot')

# %%
# read multi-stories and get the feature vectors

# %%
#for index in range(len(path_list)):
for index in range(1):
    print(index)
    index = 1
    data = pd.read_table(path_list[index], encoding="utf-8")
    print(data)
    data_list = data[data.columns[0]].values.tolist()
    print('len(data_list)',len(data_list))
    
    vec_list = []
    sentence_list = []
    for idx, sentence in enumerate(data_list):
        print(idx, sentence)
        para = sentence

        punkt_params = PunktParameters()
        punkt_params.abbrev_types = set(['Mr', 'Mrs', 'LLC', 'Miss'])
        tokenizer = PunktSentenceTokenizer(punkt_params)
        tokens = tokenizer.tokenize(para)

        for t in tokens:
            print (t, "\n")

        df_sentence = pd.DataFrame(tokens)
        df_sentence = df_sentence.rename(columns={0: 'headline_text'})
        print(idx, df_sentence)

        col = pd.DataFrame(df_sentence).columns[0]
        series = pd.DataFrame(df_sentence)['headline_text']
        print(col, series, type(series), series.shape)

        df_sentence = preprocess(pd.DataFrame(series))
        sentences, vec = get_word_vector()

        if len(sentences) == 0 or len(vec)==0:
            continue
        elif (len(sentences) == 1 and sentences[0][0] == 'headline_text'):
            continue
        elif (len(sentences) > 1 and sentences[0][0] == 'headline_text'):
            for j in range(vec.shape[0]):
                if j == 0:
                    continue
                else:
                    sentence_list.append(sentences[j])
                    vec_list.append(vec[j])
        else:
            for j in range(vec.shape[0]):
                sentence_list.append(sentences[j])
                vec_list.append(vec[j])

        #print(vec.shape, sentences[1], vec_list[1])
        print('idx:',idx, '\n',vec.shape, sentences)
        #sentence_list.append(sentences[1])
        #vec_list.append(vec[1])
        
        # preserve the results into csv by authers
        df_vec_list = []
        for i in range(len(vec_list)):
            vec_series = pd.Series(vec_list[i])
            vec_series
            df_vec = pd.DataFrame(vec_series)
            print(df_vec)
            df_vec_list.append(df_vec)
            
        df_vec_concat = pd.concat([df_vec_list[j] for j in range(len(vec_list))], axis=1)
        df_vec_concat
        
        df_vec_concat.to_csv(new_dir_path_csv +'\df_vec_'+str(index)+'.csv')
        df_vec2 = pd.read_csv(new_dir_path_csv +'\df_vec_'+str(index)+'.csv')
        df_vec2
        
        df_sentence_list = []
        for i in range(len(sentence_list)):
            sentence_series = pd.Series(sentence_list[i])
            sentence_series
            df_sentence = pd.DataFrame(sentence_series)
            print(df_sentence)
            df_sentence_list.append(df_sentence)

        df_sentence_concat = pd.concat([df_sentence_list[j] for j in range(len(sentence_list))], axis=1)
        df_sentence_concat

        df_sentence_concat.to_csv(new_dir_path_csv +'\df_sentence_'+str(index)+'.csv')
        df_sentence2 = pd.read_csv(new_dir_path_csv +'\df_sentence_'+str(index)+'.csv')
        df_sentence2
# Out:
# 0
#                              BYRON AND MISS CHAWORTH
# 0  Les anges says Madame Dudevant, a woman who in...
# 1  The angels are not more pure than the heart of...
# 2  The hyperbole is scarcely less than true. It w...
# 3  The boyish poet-love is indisputably that one ...
# 4  In every allusion made by the author of “Child...
# 5  That his attachment for this “Mary” (in whose ...
# 6  In view of a passion thus engendered, Miss Cha...
# 7  In absence, the bard bore easily with him all ...
# 8  She to him was the Egeria of his dreams  the V...
# len(data_list) 9
# 0 Les anges says Madame Dudevant, a woman who intersperses many an admirable sentiment amid a chaos of the most shameless and altogether objectionable fiction.
# Les anges says Madame Dudevant, a woman who intersperses many an admirable sentiment amid a chaos of the most shameless and altogether objectionable fiction.
#
# 0                                        headline_text
# 0  Les anges says Madame Dudevant, a woman who in...
# headline_text 0    Les anges says Madame Dudevant, a woman who in...
# Name: headline_text, dtype: object <class 'pandas.core.series.Series'> (1,)
# word, pos: Les n
# word, pos: anges v
# word, pos: says v
# word, pos: Madame n
# word, pos: Dudevant, n
# word, pos: woman n
# word, pos: intersperses v
# word, pos: many a
# word, pos: admirable a
# word, pos: sentiment n
# word, pos: chaos n
# word, pos: most r
# word, pos: shameless a
# word, pos: altogether r
# word, pos: objectionable a
# word, pos: fiction. n
# after drop and lemmatization:
#                                        headline_text preprocessed
# 0  Les anges says Madame Dudevant, a woman who in...     fiction.
# this word does not exists in corpus: headline_text at ['headline_text']
# this word does not exists in corpus: "Les at ['"Les', 'anges', 'says', 'Madame', 'Dudevant,', 'a', 'woman', 'who', 'intersperses', 'many', 'an', 'admirable', 'sentiment', 'amid', 'a', 'chaos', 'of', 'the', 'most', 'shameless', 'and', 'altogether', 'objectionable', 'fiction."']
# this word does not exists in corpus: Madame at ['"Les', 'anges', 'says', 'Madame', 'Dudevant,', 'a', 'woman', 'who', 'intersperses', 'many', 'an', 'admirable', 'sentiment', 'amid', 'a', 'chaos', 'of', 'the', 'most', 'shameless', 'and', 'altogether', 'objectionable', 'fiction."']
# this word does not exists in corpus: Dudevant, at ['"Les', 'anges', 'says', 'Madame', 'Dudevant,', 'a', 'woman', 'who', 'intersperses', 'many', 'an', 'admirable', 'sentiment', 'amid', 'a', 'chaos', 'of', 'the', 'most', 'shameless', 'and', 'altogether', 'objectionable', 'fiction."']
# this word does not exists in corpus: fiction." at ['"Les', 'anges', 'says', 'Madame', 'Dudevant,', 'a', 'woman', 'who', 'intersperses', 'many', 'an', 'admirable', 'sentiment', 'amid', 'a', 'chaos', 'of', 'the', 'most', 'shameless', 'and', 'altogether', 'objectionable', 'fiction."']
# idx: 0
#  (2, 300) [['headline_text'], ['"Les', 'anges', 'says', 'Madame', 'Dudevant,', 'a', 'woman', 'who', 'intersperses', 'many', 'an', 'admirable', 'sentiment', 'amid', 'a', 'chaos', 'of', 'the', 'most', 'shameless', 'and', 'altogether', 'objectionable', 'fiction."']]
#             0
# 0    0.003995
# 1   -0.051723
# 2   -0.215748
# 3    0.131537
# 4   -0.007957
# ..        ...
# 295 -0.086902
# 296 -0.064629
# 297  0.117861
# 298  0.102764
# 299  0.076706
#
# [300 rows x 1 columns]
#                 0
# 0            "Les
# 1           anges
# 2            says
# 3          Madame
# 4       Dudevant,
# 5               a
# 6           woman
# 7             who
# 8    intersperses
# 9            many
# 10             an
# 11      admirable
# 12      sentiment
# 13           amid
# 14              a
# 15          chaos
# 16             of
# 17            the
# 18           most
# 19      shameless
# 20            and
# 21     altogether
# 22  objectionable
# 23      fiction."
# 1 The angels are not more pure than the heart of a young man who loves with fervor.
# The angels are not more pure than the heart of a young man who loves with fervor.
#
# 1                                        headline_text
# 0  The angels are not more pure than the heart of...
# headline_text 0    The angels are not more pure than the heart of...
# Name: headline_text, dtype: object <class 'pandas.core.series.Series'> (1,)
# word, pos: angels n
# word, pos: are v
# word, pos: not r
# word, pos: more r
# word, pos: pure a
# word, pos: heart n
# word, pos: young a
# word, pos: man n
# word, pos: loves v
# word, pos: fervor. n
# after drop and lemmatization:
#                                        headline_text preprocessed
# 0  The angels are not more pure than the heart of...      fervor.
# this word does not exists in corpus: headline_text at ['headline_text']
# this word does not exists in corpus: The at ['The', 'angels', 'are', 'not', 'more', 'pure', 'than', 'the', 'heart', 'of', 'a', 'young', 'man', 'who', 'loves', 'with', 'fervor.']
# this word does not exists in corpus: fervor. at ['The', 'angels', 'are', 'not', 'more', 'pure', 'than', 'the', 'heart', 'of', 'a', 'young', 'man', 'who', 'loves', 'with', 'fervor.']
# idx: 1
#  (2, 300) [['headline_text'], ['The', 'angels', 'are', 'not', 'more', 'pure', 'than', 'the', 'heart', 'of', 'a', 'young', 'man', 'who', 'loves', 'with', 'fervor.']]
#             0
# 0    0.003995
# 1   -0.051723
# 2   -0.215748
# 3    0.131537
# 4   -0.007957
# ..        ...
# 295 -0.086902
# 296 -0.064629
# 297  0.117861
# 298  0.102764
# 299  0.076706
#
# [300 rows x 1 columns]
#             0
# 0    0.035452
# 1   -0.009137
# 2   -0.115111
# 3    0.226576
# 4   -0.035714
# ..        ...
# 295 -0.140891
# 296 -0.055871
# 297  0.146556
# 298  0.198892
# 299  0.023690
#
# [300 rows x 1 columns]
#                 0
# 0            "Les
# 1           anges
# 2            says
# 3          Madame
# 4       Dudevant,
# 5               a
# 6           woman
# 7             who
# 8    intersperses
# 9            many
# 10             an
# 11      admirable
# 12      sentiment
# 13           amid
# 14              a
# 15          chaos
# 16             of
# 17            the
# 18           most
# 19      shameless
# 20            and
# 21     altogether
# 22  objectionable
# 23      fiction."
#           0
# 0       The
# 1    angels
# 2       are
# 3       not
# 4      more
# 5      pure
# 6      than
# 7       the
# 8     heart
# 9        of
# 10        a
# 11    young
# 12      man
# 13      who
# 14    loves
# 15     with
# 16  fervor.
# 2 The hyperbole is scarcely less than true. It would be truth itself, were it averred of the love of him who is at the same time young and a poet.
# The hyperbole is scarcely less than true.
#
# It would be truth itself, were it averred of the love of him who is at the same time young and a poet.
#
# 2                                        headline_text
# 0          The hyperbole is scarcely less than true.
# 1  It would be truth itself, were it averred of t...
# headline_text 0            The hyperbole is scarcely less than true.
# 1    It would be truth itself, were it averred of t...
# Name: headline_text, dtype: object <class 'pandas.core.series.Series'> (2,)
# word, pos: hyperbole n
# word, pos: is v
# word, pos: scarcely r
# word, pos: less a
# word, pos: true. n
# word, pos: be v
# word, pos: truth a
# word, pos: itself, n
# word, pos: were v
# word, pos: averred v
# word, pos: love n
# word, pos: is v
# word, pos: same a
# word, pos: time n
# word, pos: young a
# word, pos: poet. n
# after drop and lemmatization:
#                                        headline_text preprocessed
# 0          The hyperbole is scarcely less than true.        true.
# 1  It would be truth itself, were it averred of t...        poet.
# this word does not exists in corpus: headline_text at ['headline_text']
# this word does not exists in corpus: The at ['The', 'hyperbole', 'is', 'scarcely', 'less', 'than', 'true.']
# this word does not exists in corpus: true. at ['The', 'hyperbole', 'is', 'scarcely', 'less', 'than', 'true.']
# this word does not exists in corpus: "It at ['"It', 'would', 'be', 'truth', 'itself,', 'were', 'it', 'averred', 'of', 'the', 'love', 'of', 'him', 'who', 'is', 'at', 'the', 'same', 'time', 'young', 'and', 'a', 'poet."']
# this word does not exists in corpus: poet." at ['"It', 'would', 'be', 'truth', 'itself,', 'were', 'it', 'averred', 'of', 'the', 'love', 'of', 'him', 'who', 'is', 'at', 'the', 'same', 'time', 'young', 'and', 'a', 'poet."']
# idx: 2
#  (3, 300) [['headline_text'], ['The', 'hyperbole', 'is', 'scarcely', 'less', 'than', 'true.'], ['"It', 'would', 'be', 'truth', 'itself,', 'were', 'it', 'averred', 'of', 'the', 'love', 'of', 'him', 'who', 'is', 'at', 'the', 'same', 'time', 'young', 'and', 'a', 'poet."']]
#             0
# 0    0.003995
# 1   -0.051723
# 2   -0.215748
# 3    0.131537
# 4   -0.007957
# ..        ...
# 295 -0.086902
# 296 -0.064629
# 297  0.117861
# 298  0.102764
# 299  0.076706
#
# [300 rows x 1 columns]
#             0
# 0    0.035452
# 1   -0.009137
# 2   -0.115111
# 3    0.226576
# 4   -0.035714
# ..        ...
# 295 -0.140891
# 296 -0.055871
# 297  0.146556
# 298  0.198892
# 299  0.023690
#
# [300 rows x 1 columns]
#             0
# 0   -0.153891
# 1    0.129501
# 2   -0.287953
# 3    0.257565
# 4    0.091509
# ..        ...
# 295 -0.285526
# 296 -0.035797
# 297  0.071537
# 298  0.290575
# 299  0.041802
#
# [300 rows x 1 columns]
#             0
# 0   -0.030198
# 1   -0.007204
# 2   -0.078799
# 3    0.113308
# 4   -0.057554
# ..        ...
# 295 -0.044002
# 296 -0.075793
# 297  0.090007
# 298  0.101932
# 299  0.052609
#
# [300 rows x 1 columns]
#                 0
# 0            "Les
# 1           anges
# 2            says
# 3          Madame
# 4       Dudevant,
# 5               a
# 6           woman
# 7             who
# 8    intersperses
# 9            many
# 10             an
# 11      admirable
# 12      sentiment
# 13           amid
# 14              a
# 15          chaos
# 16             of
# 17            the
# 18           most
# 19      shameless
# 20            and
# 21     altogether
# 22  objectionable
# 23      fiction."
#           0
# 0       The
# 1    angels
# 2       are
# 3       not
# 4      more
# 5      pure
# 6      than
# 7       the
# 8     heart
# 9        of
# 10        a
# 11    young
# 12      man
# 13      who
# 14    loves
# 15     with
# 16  fervor.
#            0
# 0        The
# 1  hyperbole
# 2         is
# 3   scarcely
# 4       less
# 5       than
# 6      true.
#           0
# 0       "It
# 1     would
# 2        be
# 3     truth
# 4   itself,
# 5      were
# 6        it
# 7   averred
# 8        of
# 9       the
# 10     love
# 11       of
# 12      him
# 13      who
# 14       is
# 15       at
# 16      the
# 17     same
# 18     time
# 19    young
# 20      and
# 21        a
# 22   poet."
# 3 The boyish poet-love is indisputably that one of the human sentiments which most nearly realizes our dreams of the chastened voluptuousness of heaven.
# The boyish poet-love is indisputably that one of the human sentiments which most nearly realizes our dreams of the chastened voluptuousness of heaven.
#
# 3                                        headline_text
# 0  The boyish poet-love is indisputably that one ...
# headline_text 0    The boyish poet-love is indisputably that one ...
# Name: headline_text, dtype: object <class 'pandas.core.series.Series'> (1,)
# word, pos: boyish a
# word, pos: poet-love n
# word, pos: is v
# word, pos: indisputably r
# word, pos: human a
# word, pos: sentiments n
# word, pos: most a
# word, pos: nearly r
# word, pos: realizes v
# word, pos: dreams n
# word, pos: chastened a
# word, pos: voluptuousness n
# word, pos: heaven. n
# after drop and lemmatization:
#                                        headline_text preprocessed
# 0  The boyish poet-love is indisputably that one ...      heaven.
# this word does not exists in corpus: headline_text at ['headline_text']
# this word does not exists in corpus: The at ['The', 'boyish', 'poet-love', 'is', 'indisputably', 'that', 'one', 'of', 'the', 'human', 'sentiments', 'which', 'most', 'nearly', 'realizes', 'our', 'dreams', 'of', 'the', 'chastened', 'voluptuousness', 'of', 'heaven.']
# this word does not exists in corpus: poet-love at ['The', 'boyish', 'poet-love', 'is', 'indisputably', 'that', 'one', 'of', 'the', 'human', 'sentiments', 'which', 'most', 'nearly', 'realizes', 'our', 'dreams', 'of', 'the', 'chastened', 'voluptuousness', 'of', 'heaven.']
# this word does not exists in corpus: heaven. at ['The', 'boyish', 'poet-love', 'is', 'indisputably', 'that', 'one', 'of', 'the', 'human', 'sentiments', 'which', 'most', 'nearly', 'realizes', 'our', 'dreams', 'of', 'the', 'chastened', 'voluptuousness', 'of', 'heaven.']
# idx: 3
#  (2, 300) [['headline_text'], ['The', 'boyish', 'poet-love', 'is', 'indisputably', 'that', 'one', 'of', 'the', 'human', 'sentiments', 'which', 'most', 'nearly', 'realizes', 'our', 'dreams', 'of', 'the', 'chastened', 'voluptuousness', 'of', 'heaven.']]
#             0
# 0    0.003995
# 1   -0.051723
# 2   -0.215748
# 3    0.131537
# 4   -0.007957
# ..        ...
# 295 -0.086902
# 296 -0.064629
# 297  0.117861
# 298  0.102764
# 299  0.076706
#
# [300 rows x 1 columns]
#             0
# 0    0.035452
# 1   -0.009137
# 2   -0.115111
# 3    0.226576
# 4   -0.035714
# ..        ...
# 295 -0.140891
# 296 -0.055871
# 297  0.146556
# 298  0.198892
# 299  0.023690
#
# [300 rows x 1 columns]
#             0
# 0   -0.153891
# 1    0.129501
# 2   -0.287953
# 3    0.257565
# 4    0.091509
# ..        ...
# 295 -0.285526
# 296 -0.035797
# 297  0.071537
# 298  0.290575
# 299  0.041802
#
# [300 rows x 1 columns]
#             0
# 0   -0.030198
# 1   -0.007204
# 2   -0.078799
# 3    0.113308
# 4   -0.057554
# ..        ...
# 295 -0.044002
# 296 -0.075793
# 297  0.090007
# 298  0.101932
# 299  0.052609
#
# [300 rows x 1 columns]
#             0
# 0    0.006597
# 1   -0.069527
# 2   -0.179672
# 3    0.202771
# 4   -0.011710
# ..        ...
# 295 -0.055516
# 296 -0.067091
# 297  0.163108
# 298  0.128330
# 299  0.037653
#
# [300 rows x 1 columns]
#                 0
# 0            "Les
# 1           anges
# 2            says
# 3          Madame
# 4       Dudevant,
# 5               a
# 6           woman
# 7             who
# 8    intersperses
# 9            many
# 10             an
# 11      admirable
# 12      sentiment
# 13           amid
# 14              a
# 15          chaos
# 16             of
# 17            the
# 18           most
# 19      shameless
# 20            and
# 21     altogether
# 22  objectionable
# 23      fiction."
#           0
# 0       The
# 1    angels
# 2       are
# 3       not
# 4      more
# 5      pure
# 6      than
# 7       the
# 8     heart
# 9        of
# 10        a
# 11    young
# 12      man
# 13      who
# 14    loves
# 15     with
# 16  fervor.
#            0
# 0        The
# 1  hyperbole
# 2         is
# 3   scarcely
# 4       less
# 5       than
# 6      true.
#           0
# 0       "It
# 1     would
# 2        be
# 3     truth
# 4   itself,
# 5      were
# 6        it
# 7   averred
# 8        of
# 9       the
# 10     love
# 11       of
# 12      him
# 13      who
# 14       is
# 15       at
# 16      the
# 17     same
# 18     time
# 19    young
# 20      and
# 21        a
# 22   poet."
#                  0
# 0              The
# 1           boyish
# 2        poet-love
# 3               is
# 4     indisputably
# 5             that
# 6              one
# 7               of
# 8              the
# 9            human
# 10      sentiments
# 11           which
# 12            most
# 13          nearly
# 14        realizes
# 15             our
# 16          dreams
# 17              of
# 18             the
# 19       chastened
# 20  voluptuousness
# 21              of
# 22         heaven.
# 4 In every allusion made by the author of “Childe Harold” to his passion for Mary Chaworth, there runs a vein of almost spiritual tenderness and purity, strongly in contrast with the gross earthliness pervading and disfiguring his ordinary love-poems. The Dream, in which the incidents of his parting with her when about to travel, are said to be delineated, or at least paralleled, has never been excelled (certainly never excelled by him) in the blended fervor, delicacy, truthfulness and ethereality which sublimate and adorn it. For this reason, it may well be doubted if he has written anything so universally popular.
# In every allusion made by the author of “Childe Harold” to his passion for Mary Chaworth, there runs a vein of almost spiritual tenderness and purity, strongly in contrast with the gross earthliness pervading and disfiguring his ordinary love-poems.
#
# The Dream, in which the incidents of his parting with her when about to travel, are said to be delineated, or at least paralleled, has never been excelled (certainly never excelled by him) in the blended fervor, delicacy, truthfulness and ethereality which sublimate and adorn it.
#
# For this reason, it may well be doubted if he has written anything so universally popular.
#
# 4                                        headline_text
# 0  In every allusion made by the author of “Child...
# 1  The Dream, in which the incidents of his parti...
# 2  For this reason, it may well be doubted if he ...
# headline_text 0    In every allusion made by the author of “Child...
# 1    The Dream, in which the incidents of his parti...
# 2    For this reason, it may well be doubted if he ...
# Name: headline_text, dtype: object <class 'pandas.core.series.Series'> (3,)
# word, pos: allusion n
# word, pos: made v
# word, pos: author n
# word, pos: “Childe n
# word, pos: Harold” n
# word, pos: passion n
# word, pos: Mary n
# word, pos: Chaworth, n
# word, pos: runs v
# word, pos: vein n
# word, pos: almost r
# word, pos: spiritual a
# word, pos: tenderness n
# word, pos: purity, n
# word, pos: strongly r
# word, pos: contrast n
# word, pos: gross a
# word, pos: earthliness n
# word, pos: pervading n
# word, pos: disfiguring v
# word, pos: ordinary a
# word, pos: love-poems. n
# word, pos: Dream, n
# word, pos: incidents n
# word, pos: parting n
# word, pos: travel, n
# word, pos: are v
# word, pos: said v
# word, pos: be v
# word, pos: delineated, a
# word, pos: least a
# word, pos: paralleled, n
# word, pos: has v
# word, pos: never r
# word, pos: been v
# word, pos: excelled v
# word, pos: (certainly r
# word, pos: never r
# word, pos: excelled v
# word, pos: him) n
# word, pos: blended a
# word, pos: fervor, n
# word, pos: delicacy, n
# word, pos: truthfulness n
# word, pos: ethereality n
# word, pos: sublimate n
# word, pos: adorn a
# word, pos: it. n
# word, pos: reason, n
# word, pos: well r
# word, pos: be v
# word, pos: doubted v
# word, pos: has v
# word, pos: written v
# word, pos: anything n
# word, pos: so r
# word, pos: universally r
# word, pos: popular. v
# after drop and lemmatization:
#                                        headline_text preprocessed
# 0  In every allusion made by the author of “Child...  love-poems.
# 1  The Dream, in which the incidents of his parti...          it.
# 2  For this reason, it may well be doubted if he ...     popular.
# this word does not exists in corpus: headline_text at ['headline_text']
# this word does not exists in corpus: "In at ['"In', 'every', 'allusion', 'made', 'by', 'the', 'author', 'of', '“Childe', 'Harold”', 'to', 'his', 'passion', 'for', 'Mary', 'Chaworth,', 'there', 'runs', 'a', 'vein', 'of', 'almost', 'spiritual', 'tenderness', 'and', 'purity,', 'strongly', 'in', 'contrast', 'with', 'the', 'gross', 'earthliness', 'pervading', 'and', 'disfiguring', 'his', 'ordinary', 'love-poems."']
# this word does not exists in corpus: “Childe at ['"In', 'every', 'allusion', 'made', 'by', 'the', 'author', 'of', '“Childe', 'Harold”', 'to', 'his', 'passion', 'for', 'Mary', 'Chaworth,', 'there', 'runs', 'a', 'vein', 'of', 'almost', 'spiritual', 'tenderness', 'and', 'purity,', 'strongly', 'in', 'contrast', 'with', 'the', 'gross', 'earthliness', 'pervading', 'and', 'disfiguring', 'his', 'ordinary', 'love-poems."']
# this word does not exists in corpus: Harold” at ['"In', 'every', 'allusion', 'made', 'by', 'the', 'author', 'of', '“Childe', 'Harold”', 'to', 'his', 'passion', 'for', 'Mary', 'Chaworth,', 'there', 'runs', 'a', 'vein', 'of', 'almost', 'spiritual', 'tenderness', 'and', 'purity,', 'strongly', 'in', 'contrast', 'with', 'the', 'gross', 'earthliness', 'pervading', 'and', 'disfiguring', 'his', 'ordinary', 'love-poems."']
# this word does not exists in corpus: Mary at ['"In', 'every', 'allusion', 'made', 'by', 'the', 'author', 'of', '“Childe', 'Harold”', 'to', 'his', 'passion', 'for', 'Mary', 'Chaworth,', 'there', 'runs', 'a', 'vein', 'of', 'almost', 'spiritual', 'tenderness', 'and', 'purity,', 'strongly', 'in', 'contrast', 'with', 'the', 'gross', 'earthliness', 'pervading', 'and', 'disfiguring', 'his', 'ordinary', 'love-poems."']
# this word does not exists in corpus: Chaworth, at ['"In', 'every', 'allusion', 'made', 'by', 'the', 'author', 'of', '“Childe', 'Harold”', 'to', 'his', 'passion', 'for', 'Mary', 'Chaworth,', 'there', 'runs', 'a', 'vein', 'of', 'almost', 'spiritual', 'tenderness', 'and', 'purity,', 'strongly', 'in', 'contrast', 'with', 'the', 'gross', 'earthliness', 'pervading', 'and', 'disfiguring', 'his', 'ordinary', 'love-poems."']
# this word does not exists in corpus: purity, at ['"In', 'every', 'allusion', 'made', 'by', 'the', 'author', 'of', '“Childe', 'Harold”', 'to', 'his', 'passion', 'for', 'Mary', 'Chaworth,', 'there', 'runs', 'a', 'vein', 'of', 'almost', 'spiritual', 'tenderness', 'and', 'purity,', 'strongly', 'in', 'contrast', 'with', 'the', 'gross', 'earthliness', 'pervading', 'and', 'disfiguring', 'his', 'ordinary', 'love-poems."']
# this word does not exists in corpus: love-poems." at ['"In', 'every', 'allusion', 'made', 'by', 'the', 'author', 'of', '“Childe', 'Harold”', 'to', 'his', 'passion', 'for', 'Mary', 'Chaworth,', 'there', 'runs', 'a', 'vein', 'of', 'almost', 'spiritual', 'tenderness', 'and', 'purity,', 'strongly', 'in', 'contrast', 'with', 'the', 'gross', 'earthliness', 'pervading', 'and', 'disfiguring', 'his', 'ordinary', 'love-poems."']
# this word does not exists in corpus: "The at ['"The', 'Dream,', 'in', 'which', 'the', 'incidents', 'of', 'his', 'parting', 'with', 'her', 'when', 'about', 'to', 'travel,', 'are', 'said', 'to', 'be', 'delineated,', 'or', 'at', 'least', 'paralleled,', 'has', 'never', 'been', 'excelled', '(certainly', 'never', 'excelled', 'by', 'him)', 'in', 'the', 'blended', 'fervor,', 'delicacy,', 'truthfulness', 'and', 'ethereality', 'which', 'sublimate', 'and', 'adorn', 'it."']
# this word does not exists in corpus: Dream, at ['"The', 'Dream,', 'in', 'which', 'the', 'incidents', 'of', 'his', 'parting', 'with', 'her', 'when', 'about', 'to', 'travel,', 'are', 'said', 'to', 'be', 'delineated,', 'or', 'at', 'least', 'paralleled,', 'has', 'never', 'been', 'excelled', '(certainly', 'never', 'excelled', 'by', 'him)', 'in', 'the', 'blended', 'fervor,', 'delicacy,', 'truthfulness', 'and', 'ethereality', 'which', 'sublimate', 'and', 'adorn', 'it."']
# this word does not exists in corpus: delineated, at ['"The', 'Dream,', 'in', 'which', 'the', 'incidents', 'of', 'his', 'parting', 'with', 'her', 'when', 'about', 'to', 'travel,', 'are', 'said', 'to', 'be', 'delineated,', 'or', 'at', 'least', 'paralleled,', 'has', 'never', 'been', 'excelled', '(certainly', 'never', 'excelled', 'by', 'him)', 'in', 'the', 'blended', 'fervor,', 'delicacy,', 'truthfulness', 'and', 'ethereality', 'which', 'sublimate', 'and', 'adorn', 'it."']
# this word does not exists in corpus: paralleled, at ['"The', 'Dream,', 'in', 'which', 'the', 'incidents', 'of', 'his', 'parting', 'with', 'her', 'when', 'about', 'to', 'travel,', 'are', 'said', 'to', 'be', 'delineated,', 'or', 'at', 'least', 'paralleled,', 'has', 'never', 'been', 'excelled', '(certainly', 'never', 'excelled', 'by', 'him)', 'in', 'the', 'blended', 'fervor,', 'delicacy,', 'truthfulness', 'and', 'ethereality', 'which', 'sublimate', 'and', 'adorn', 'it."']
# this word does not exists in corpus: (certainly at ['"The', 'Dream,', 'in', 'which', 'the', 'incidents', 'of', 'his', 'parting', 'with', 'her', 'when', 'about', 'to', 'travel,', 'are', 'said', 'to', 'be', 'delineated,', 'or', 'at', 'least', 'paralleled,', 'has', 'never', 'been', 'excelled', '(certainly', 'never', 'excelled', 'by', 'him)', 'in', 'the', 'blended', 'fervor,', 'delicacy,', 'truthfulness', 'and', 'ethereality', 'which', 'sublimate', 'and', 'adorn', 'it."']
# this word does not exists in corpus: him) at ['"The', 'Dream,', 'in', 'which', 'the', 'incidents', 'of', 'his', 'parting', 'with', 'her', 'when', 'about', 'to', 'travel,', 'are', 'said', 'to', 'be', 'delineated,', 'or', 'at', 'least', 'paralleled,', 'has', 'never', 'been', 'excelled', '(certainly', 'never', 'excelled', 'by', 'him)', 'in', 'the', 'blended', 'fervor,', 'delicacy,', 'truthfulness', 'and', 'ethereality', 'which', 'sublimate', 'and', 'adorn', 'it."']
# this word does not exists in corpus: fervor, at ['"The', 'Dream,', 'in', 'which', 'the', 'incidents', 'of', 'his', 'parting', 'with', 'her', 'when', 'about', 'to', 'travel,', 'are', 'said', 'to', 'be', 'delineated,', 'or', 'at', 'least', 'paralleled,', 'has', 'never', 'been', 'excelled', '(certainly', 'never', 'excelled', 'by', 'him)', 'in', 'the', 'blended', 'fervor,', 'delicacy,', 'truthfulness', 'and', 'ethereality', 'which', 'sublimate', 'and', 'adorn', 'it."']
# this word does not exists in corpus: delicacy, at ['"The', 'Dream,', 'in', 'which', 'the', 'incidents', 'of', 'his', 'parting', 'with', 'her', 'when', 'about', 'to', 'travel,', 'are', 'said', 'to', 'be', 'delineated,', 'or', 'at', 'least', 'paralleled,', 'has', 'never', 'been', 'excelled', '(certainly', 'never', 'excelled', 'by', 'him)', 'in', 'the', 'blended', 'fervor,', 'delicacy,', 'truthfulness', 'and', 'ethereality', 'which', 'sublimate', 'and', 'adorn', 'it."']
# this word does not exists in corpus: it." at ['"The', 'Dream,', 'in', 'which', 'the', 'incidents', 'of', 'his', 'parting', 'with', 'her', 'when', 'about', 'to', 'travel,', 'are', 'said', 'to', 'be', 'delineated,', 'or', 'at', 'least', 'paralleled,', 'has', 'never', 'been', 'excelled', '(certainly', 'never', 'excelled', 'by', 'him)', 'in', 'the', 'blended', 'fervor,', 'delicacy,', 'truthfulness', 'and', 'ethereality', 'which', 'sublimate', 'and', 'adorn', 'it."']
# this word does not exists in corpus: "For at ['"For', 'this', 'reason,', 'it', 'may', 'well', 'be', 'doubted', 'if', 'he', 'has', 'written', 'anything', 'so', 'universally', 'popular."']
# this word does not exists in corpus: popular." at ['"For', 'this', 'reason,', 'it', 'may', 'well', 'be', 'doubted', 'if', 'he', 'has', 'written', 'anything', 'so', 'universally', 'popular."']
# idx: 4
#  (4, 300) [['headline_text'], ['"In', 'every', 'allusion', 'made', 'by', 'the', 'author', 'of', '“Childe', 'Harold”', 'to', 'his', 'passion', 'for', 'Mary', 'Chaworth,', 'there', 'runs', 'a', 'vein', 'of', 'almost', 'spiritual', 'tenderness', 'and', 'purity,', 'strongly', 'in', 'contrast', 'with', 'the', 'gross', 'earthliness', 'pervading', 'and', 'disfiguring', 'his', 'ordinary', 'love-poems."'], ['"The', 'Dream,', 'in', 'which', 'the', 'incidents', 'of', 'his', 'parting', 'with', 'her', 'when', 'about', 'to', 'travel,', 'are', 'said', 'to', 'be', 'delineated,', 'or', 'at', 'least', 'paralleled,', 'has', 'never', 'been', 'excelled', '(certainly', 'never', 'excelled', 'by', 'him)', 'in', 'the', 'blended', 'fervor,', 'delicacy,', 'truthfulness', 'and', 'ethereality', 'which', 'sublimate', 'and', 'adorn', 'it."'], ['"For', 'this', 'reason,', 'it', 'may', 'well', 'be', 'doubted', 'if', 'he', 'has', 'written', 'anything', 'so', 'universally', 'popular."']]
#             0
# 0    0.003995
# 1   -0.051723
# 2   -0.215748
# 3    0.131537
# 4   -0.007957
# ..        ...
# 295 -0.086902
# 296 -0.064629
# 297  0.117861
# 298  0.102764
# 299  0.076706
#
# [300 rows x 1 columns]
#             0
# 0    0.035452
# 1   -0.009137
# 2   -0.115111
# 3    0.226576
# 4   -0.035714
# ..        ...
# 295 -0.140891
# 296 -0.055871
# 297  0.146556
# 298  0.198892
# 299  0.023690
#
# [300 rows x 1 columns]
#             0
# 0   -0.153891
# 1    0.129501
# 2   -0.287953
# 3    0.257565
# 4    0.091509
# ..        ...
# 295 -0.285526
# 296 -0.035797
# 297  0.071537
# 298  0.290575
# 299  0.041802
#
# [300 rows x 1 columns]
#             0
# 0   -0.030198
# 1   -0.007204
# 2   -0.078799
# 3    0.113308
# 4   -0.057554
# ..        ...
# 295 -0.044002
# 296 -0.075793
# 297  0.090007
# 298  0.101932
# 299  0.052609
#
# [300 rows x 1 columns]
#             0
# 0    0.006597
# 1   -0.069527
# 2   -0.179672
# 3    0.202771
# 4   -0.011710
# ..        ...
# 295 -0.055516
# 296 -0.067091
# 297  0.163108
# 298  0.128330
# 299  0.037653
#
# [300 rows x 1 columns]
#             0
# 0   -0.005902
# 1   -0.000112
# 2   -0.165291
# 3    0.210119
# 4   -0.015163
# ..        ...
# 295 -0.106911
# 296 -0.006230
# 297  0.151556
# 298  0.013650
# 299  0.082061
#
# [300 rows x 1 columns]
#             0
# 0   -0.070473
# 1    0.001491
# 2   -0.158390
# 3    0.182365
# 4   -0.034184
# ..        ...
# 295 -0.055827
# 296 -0.068437
# 297  0.147066
# 298  0.091114
# 299  0.056260
#
# [300 rows x 1 columns]
#             0
# 0   -0.167692
# 1   -0.014294
# 2   -0.123033
# 3    0.088266
# 4   -0.052464
# ..        ...
# 295 -0.158198
# 296 -0.124550
# 297  0.098641
# 298  0.113704
# 299  0.084299
#
# [300 rows x 1 columns]
#                 0
# 0            "Les
# 1           anges
# 2            says
# 3          Madame
# 4       Dudevant,
# 5               a
# 6           woman
# 7             who
# 8    intersperses
# 9            many
# 10             an
# 11      admirable
# 12      sentiment
# 13           amid
# 14              a
# 15          chaos
# 16             of
# 17            the
# 18           most
# 19      shameless
# 20            and
# 21     altogether
# 22  objectionable
# 23      fiction."
#           0
# 0       The
# 1    angels
# 2       are
# 3       not
# 4      more
# 5      pure
# 6      than
# 7       the
# 8     heart
# 9        of
# 10        a
# 11    young
# 12      man
# 13      who
# 14    loves
# 15     with
# 16  fervor.
#            0
# 0        The
# 1  hyperbole
# 2         is
# 3   scarcely
# 4       less
# 5       than
# 6      true.
#           0
# 0       "It
# 1     would
# 2        be
# 3     truth
# 4   itself,
# 5      were
# 6        it
# 7   averred
# 8        of
# 9       the
# 10     love
# 11       of
# 12      him
# 13      who
# 14       is
# 15       at
# 16      the
# 17     same
# 18     time
# 19    young
# 20      and
# 21        a
# 22   poet."
#                  0
# 0              The
# 1           boyish
# 2        poet-love
# 3               is
# 4     indisputably
# 5             that
# 6              one
# 7               of
# 8              the
# 9            human
# 10      sentiments
# 11           which
# 12            most
# 13          nearly
# 14        realizes
# 15             our
# 16          dreams
# 17              of
# 18             the
# 19       chastened
# 20  voluptuousness
# 21              of
# 22         heaven.
#                0
# 0            "In
# 1          every
# 2       allusion
# 3           made
# 4             by
# 5            the
# 6         author
# 7             of
# 8        “Childe
# 9        Harold”
# 10            to
# 11           his
# 12       passion
# 13           for
# 14          Mary
# 15     Chaworth,
# 16         there
# 17          runs
# 18             a
# 19          vein
# 20            of
# 21        almost
# 22     spiritual
# 23    tenderness
# 24           and
# 25       purity,
# 26      strongly
# 27            in
# 28      contrast
# 29          with
# 30           the
# 31         gross
# 32   earthliness
# 33     pervading
# 34           and
# 35   disfiguring
# 36           his
# 37      ordinary
# 38  love-poems."
#                0
# 0           "The
# 1         Dream,
# 2             in
# 3          which
# 4            the
# 5      incidents
# 6             of
# 7            his
# 8        parting
# 9           with
# 10           her
# 11          when
# 12         about
# 13            to
# 14       travel,
# 15           are
# 16          said
# 17            to
# 18            be
# 19   delineated,
# 20            or
# 21            at
# 22         least
# 23   paralleled,
# 24           has
# 25         never
# 26          been
# 27      excelled
# 28    (certainly
# 29         never
# 30      excelled
# 31            by
# 32          him)
# 33            in
# 34           the
# 35       blended
# 36       fervor,
# 37     delicacy,
# 38  truthfulness
# 39           and
# 40   ethereality
# 41         which
# 42     sublimate
# 43           and
# 44         adorn
# 45          it."
#               0
# 0          "For
# 1          this
# 2       reason,
# 3            it
# 4           may
# 5          well
# 6            be
# 7       doubted
# 8            if
# 9            he
# 10          has
# 11      written
# 12     anything
# 13           so
# 14  universally
# 15    popular."
# 5 That his attachment for this “Mary” (in whose very name there indeed seemed to exist for him an “enchantment”) was earnest, and long-abiding, we have every reason to believe. There are a hundred evidences of this fact, scattered not only through his own poems and letters, but in the memoirs of his relatives, and cotemporaries in general. But that it was thus earnest and enduring, does not controvert, in any degree, the opinion that it was a passion (if passion it can properly be termed) of the most thoroughly romantic shadowy and imaginative character. It was born of the hour, and of the youthful necessity to love, while it was nurtured by the waters and the hills, and the flowers and the stars. It had no peculiar regard to the person, or to the character, or to the reciprocating affection of Mary Chaworth. Any maiden, not immediately and positively repulsive, he would have loved, under the same circumstances of hourly and unrestricted communion, such as our engraving shadows forth. They met without restraint and without reserve. As mere children they sported together; in boyhood and girlhood they read  from the same books, sang the same songs, or roamed, hand in hand, through the grounds of the conjoining estates. The result was not merely natural or merely probable, it was as inevitable as destiny itself.
# That his attachment for this “Mary” (in whose very name there indeed seemed to exist for him an “enchantment”) was earnest, and long-abiding, we have every reason to believe.
#
# There are a hundred evidences of this fact, scattered not only through his own poems and letters, but in the memoirs of his relatives, and cotemporaries in general.
#
# But that it was thus earnest and enduring, does not controvert, in any degree, the opinion that it was a passion (if passion it can properly be termed) of the most thoroughly romantic shadowy and imaginative character.
#
# It was born of the hour, and of the youthful necessity to love, while it was nurtured by the waters and the hills, and the flowers and the stars.
#
# It had no peculiar regard to the person, or to the character, or to the reciprocating affection of Mary Chaworth.
#
# Any maiden, not immediately and positively repulsive, he would have loved, under the same circumstances of hourly and unrestricted communion, such as our engraving shadows forth.
#
# They met without restraint and without reserve.
#
# As mere children they sported together; in boyhood and girlhood they read  from the same books, sang the same songs, or roamed, hand in hand, through the grounds of the conjoining estates.
#
# The result was not merely natural or merely probable, it was as inevitable as destiny itself.
#
# 5                                        headline_text
# 0  That his attachment for this “Mary” (in whose ...
# 1  There are a hundred evidences of this fact, sc...
# 2  But that it was thus earnest and enduring, doe...
# 3  It was born of the hour, and of the youthful n...
# 4  It had no peculiar regard to the person, or to...
# 5  Any maiden, not immediately and positively rep...
# 6    They met without restraint and without reserve.
# 7  As mere children they sported together; in boy...
# 8  The result was not merely natural or merely pr...
# headline_text 0    That his attachment for this “Mary” (in whose ...
# 1    There are a hundred evidences of this fact, sc...
# 2    But that it was thus earnest and enduring, doe...
# 3    It was born of the hour, and of the youthful n...
# 4    It had no peculiar regard to the person, or to...
# 5    Any maiden, not immediately and positively rep...
# 6      They met without restraint and without reserve.
# 7    As mere children they sported together; in boy...
# 8    The result was not merely natural or merely pr...
# Name: headline_text, dtype: object <class 'pandas.core.series.Series'> (9,)
# word, pos: attachment n
# word, pos: “Mary” a
# word, pos: (in n
# word, pos: very r
# word, pos: name r
# word, pos: indeed r
# word, pos: seemed v
# word, pos: exist v
# word, pos: “enchantment”) n
# word, pos: was v
# word, pos: earnest, a
# word, pos: long-abiding, a
# word, pos: have v
# word, pos: reason n
# word, pos: believe. v
# word, pos: are v
# word, pos: hundred a
# word, pos: evidences n
# word, pos: fact, n
# word, pos: scattered v
# word, pos: not r
# word, pos: only r
# word, pos: own a
# word, pos: poems n
# word, pos: letters, n
# word, pos: memoirs n
# word, pos: relatives, n
# word, pos: cotemporaries n
# word, pos: general. n
# word, pos: was v
# word, pos: thus r
# word, pos: earnest a
# word, pos: enduring, n
# word, pos: does v
# word, pos: not r
# word, pos: controvert, v
# word, pos: degree, n
# word, pos: opinion n
# word, pos: was v
# word, pos: passion n
# word, pos: (if n
# word, pos: passion n
# word, pos: properly r
# word, pos: be v
# word, pos: termed) n
# word, pos: most r
# word, pos: thoroughly a
# word, pos: romantic a
# word, pos: shadowy n
# word, pos: imaginative a
# word, pos: character. n
# word, pos: was v
# word, pos: born v
# word, pos: hour, n
# word, pos: youthful a
# word, pos: necessity n
# word, pos: love, v
# word, pos: was v
# word, pos: nurtured v
# word, pos: waters n
# word, pos: hills, n
# word, pos: flowers n
# word, pos: stars. n
# word, pos: had v
# word, pos: peculiar a
# word, pos: regard n
# word, pos: person, n
# word, pos: character, n
# word, pos: reciprocating v
# word, pos: affection n
# word, pos: Mary n
# word, pos: Chaworth. n
# word, pos: not r
# word, pos: immediately r
# word, pos: positively r
# word, pos: repulsive, n
# word, pos: have v
# word, pos: loved, v
# word, pos: same a
# word, pos: circumstances n
# word, pos: hourly a
# word, pos: unrestricted a
# word, pos: communion, n
# word, pos: such a
# word, pos: engraving v
# word, pos: shadows n
# word, pos: forth. n
# word, pos: met v
# word, pos: restraint n
# word, pos: reserve. n
# word, pos: mere a
# word, pos: children n
# word, pos: sported v
# word, pos: together; n
# word, pos: boyhood n
# word, pos: girlhood n
# word, pos: read v
# word, pos: same a
# word, pos: books, n
# word, pos: sang v
# word, pos: same a
# word, pos: songs, n
# word, pos: roamed, a
# word, pos: hand n
# word, pos: hand, n
# word, pos: grounds n
# word, pos: conjoining n
# word, pos: estates. n
# word, pos: result n
# word, pos: was v
# word, pos: not r
# word, pos: merely r
# word, pos: natural a
# word, pos: merely r
# word, pos: was v
# word, pos: as r
# word, pos: inevitable a
# word, pos: destiny a
# word, pos: itself. n
# after drop and lemmatization:
#                                        headline_text preprocessed
# 0  That his attachment for this “Mary” (in whose ...     believe.
# 1  There are a hundred evidences of this fact, sc...     general.
# 2  But that it was thus earnest and enduring, doe...   character.
# 3  It was born of the hour, and of the youthful n...       stars.
# 4  It had no peculiar regard to the person, or to...    Chaworth.
# 5  Any maiden, not immediately and positively rep...       forth.
# 6    They met without restraint and without reserve.     reserve.
# 7  As mere children they sported together; in boy...     estates.
# 8  The result was not merely natural or merely pr...      itself.
# this word does not exists in corpus: headline_text at ['headline_text']
# this word does not exists in corpus: "That at ['"That', 'his', 'attachment', 'for', 'this', '“Mary”', '(in', 'whose', 'very', 'name', 'there', 'indeed', 'seemed', 'to', 'exist', 'for', 'him', 'an', '“enchantment”)', 'was', 'earnest,', 'and', 'long-abiding,', 'we', 'have', 'every', 'reason', 'to', 'believe."']
# this word does not exists in corpus: “Mary” at ['"That', 'his', 'attachment', 'for', 'this', '“Mary”', '(in', 'whose', 'very', 'name', 'there', 'indeed', 'seemed', 'to', 'exist', 'for', 'him', 'an', '“enchantment”)', 'was', 'earnest,', 'and', 'long-abiding,', 'we', 'have', 'every', 'reason', 'to', 'believe."']
# this word does not exists in corpus: (in at ['"That', 'his', 'attachment', 'for', 'this', '“Mary”', '(in', 'whose', 'very', 'name', 'there', 'indeed', 'seemed', 'to', 'exist', 'for', 'him', 'an', '“enchantment”)', 'was', 'earnest,', 'and', 'long-abiding,', 'we', 'have', 'every', 'reason', 'to', 'believe."']
# this word does not exists in corpus: “enchantment”) at ['"That', 'his', 'attachment', 'for', 'this', '“Mary”', '(in', 'whose', 'very', 'name', 'there', 'indeed', 'seemed', 'to', 'exist', 'for', 'him', 'an', '“enchantment”)', 'was', 'earnest,', 'and', 'long-abiding,', 'we', 'have', 'every', 'reason', 'to', 'believe."']
# this word does not exists in corpus: earnest, at ['"That', 'his', 'attachment', 'for', 'this', '“Mary”', '(in', 'whose', 'very', 'name', 'there', 'indeed', 'seemed', 'to', 'exist', 'for', 'him', 'an', '“enchantment”)', 'was', 'earnest,', 'and', 'long-abiding,', 'we', 'have', 'every', 'reason', 'to', 'believe."']
# this word does not exists in corpus: long-abiding, at ['"That', 'his', 'attachment', 'for', 'this', '“Mary”', '(in', 'whose', 'very', 'name', 'there', 'indeed', 'seemed', 'to', 'exist', 'for', 'him', 'an', '“enchantment”)', 'was', 'earnest,', 'and', 'long-abiding,', 'we', 'have', 'every', 'reason', 'to', 'believe."']
# this word does not exists in corpus: believe." at ['"That', 'his', 'attachment', 'for', 'this', '“Mary”', '(in', 'whose', 'very', 'name', 'there', 'indeed', 'seemed', 'to', 'exist', 'for', 'him', 'an', '“enchantment”)', 'was', 'earnest,', 'and', 'long-abiding,', 'we', 'have', 'every', 'reason', 'to', 'believe."']
# this word does not exists in corpus: "There at ['"There', 'are', 'a', 'hundred', 'evidences', 'of', 'this', 'fact,', 'scattered', 'not', 'only', 'through', 'his', 'own', 'poems', 'and', 'letters,', 'but', 'in', 'the', 'memoirs', 'of', 'his', 'relatives,', 'and', 'cotemporaries', 'in', 'general."']
# this word does not exists in corpus: relatives, at ['"There', 'are', 'a', 'hundred', 'evidences', 'of', 'this', 'fact,', 'scattered', 'not', 'only', 'through', 'his', 'own', 'poems', 'and', 'letters,', 'but', 'in', 'the', 'memoirs', 'of', 'his', 'relatives,', 'and', 'cotemporaries', 'in', 'general."']
# this word does not exists in corpus: cotemporaries at ['"There', 'are', 'a', 'hundred', 'evidences', 'of', 'this', 'fact,', 'scattered', 'not', 'only', 'through', 'his', 'own', 'poems', 'and', 'letters,', 'but', 'in', 'the', 'memoirs', 'of', 'his', 'relatives,', 'and', 'cotemporaries', 'in', 'general."']
# this word does not exists in corpus: general." at ['"There', 'are', 'a', 'hundred', 'evidences', 'of', 'this', 'fact,', 'scattered', 'not', 'only', 'through', 'his', 'own', 'poems', 'and', 'letters,', 'but', 'in', 'the', 'memoirs', 'of', 'his', 'relatives,', 'and', 'cotemporaries', 'in', 'general."']
# this word does not exists in corpus: "But at ['"But', 'that', 'it', 'was', 'thus', 'earnest', 'and', 'enduring,', 'does', 'not', 'controvert,', 'in', 'any', 'degree,', 'the', 'opinion', 'that', 'it', 'was', 'a', 'passion', '(if', 'passion', 'it', 'can', 'properly', 'be', 'termed)', 'of', 'the', 'most', 'thoroughly', 'romantic', 'shadowy', 'and', 'imaginative', 'character."']
# this word does not exists in corpus: enduring, at ['"But', 'that', 'it', 'was', 'thus', 'earnest', 'and', 'enduring,', 'does', 'not', 'controvert,', 'in', 'any', 'degree,', 'the', 'opinion', 'that', 'it', 'was', 'a', 'passion', '(if', 'passion', 'it', 'can', 'properly', 'be', 'termed)', 'of', 'the', 'most', 'thoroughly', 'romantic', 'shadowy', 'and', 'imaginative', 'character."']
# this word does not exists in corpus: controvert, at ['"But', 'that', 'it', 'was', 'thus', 'earnest', 'and', 'enduring,', 'does', 'not', 'controvert,', 'in', 'any', 'degree,', 'the', 'opinion', 'that', 'it', 'was', 'a', 'passion', '(if', 'passion', 'it', 'can', 'properly', 'be', 'termed)', 'of', 'the', 'most', 'thoroughly', 'romantic', 'shadowy', 'and', 'imaginative', 'character."']
# this word does not exists in corpus: (if at ['"But', 'that', 'it', 'was', 'thus', 'earnest', 'and', 'enduring,', 'does', 'not', 'controvert,', 'in', 'any', 'degree,', 'the', 'opinion', 'that', 'it', 'was', 'a', 'passion', '(if', 'passion', 'it', 'can', 'properly', 'be', 'termed)', 'of', 'the', 'most', 'thoroughly', 'romantic', 'shadowy', 'and', 'imaginative', 'character."']
# this word does not exists in corpus: termed) at ['"But', 'that', 'it', 'was', 'thus', 'earnest', 'and', 'enduring,', 'does', 'not', 'controvert,', 'in', 'any', 'degree,', 'the', 'opinion', 'that', 'it', 'was', 'a', 'passion', '(if', 'passion', 'it', 'can', 'properly', 'be', 'termed)', 'of', 'the', 'most', 'thoroughly', 'romantic', 'shadowy', 'and', 'imaginative', 'character."']
# this word does not exists in corpus: character." at ['"But', 'that', 'it', 'was', 'thus', 'earnest', 'and', 'enduring,', 'does', 'not', 'controvert,', 'in', 'any', 'degree,', 'the', 'opinion', 'that', 'it', 'was', 'a', 'passion', '(if', 'passion', 'it', 'can', 'properly', 'be', 'termed)', 'of', 'the', 'most', 'thoroughly', 'romantic', 'shadowy', 'and', 'imaginative', 'character."']
# this word does not exists in corpus: "It at ['"It', 'was', 'born', 'of', 'the', 'hour,', 'and', 'of', 'the', 'youthful', 'necessity', 'to', 'love,', 'while', 'it', 'was', 'nurtured', 'by', 'the', 'waters', 'and', 'the', 'hills,', 'and', 'the', 'flowers', 'and', 'the', 'stars."']
# this word does not exists in corpus: stars." at ['"It', 'was', 'born', 'of', 'the', 'hour,', 'and', 'of', 'the', 'youthful', 'necessity', 'to', 'love,', 'while', 'it', 'was', 'nurtured', 'by', 'the', 'waters', 'and', 'the', 'hills,', 'and', 'the', 'flowers', 'and', 'the', 'stars."']
# this word does not exists in corpus: "It at ['"It', 'had', 'no', 'peculiar', 'regard', 'to', 'the', 'person,', 'or', 'to', 'the', 'character,', 'or', 'to', 'the', 'reciprocating', 'affection', 'of', 'Mary', 'Chaworth."']
# this word does not exists in corpus: Mary at ['"It', 'had', 'no', 'peculiar', 'regard', 'to', 'the', 'person,', 'or', 'to', 'the', 'character,', 'or', 'to', 'the', 'reciprocating', 'affection', 'of', 'Mary', 'Chaworth."']
# this word does not exists in corpus: Chaworth." at ['"It', 'had', 'no', 'peculiar', 'regard', 'to', 'the', 'person,', 'or', 'to', 'the', 'character,', 'or', 'to', 'the', 'reciprocating', 'affection', 'of', 'Mary', 'Chaworth."']
# this word does not exists in corpus: "Any at ['"Any', 'maiden,', 'not', 'immediately', 'and', 'positively', 'repulsive,', 'he', 'would', 'have', 'loved,', 'under', 'the', 'same', 'circumstances', 'of', 'hourly', 'and', 'unrestricted', 'communion,', 'such', 'as', 'our', 'engraving', 'shadows', 'forth."']
# this word does not exists in corpus: repulsive, at ['"Any', 'maiden,', 'not', 'immediately', 'and', 'positively', 'repulsive,', 'he', 'would', 'have', 'loved,', 'under', 'the', 'same', 'circumstances', 'of', 'hourly', 'and', 'unrestricted', 'communion,', 'such', 'as', 'our', 'engraving', 'shadows', 'forth."']
# this word does not exists in corpus: communion, at ['"Any', 'maiden,', 'not', 'immediately', 'and', 'positively', 'repulsive,', 'he', 'would', 'have', 'loved,', 'under', 'the', 'same', 'circumstances', 'of', 'hourly', 'and', 'unrestricted', 'communion,', 'such', 'as', 'our', 'engraving', 'shadows', 'forth."']
# this word does not exists in corpus: forth." at ['"Any', 'maiden,', 'not', 'immediately', 'and', 'positively', 'repulsive,', 'he', 'would', 'have', 'loved,', 'under', 'the', 'same', 'circumstances', 'of', 'hourly', 'and', 'unrestricted', 'communion,', 'such', 'as', 'our', 'engraving', 'shadows', 'forth."']
# this word does not exists in corpus: They at ['They', 'met', 'without', 'restraint', 'and', 'without', 'reserve.']
# this word does not exists in corpus: reserve. at ['They', 'met', 'without', 'restraint', 'and', 'without', 'reserve.']
# this word does not exists in corpus: "As at ['"As', 'mere', 'children', 'they', 'sported', 'together;', 'in', 'boyhood', 'and', 'girlhood', 'they', 'read', '', 'from', 'the', 'same', 'books,', 'sang', 'the', 'same', 'songs,', 'or', 'roamed,', 'hand', 'in', 'hand,', 'through', 'the', 'grounds', 'of', 'the', 'conjoining', 'estates."']
# this word does not exists in corpus: together; at ['"As', 'mere', 'children', 'they', 'sported', 'together;', 'in', 'boyhood', 'and', 'girlhood', 'they', 'read', '', 'from', 'the', 'same', 'books,', 'sang', 'the', 'same', 'songs,', 'or', 'roamed,', 'hand', 'in', 'hand,', 'through', 'the', 'grounds', 'of', 'the', 'conjoining', 'estates."']
# this word does not exists in corpus:  at ['"As', 'mere', 'children', 'they', 'sported', 'together;', 'in', 'boyhood', 'and', 'girlhood', 'they', 'read', '', 'from', 'the', 'same', 'books,', 'sang', 'the', 'same', 'songs,', 'or', 'roamed,', 'hand', 'in', 'hand,', 'through', 'the', 'grounds', 'of', 'the', 'conjoining', 'estates."']
# ...
# 0    0.006597
# 1   -0.069527
# 2   -0.179672
# 3    0.202771
# 4   -0.011710
# ..        ...
# 295 -0.055516
# 296 -0.067091
# 297  0.163108
# 298  0.128330
# 299  0.037653
#
# [300 rows x 1 columns]
#             0
# 0   -0.005902
# 1   -0.000112
# 2   -0.165291
# 3    0.210119
# 4   -0.015163
# ..        ...
# 295 -0.106911
# 296 -0.006230
# 297  0.151556
# 298  0.013650
# 299  0.082061
#
# [300 rows x 1 columns]
#             0
# 0   -0.070473
# 1    0.001491
# 2   -0.158390
# 3    0.182365
# 4   -0.034184
# ..        ...
# 295 -0.055827
# 296 -0.068437
# 297  0.147066
# 298  0.091114
# 299  0.056260
#
# [300 rows x 1 columns]
#             0
# 0   -0.167692
# 1   -0.014294
# 2   -0.123033
# 3    0.088266
# 4   -0.052464
# ..        ...
# 295 -0.158198
# 296 -0.124550
# 297  0.098641
# 298  0.113704
# 299  0.084299
#
# [300 rows x 1 columns]
#             0
# 0   -0.091992
# 1    0.068875
# 2   -0.121229
# 3    0.126970
# 4   -0.069246
# ..        ...
# 295 -0.084874
# 296 -0.094813
# 297  0.107892
# 298  0.059873
# 299  0.054259
#
# [300 rows x 1 columns]
#             0
# 0    0.025645
# 1   -0.012735
# 2   -0.069371
# 3    0.189718
# 4   -0.035810
# ..        ...
# 295 -0.089727
# 296 -0.106727
# 297  0.134649
# 298  0.085635
# 299  0.076093
#
# [300 rows x 1 columns]
#             0
# 0   -0.078338
# 1    0.029569
# 2   -0.166783
# 3    0.107994
# 4   -0.038628
# ..        ...
# 295 -0.118763
# 296 -0.099074
# 297  0.155100
# 298  0.139079
# 299  0.032655
#
# [300 rows x 1 columns]
#             0
# 0   -0.076922
# 1   -0.040453
# 2   -0.092820
# 3    0.210236
# 4   -0.035269
# ..        ...
# 295 -0.053602
# 296 -0.061836
# 297  0.094179
# 298  0.059694
# 299  0.074115
#
# [300 rows x 1 columns]
#             0
# 0   -0.048188
# 1    0.020994
# 2   -0.156969
# 3    0.113585
# 4   -0.038397
# ..        ...
# 295 -0.161983
# 296 -0.098203
# 297  0.080771
# 298  0.053771
# 299  0.087283
#
# [300 rows x 1 columns]
#             0
# 0   -0.086764
# 1    0.048637
# 2   -0.161987
# 3    0.124576
# 4   -0.009568
# ..        ...
# 295 -0.103141
# 296 -0.051271
# 297  0.098953
# 298  0.071183
# 299  0.046076
#
# [300 rows x 1 columns]
#             0
# 0   -0.131448
# 1    0.051980
# 2   -0.245710
# 3    0.295390
# 4    0.025510
# ..        ...
# 295 -0.214960
# 296 -0.052583
# 297  0.220593
# 298  0.015237
# 299  0.009892
#
# [300 rows x 1 columns]
#             0
# 0    0.029506
# 1   -0.023947
# 2   -0.092039
# 3    0.194106
# 4   -0.007014
# ..        ...
# 295 -0.031634
# 296 -0.104286
# 297  0.080171
# 298  0.105688
# 299  0.107798
#
# [300 rows x 1 columns]
#             0
# 0   -0.058324
# 1    0.052361
# 2   -0.111132
# 3    0.211689
# 4   -0.084306
# ..        ...
# 295 -0.117633
# 296 -0.118447
# 297  0.100536
# 298  0.034655
# 299  0.064321
#
# [300 rows x 1 columns]
#             0
# 0   -0.059359
# 1    0.000185
# 2   -0.125374
# 3    0.150084
# 4   -0.003433
# ..        ...
# 295 -0.085119
# 296 -0.083590
# 297  0.142618
# 298  0.046429
# 299  0.017725
#
# [300 rows x 1 columns]
#             0
# 0    0.027358
# 1    0.000496
# 2   -0.091497
# 3    0.148675
# 4   -0.045273
# ..        ...
# 295 -0.020671
# 296 -0.041062
# 297  0.085309
# 298  0.012503
# 299  0.057071
#
# [300 rows x 1 columns]
#             0
# 0   -0.056542
# 1   -0.039695
# 2   -0.073512
# 3    0.148135
# 4   -0.058845
# ..        ...
# 295 -0.082240
# 296 -0.084330
# 297  0.138396
# 298  0.042927
# 299  0.025777
#
# [300 rows x 1 columns]
#             0
# 0   -0.016408
# 1    0.002130
# 2   -0.093533
# 3    0.154444
# 4   -0.085135
# ..        ...
# 295 -0.064710
# 296 -0.090079
# 297  0.199170
# 298  0.038207
# 299  0.083425
#
# [300 rows x 1 columns]
#             0
# 0   -0.056547
# 1   -0.035179
# 2   -0.135285
# 3    0.160491
# 4   -0.077414
# ..        ...
# 295 -0.077777
# 296 -0.066227
# 297  0.112291
# 298  0.123842
# 299  0.042235
#
# [300 rows x 1 columns]
#             0
# 0   -0.045248
# 1   -0.013635
# 2   -0.105201
# 3    0.209208
# 4   -0.037952
# ..        ...
# 295 -0.072555
# 296 -0.060629
# 297  0.138521
# 298  0.087072
# 299  0.060832
#
# [300 rows x 1 columns]
#             0
# 0   -0.025489
# 1    0.036911
# 2   -0.151631
# 3    0.153628
# 4   -0.008228
# ..        ...
# 295 -0.091160
# 296 -0.158863
# 297  0.111569
# 298  0.096267
# 299  0.086360
#
# [300 rows x 1 columns]
#                 0
# 0            "Les
# 1           anges
# 2            says
# 3          Madame
# 4       Dudevant,
# 5               a
# 6           woman
# 7             who
# 8    intersperses
# 9            many
# 10             an
# 11      admirable
# 12      sentiment
# 13           amid
# 14              a
# 15          chaos
# 16             of
# 17            the
# 18           most
# 19      shameless
# 20            and
# 21     altogether
# 22  objectionable
# 23      fiction."
#           0
# 0       The
# 1    angels
# 2       are
# 3       not
# 4      more
# 5      pure
# 6      than
# 7       the
# 8     heart
# 9        of
# 10        a
# 11    young
# 12      man
# 13      who
# 14    loves
# 15     with
# 16  fervor.
#            0
# 0        The
# 1  hyperbole
# 2         is
# 3   scarcely
# 4       less
# 5       than
# 6      true.
#           0
# 0       "It
# 1     would
# 2        be
# 3     truth
# 4   itself,
# 5      were
# 6        it
# 7   averred
# 8        of
# 9       the
# 10     love
# 11       of
# 12      him
# 13      who
# 14       is
# 15       at
# 16      the
# 17     same
# 18     time
# 19    young
# 20      and
# 21        a
# 22   poet."
#                  0
# 0              The
# 1           boyish
# 2        poet-love
# 3               is
# 4     indisputably
# 5             that
# 6              one
# 7               of
# 8              the
# 9            human
# 10      sentiments
# 11           which
# 12            most
# 13          nearly
# 14        realizes
# 15             our
# 16          dreams
# 17              of
# 18             the
# 19       chastened
# 20  voluptuousness
# 21              of
# 22         heaven.
#                0
# 0            "In
# 1          every
# 2       allusion
# 3           made
# 4             by
# 5            the
# 6         author
# 7             of
# 8        “Childe
# 9        Harold”
# 10            to
# 11           his
# 12       passion
# 13           for
# 14          Mary
# 15     Chaworth,
# 16         there
# 17          runs
# 18             a
# 19          vein
# 20            of
# 21        almost
# 22     spiritual
# 23    tenderness
# 24           and
# 25       purity,
# 26      strongly
# 27            in
# 28      contrast
# 29          with
# 30           the
# 31         gross
# 32   earthliness
# 33     pervading
# 34           and
# 35   disfiguring
# 36           his
# 37      ordinary
# 38  love-poems."
#                0
# 0           "The
# 1         Dream,
# 2             in
# 3          which
# 4            the
# 5      incidents
# 6             of
# 7            his
# 8        parting
# 9           with
# 10           her
# 11          when
# 12         about
# 13            to
# 14       travel,
# 15           are
# 16          said
# 17            to
# 18            be
# 19   delineated,
# 20            or
# 21            at
# 22         least
# 23   paralleled,
# 24           has
# 25         never
# 26          been
# 27      excelled
# 28    (certainly
# 29         never
# 30      excelled
# 31            by
# 32          him)
# 33            in
# 34           the
# 35       blended
# 36       fervor,
# 37     delicacy,
# 38  truthfulness
# 39           and
# 40   ethereality
# 41         which
# 42     sublimate
# 43           and
# 44         adorn
# 45          it."
#               0
# 0          "For
# 1          this
# 2       reason,
# 3            it
# 4           may
# 5          well
# 6            be
# 7       doubted
# 8            if
# 9            he
# 10          has
# 11      written
# 12     anything
# 13           so
# 14  universally
# 15    popular."
#                  0
# 0            "That
# 1              his
# 2       attachment
# 3              for
# 4             this
# 5           “Mary”
# 6              (in
# 7            whose
# 8             very
# 9             name
# 10           there
# 11          indeed
# 12          seemed
# 13              to
# 14           exist
# 15             for
# 16             him
# 17              an
# 18  “enchantment”)
# 19             was
# 20        earnest,
# 21             and
# 22   long-abiding,
# 23              we
# 24            have
# 25           every
# 26          reason
# 27              to
# 28       believe."
#                 0
# 0          "There
# 1             are
# 2               a
# 3         hundred
# 4       evidences
# 5              of
# 6            this
# 7           fact,
# 8       scattered
# 9             not
# 10           only
# 11        through
# 12            his
# 13            own
# 14          poems
# 15            and
# 16       letters,
# 17            but
# 18             in
# 19            the
# 20        memoirs
# 21             of
# 22            his
# 23     relatives,
# 24            and
# 25  cotemporaries
# 26             in
# 27      general."
#               0
# 0          "But
# 1          that
# 2            it
# 3           was
# 4          thus
# 5       earnest
# 6           and
# 7     enduring,
# 8          does
# 9           not
# 10  controvert,
# 11           in
# 12          any
# 13      degree,
# 14          the
# 15      opinion
# 16         that
# 17           it
# 18          was
# 19            a
# 20      passion
# 21          (if
# 22      passion
# 23           it
# 24          can
# 25     properly
# 26           be
# 27      termed)
# 28           of
# 29          the
# 30         most
# 31   thoroughly
# 32     romantic
# 33      shadowy
# 34          and
# 35  imaginative
# 36  character."
#             0
# 0         "It
# 1         was
# 2        born
# 3          of
# 4         the
# 5       hour,
# 6         and
# 7          of
# 8         the
# 9    youthful
# 10  necessity
# 11         to
# 12      love,
# 13      while
# 14         it
# 15        was
# 16   nurtured
# 17         by
# 18        the
# 19     waters
# 20        and
# 21        the
# 22     hills,
# 23        and
# 24        the
# 25    flowers
# 26        and
# 27        the
# 28    stars."
#                 0
# 0             "It
# 1             had
# 2              no
# 3        peculiar
# 4          regard
# 5              to
# 6             the
# 7         person,
# 8              or
# 9              to
# 10            the
# 11     character,
# 12             or
# 13             to
# 14            the
# 15  reciprocating
# 16      affection
# 17             of
# 18           Mary
# 19     Chaworth."
#                 0
# 0            "Any
# 1         maiden,
# 2             not
# 3     immediately
# 4             and
# 5      positively
# 6      repulsive,
# 7              he
# 8           would
# 9            have
# 10         loved,
# 11          under
# 12            the
# 13           same
# 14  circumstances
# 15             of
# 16         hourly
# 17            and
# 18   unrestricted
# 19     communion,
# 20           such
# 21             as
# 22            our
# 23      engraving
# 24        shadows
# 25        forth."
#            0
# 0       They
# 1        met
# 2    without
# 3  restraint
# 4        and
# 5    without
# 6   reserve.
#              0
# 0          "As
# 1         mere
# 2     children
# 3         they
# 4      sported
# 5    together;
# 6           in
# 7      boyhood
# 8          and
# 9     girlhood
# 10        they
# 11        read
# 12
# 13        from
# 14         the
# 15        same
# 16      books,
# 17        sang
# 18         the
# 19        same
# 20      songs,
# 21          or
# 22     roamed,
# 23        hand
# 24          in
# 25       hand,
# 26     through
# 27         the
# 28     grounds
# 29          of
# 30         the
# 31  conjoining
# 32   estates."
#              0
# 0         "The
# 1       result
# 2          was
# 3          not
# 4       merely
# 5      natural
# 6           or
# 7       merely
# 8    probable,
# 9           it
# 10         was
# 11          as
# 12  inevitable
# 13          as
# 14     destiny
# 15    itself."
#                     0
# 0                 "In
# 1                view
# 2                  of
# 3                   a
# 4             passion
# 5                thus
# 6         engendered,
# 7                Miss
# 8           Chaworth,
# 9                (who
# 10                 is
# 11        represented
# 12                 as
# 13          possessed
# 14                 of
# 15                 no
# 16             little
# 17           personal
# 18             beauty
# 19                and
# 20               some
# 21  accomplishments,)
# 22              could
# 23                not
# 24               have
# 25             failed
# 26                 to
# 27              serve
# 28       sufficiently
# 29               well
# 30                 as
# 31                the
# 32        incarnation
# 33                 of
# 34                the
# 35              ideal
# 36               that
# 37            haunted
# 38                the
# 39              fancy
# 40                 of
# 41                the
# 42             poet."
#                   0
# 0               "It
# 1                is
# 2           perhaps
# 3           better,
# 4     nevertheless,
# 5               for
# 6               the
# 7              mere
# 8           romance
# 9                of
# 10              the
# 11    love-passages
# 12          between
# 13              the
# 14             two,
# 15             that
# 16            their
# 17      intercourse
# 18              was
# 19           broken
# 20               up
# 21               in
# 22            early
# 23             life
# 24              and
# 25            never
# 26  uninterruptedly
# 27          resumed
# 28               in
# 29            after
# 30          years."
#                 0
# 0       "Whatever
# 1              of
# 2         warmth,
# 3        whatever
# 4              of
# 5   soul-passion,
# 6        whatever
# 7              of
# 8             the
# 9           truer
# 10           nare
# 11            and
# 12   essentiality
# 13             of
# 14        romance
# 15            was
# 16       elicited
# 17         during
# 18            the
# 19       youthful
# 20    association
# 21             is
# 22             to
# 23             be
# 24     attributed
# 25     altogether
# 26             to
# 27            the
# 28         poet."
#             0
# 0         "If
# 1         she
# 2        felt
# 3          at
# 4        all,
# 5          it
# 6         was
# 7        only
# 8       while
# 9         the
# 10  magnetism
# 11         of
# 12        his
# 13     actual
# 14   presence
# 15  compelled
# 16        her
# 17         to
# 18     feel."
#              0
# 0          "If
# 1          she
# 2    responded
# 3           at
# 4         all,
# 5           it
# 6          was
# 7       merely
# 8      because
# 9          the
# 10  necromancy
# 11          of
# 12         his
# 13       words
# 14          of
# 15        fire
# 16       could
# 17         not
# 18          do
# 19   otherwise
# 20        than
# 21      exhort
# 22           a
# 23  response."
#            0
# 0        "In
# 1   absence,
# 2        the
# 3       bard
# 4       bore
# ..       ...
# 59       had
# 60    fanned
# 61        it
# 62      into
# 63   being."
#
# [64 rows x 1 columns]
#                0
# 0            "He
# 1             to
# 2           her,
# 3             in
# 4         brief,
# 5            was
# 6              a
# 7            not
# 8    unhandsome,
# 9            and
# 10           not
# 11      ignoble,
# 12           but
# 13      somewhat
# 14  portionless,
# 15      somewhat
# 16     eccentric
# 17           and
# 18        rather
# 19          lame
# 20         young
# 21         man."
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-11-4786fb89a8ab> in <module>
#      81         df_sentence_concat
#      82
# ---> 83         df_sentence_concat.to_csv(new_dir_path_csv +'\df_sentence_'+str(index)+'.csv')
#      84         df_sentence2 = pd.read_csv(new_dir_path_csv +'\df_sentence_'+str(index)+'.csv')
#      85         df_sentence2
#
# C:\anaconda3\envs\fasttext\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# C:\anaconda3\envs\fasttext\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     188                 encoding=self.encoding,
#     189                 errors=self.errors,
# --> 190                 compression=dict(self.compression_args, method=self.compression),
#     191             )
#     192             close = True
#
# C:\anaconda3\envs\fasttext\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'csv/Poe-story\\df_sentence_1.csv'

# %%
for i in range(len(vec_list)):
    print(i, len(vec_list[i]), vec_list[i])

# %%
print(vec.shape, len(vec_list), len(vec_list[0]), type(vec_list[0]))

# %%
for i in range(len(sentence_list)):
    print(i, len(sentence_list[i]), sentence_list[i])

# %%
# save the feature vectors into csv

# %%
print(vec.shape, len(vec_list), len(vec_list[0]), type(vec_list[0]))

# %%
df_vec_list = []
for i in range(len(vec_list)):
    vec_series = pd.Series(vec_list[i])
    vec_series
    df_vec = pd.DataFrame(vec_series)
    print(df_vec)
    df_vec_list.append(df_vec)

# %%
df_vec_concat = pd.concat([df_vec_list[j] for j in range(len(vec_list))], axis=1)
df_vec_concat

# %%
df_vec_concat.to_csv(new_dir_path_csv +'\df_vec_test.csv')
df_vec2 = pd.read_csv(new_dir_path_csv +'\df_vec_test.csv')
df_vec2

# %%
# save the original sentences into csv

# %%
df_sentence_list = []
for i in range(len(sentence_list)):
    sentence_series = pd.Series(sentence_list[i])
    sentence_series
    df_sentence = pd.DataFrame(sentence_series)
    print(df_sentence)
    df_sentence_list.append(df_sentence)

df_sentence_concat = pd.concat([df_sentence_list[j] for j in range(len(sentence_list))], axis=1)
df_sentence_concat

df_sentence_concat.to_csv(new_dir_path_csv +'\df_sentence_test.csv')
df_sentence2 = pd.read_csv(new_dir_path_csv +'\df_sentence_test.csv')
df_sentence2
